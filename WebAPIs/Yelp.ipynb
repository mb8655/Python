# %% [markdown]
# <a href="https://colab.research.google.com/github/mb8655/Python/blob/main/Yelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
# Go to https://www.yelp.com/developers/
# create an app, and get the key
key = 'iI4dsdXt-g13ESGVicCEP7g8svwE657yNKQtQx0UXtrjgteJuPjddz_RYf92YIWiUJxpMx_To53E2hXoMQmnpOSc3Jws0L7SAQTH2Qdno9XFlOih236mUlx6AIEhW3Yx'
auth_header = {'Authorization': 'Bearer ' + key}

# We demo the "Business Search" part of the Yelp API
# See https://www.yelp.com/developers/documentation/v3/business_search
# for documentation
url = 'https://api.yelp.com/v3/businesses/search'

# We search for "Village Taverna in New York"
# Check the documentation for other parameters
parameters = {
    "term": "village taverna",
    "location": "new york, ny",
    "limit": 50
}

# Issue the authenticated request
resp = requests.get(url, headers=auth_header, params=parameters)
data = resp.json()

# %%
# Here is what we get back from Yelp
data
# Out:
# {'businesses': [{'id': 'ZXiT7FuFAkmjg4pXYxb06A',
#    'alias': 'village-taverna-new-york',
#    'name': 'Village Taverna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC3DAd0TXiibbrqx4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 427,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 40.73339, 'longitude': -73.99306},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '81 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 University Pl', 'New York, NY 10003']},
#    'phone': '+12129823457',
#    'display_phone': '(212) 982-3457',
#    'distance': 3109.4021102645056},
#   {'id': '7xV4gzrgaOgQYtPC3FBZig',
#    'alias': 'pylos-new-york',
#    'name': 'Pylos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XmVtTmflLK_0Ab0azWLZvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pylos-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1282,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.72608, 'longitude': -73.98415},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '128 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 E 7th St', 'New York, NY 10009']},
#    'phone': '+12124730220',
#    'display_phone': '(212) 473-0220',
#    'distance': 2448.996903034},
#   {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#    'alias': 'taverna-east-village-new-york-3',
#    'name': 'Taverna East Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YPv5hWipQLyPOJlBkq6toQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-east-village-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1009,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.73097446325832,
#     'longitude': -73.98250256441592},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '228 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 1st Ave', 'New York, NY 10009']},
#    'phone': '+12124320011',
#    'display_phone': '(212) 432-0011',
#    'distance': 3007.6510395580667},
#   {'id': 'MxE0X8ayNGii9zA2i2ZERA',
#    'alias': 'snack-taverna-new-york',
#    'name': 'Snack Taverna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6fxrI2A_435szRxdU4E-dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snack-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 389,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 40.731033, 'longitude': -74.004814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '63 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Bedford St', 'New York, NY 10014']},
#    'phone': '+12129293499',
#    'display_phone': '(212) 929-3499',
#    'distance': 2980.3515196916433},
#   {'id': '6gDUVNZo0E9lxO2DkAhHOQ',
#    'alias': 'the-greek-new-york-2',
#    'name': 'The Greek',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Trhe-HutmNkEgqib9DBcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greek-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 556,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.724, 'longitude': -74.010502},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '452 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['452 Washington St', 'New York, NY 10013']},
#    'phone': '+16464763941',
#    'display_phone': '(646) 476-3941',
#    'distance': 2473.6131928616687},
#   {'id': 'GeoR6dpTUEpdIoyAd68Irg',
#    'alias': 'kyma-new-york',
#    'name': 'Kyma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k7aFxw1WHfUf6hoDaCEkzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyma-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 442,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.73904, 'longitude': -73.99283},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '15 W 18th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122685555',
#    'display_phone': '(212) 268-5555',
#    'distance': 3748.6220938396277},
#   {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#    'alias': 'mémé-mediterranean-new-york-4',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fRTQqcUSbotg9nIRyhwdgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 718,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '581 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466928450',
#    'display_phone': '(646) 692-8450',
#    'distance': 3585.669092216312},
#   {'id': '_4Grm99JEHnDWskCHAJfUg',
#    'alias': 'kikis-new-york',
#    'name': "Kiki's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kuIPmGUJswjrTwp0HHwOvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikis-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 957,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.7144971858255,
#     'longitude': -73.9918553931336},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '130 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Division St', 'New York, NY 10002']},
#    'phone': '+16468827052',
#    'display_phone': '(646) 882-7052',
#    'distance': 1027.330009136556},
#   {'id': 'lUpyqsKw-IBqsMgYIHZj7Q',
#    'alias': 'balade-new-york',
#    'name': 'Balade',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FjSL4qV2G2hUOtDdIpoPJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balade-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1143,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.73028887013061, 'longitude': -73.9830423},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '208 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 1st Ave', 'New York, NY 10009']},
#    'phone': '+12125296868',
#    'display_phone': '(212) 529-6868',
#    'distance': 2920.7245499842466},
#   {'id': 'F89nDDlYZ7wbRe8EpLCqBw',
#    'alias': 'avra-48th-street-new-york',
#    'name': 'Avra 48th Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TvLumNxdcWX2ZX9MWUwMJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-48th-street-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1097,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.755048569901554,
#     'longitude': -73.97243859999999},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '141 E 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 E 48th St', 'New York, NY 10017']},
#    'phone': '+12127598550',
#    'display_phone': '(212) 759-8550',
#    'distance': 5814.968474593477},
#   {'id': 'gG0pitVnSaUMGbEL3boF0g',
#    'alias': 'souvlaki-gr-new-york-3',
#    'name': 'Souvlaki GR',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5_A05FjRWekB4KX3pia-DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1015,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.721196, 'longitude': -73.987118},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '116 Stanton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 Stanton St', 'New York, NY 10002']},
#    'phone': '+12127770116',
#    'display_phone': '(212) 777-0116',
#    'distance': 1853.91424027682},
#   {'id': 'ZD9OPTKRx-BWqXgfqwCy7w',
#    'alias': 'souvlaki-gr-new-york-9',
#    'name': 'Souvlaki GR',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeswqPMHq4qoZdguNN4iww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-9?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 260,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 40.75725, 'longitude': -73.96808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '231 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12128320395',
#    'display_phone': '(212) 832-0395',
#    'distance': 6172.961659773376},
#   {'id': 'Rj2ACaJcbroJLPDhRhzvBw',
#    'alias': 'shuka-new-york-3',
#    'name': 'Shuka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kWone4-EUAAlsf9Q9_eeAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shuka-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1160,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.72707, 'longitude': -74.00283},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '38 MacDougal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 MacDougal St', 'New York, NY 10012']},
#    'phone': '+12124757500',
#    'display_phone': '(212) 475-7500',
#    'distance': 2508.1446558186562},
#   {'id': 'j0n_poMVZnODYOFviLbh0Q',
#    'alias': 'taïm-mediterranean-kitchen-new-york-15',
#    'name': 'taïm mediterranean kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PuLjdgXsq57DQlQU-8OZ5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ta%C3%AFm-mediterranean-kitchen-new-york-15?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1612,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 40.736002376347,
#     'longitude': -74.0019588366439},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '222 Waverly Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Waverly Pl', 'New York, NY 10014']},
#    'phone': '+12126911287',
#    'display_phone': '(212) 691-1287',
#    'distance': 3458.7033927339817},
#   {'id': 'B55Ocx5RBWxo6AGSucYSIA',
#    'alias': 'ilili-restaurant-new-york-3',
#    'name': 'ilili Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8I4hisgbMRJnrqszXlSbjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ilili-restaurant-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 2882,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.74435, 'longitude': -73.98778},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '236 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236 5th Ave', 'New York, NY 10001']},
#    'phone': '+12126832929',
#    'display_phone': '(212) 683-2929',
#    'distance': 4365.7542899009195},
#   {'id': 'H87m0azdhuw5uo6Y166uUg',
#    'alias': 'loi-estiatorio-new-york',
#    'name': 'Loi Estiatorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4YoniqYMSjGK2vJUkPVBbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loi-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 517,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 40.765385, 'longitude': -73.978002},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '132 W 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 58th St', 'New York, NY 10019']},
#    'phone': '+12127130015',
#    'display_phone': '(212) 713-0015',
#    'distance': 6804.9066611968565},
#   {'id': 'l9b8NbDyhKhnjLKtUwlPwQ',
#    'alias': 'olea-brooklyn-2',
#    'name': 'Olea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yx0TyEWGbiuRW7pJnE1HlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olea-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1069,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 40.6877844, 'longitude': -73.9706046},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '171 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Lafayette Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186437003',
#    'display_phone': '(718) 643-7003',
#    'distance': 2796.9560205637513},
#   {'id': 'niODyKeyStKEut1b6FNlhQ',
#    'alias': 'elenis-new-york-3',
#    'name': "Eleni's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dCCKmA_4zu0kJhaGHN51dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elenis-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 233,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.736601, 'longitude': -73.985085},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '226 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['226 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12129829030',
#    'display_phone': '(212) 982-9030',
#    'distance': 3550.4406994288756},
#   {'id': '1SaKutXcH38X0KvayyDHUA',
#    'alias': 'barbounia-new-york',
#    'name': 'Barbounia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ASFe45S4xRsiu4Hc_65FqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbounia-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1544,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 40.7383263, 'longitude': -73.9880646},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '250 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12129950242',
#    'display_phone': '(212) 995-0242',
#    'distance': 3693.7310578755},
#   {'id': 'blXVGUTB-4epYW9KFsQJ_g',
#    'alias': 'the-greek-kitchen-new-york',
#    'name': 'The Greek Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5-DxNww8ox9c0YZGFeQiPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greek-kitchen-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 674,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.7697614, 'longitude': -73.9881055},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '889 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['889 10th Ave', 'New York, NY 10019']},
#    'phone': '+12125814300',
#    'display_phone': '(212) 581-4300',
#    'distance': 7170.641098602993},
#   {'id': 'h77VtGL7BCXvAALx-ZFbVA',
#    'alias': 'medusa-the-greek-brooklyn',
#    'name': 'Medusa The Greek',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LnL0R5Nzm-PFnVRicbsw0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/medusa-the-greek-brooklyn?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 319,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 40.67857, 'longitude': -73.97885},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '133 5th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13475990749',
#    'display_phone': '(347) 599-0749',
#    'distance': 3266.984226145291},
#   {'id': '5ZG_cpkQ8djxt0f33yMXKA',
#    'alias': 'a-taste-of-greece-river-edge',
#    'name': 'A Taste of Greece',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6TGB09NldK-sNWIttD4PHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-taste-of-greece-river-edge?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 623,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.940180026078,
#     'longitude': -74.0307347374599},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '935 Kinderkamack Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'River Edge',
#     'zip_code': '07661',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['935 Kinderkamack Rd', 'River Edge, NJ 07661']},
#    'phone': '+12019670029',
#    'display_phone': '(201) 967-0029',
#    'distance': 26280.829997194072},
#   {'id': 'O9LKN5kk17lQWb7mMuiBzw',
#    'alias': 'yasouvlaki-new-york',
#    'name': 'yasouvlaki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqC_qUlUimCjn0go94BR-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yasouvlaki-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 224,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.7803, 'longitude': -73.95312},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1568 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1568 3rd Ave', 'New York, NY 10128']},
#    'phone': '+19295511010',
#    'display_phone': '(929) 551-1010',
#    'distance': 9017.228544450945},
#   {'id': 'wtfEOjfOWVuugf-SuCC5yA',
#    'alias': 'avra-madison-new-york-2',
#    'name': 'Avra Madison',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LU--AK2gxp2Blv0ah1AfIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-madison-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 545,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7643, 'longitude': -73.971721},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '14 E 60th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 E 60th St', 'New York, NY 10022']},
#    'phone': '+12129370100',
#    'display_phone': '(212) 937-0100',
#    'distance': 6814.558069627135},
#   {'id': 'sI4N411hfsslUJnTkEfqWw',
#    'alias': 'mémé-mediterranean-new-york-12',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3K8t19LbWK29YF_fr1U12A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-12?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 426,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.760929, 'longitude': -73.994827},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '607 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['607 10th Ave', 'New York, NY 10036']},
#    'phone': '+19172620827',
#    'display_phone': '(917) 262-0827',
#    'distance': 6169.03703676964},
#   {'id': 'p5PlsI9rZK5vkQo3njhuGQ',
#    'alias': 'blue-door-seafood-taverna-brooklyn',
#    'name': 'Blue Door Seafood Taverna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nrqfb8b8KZhaZ8DKNFMeHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-door-seafood-taverna-brooklyn?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 270,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 40.624602, 'longitude': -74.03035},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8413 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8413 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17186808600',
#    'display_phone': '(718) 680-8600',
#    'distance': 9491.271303070647},
#   {'id': 'dy_xfi_3asaGjcVpndh1SA',
#    'alias': 'iris-restaurant-new-york',
#    'name': 'IRIS Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dPWqpOkOp5I6wIAE-VLBsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iris-restaurant-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 121,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.764981, 'longitude': -73.981702},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1740 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1740 Broadway', 'New York, NY 10019']},
#    'phone': '+12129701740',
#    'display_phone': '(212) 970-1740',
#    'distance': 6721.991798716064},
#   {'id': '1hdwhb6kzLxL3Lt3PxoHKA',
#    'alias': 'shoo-shoo-nolita-new-york',
#    'name': 'Shoo Shoo Nolita',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XFGThUONtHSEVxa8ZYgm3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shoo-shoo-nolita-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 334,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.72015, 'longitude': -73.99623},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '371 Broome St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['371 Broome St', 'New York, NY 10013']},
#    'phone': '+16465906800',
#    'display_phone': '(646) 590-6800',
#    'distance': 1632.387824313953},
#   {'id': '6KzJ3JEOQ4QrVbrrRtBxQw',
#    'alias': 'avli-the-little-greek-tavern-bayside-3',
#    'name': 'Avli The Little Greek Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7VDj0U0vBSJPBvIDK6An4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avli-the-little-greek-tavern-bayside-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1033,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.765745, 'longitude': -73.77185875889714},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '38-31 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-31 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182247575',
#    'display_phone': '(718) 224-7575',
#    'distance': 19904.651739800753},
#   {'id': 'mhhTORjUdXj-UIDjyGmhBg',
#    'alias': 'estiatorio-milos-midtown-new-york-new-york',
#    'name': 'Estiatorio Milos - Midtown New York',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/osgwbo_Kxergv6E-PLMi0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estiatorio-milos-midtown-new-york-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1144,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.763541894630784,
#     'longitude': -73.97902511983438},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '125 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122457400',
#    'display_phone': '(212) 245-7400',
#    'distance': 6586.931698828523},
#   {'id': '-fcbr1p0Uijjg3WpDDn5VA',
#    'alias': 'avlee-greek-kitchen-brooklyn-3',
#    'name': 'Avlee Greek Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KvtWu1I3tzCyUz6ZoWuUnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avlee-greek-kitchen-brooklyn-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 323,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.679911, 'longitude': -73.994879},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '349 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188555125',
#    'display_phone': '(718) 855-5125',
#    'distance': 2839.6625442656896},
#   {'id': 'XDL8GWy3uCB8bdpMiRLRJw',
#    'alias': 'agnanti-astoria',
#    'name': 'Agnanti',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Fh7ofEEbYx0sS_7wON-3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agnanti-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 596,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 40.7809792, 'longitude': -73.9179077},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '19-06 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19-06 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185454554',
#    'display_phone': '(718) 545-4554',
#    'distance': 10582.859511140405},
#   {'id': '7ZecxKox2SiVtsNDWphJZQ',
#    'alias': 'limani-new-york',
#    'name': 'Limani',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XeCx1fz0_LEfl4_jdTo9Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/limani-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 581,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 40.7593809598193,
#     'longitude': -73.9778140767212},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '45 Rockerfeller Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10111',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Rockerfeller Plz', 'New York, NY 10111']},
#    'phone': '+12128589200',
#    'display_phone': '(212) 858-9200',
#    'distance': 6156.051468233541},
#   {'id': 'Nj20jEI5OB813dBdSk8WOA',
#    'alias': 'elia-taverna-bronxville',
#    'name': 'Elia Taverna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/smmxVCmd_BTbMrWkzsjjQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elia-taverna-bronxville?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 289,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.928312, 'longitude': -73.80863},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '502 New Rochelle Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronxville',
#     'zip_code': '10708',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 New Rochelle Rd', 'Bronxville, NY 10708']},
#    'phone': '+19146634976',
#    'display_phone': '(914) 663-4976',
#    'distance': 29295.73535886023},
#   {'id': 'oY-tooKEm8F-6Il1JOQzKg',
#    'alias': 'souvlaki-gr-midtown-new-york-3',
#    'name': 'Souvlaki GR Midtown ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jJ98HAr3tUNmdwHmhpQHUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-midtown-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 884,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76465, 'longitude': -73.98029},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 W 56th St', 'New York, NY 10019']},
#    'phone': '+12129747482',
#    'display_phone': '(212) 974-7482',
#    'distance': 6683.919027849633},
#   {'id': 'JEQ00qBAepe0oSiUBdfIew',
#    'alias': 'taverna-kyclades-astoria-2',
#    'name': 'Taverna Kyclades',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eEaPAOOBugA7u7LF3kSIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-astoria-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 2910,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 40.77444, 'longitude': -73.90786},
#    'transactions': ['pickup'],
#    'price': '$$$',
#    'location': {'address1': '3601 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3601 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185458666',
#    'display_phone': '(718) 545-8666',
#    'distance': 10578.710613156496},
#   {'id': 'JIWCAWQnRVevwhbyADcLgg',
#    'alias': 'meze-brooklyn-2',
#    'name': 'Meze',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7IhUSTZWX3c86eKTRwqUZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meze-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 390,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 40.62523, 'longitude': -74.00211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6601 13th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6601 13th Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17182346393',
#    'display_phone': '(718) 234-6393',
#    'distance': 8949.272440642862},
#   {'id': 'ApbLKC5c3xoYn5XOJ85Y3g',
#    'alias': 'aliada-astoria',
#    'name': 'Aliada',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xqPjVzCz7LMuG4c3AGyv1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aliada-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 527,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.76254, 'longitude': -73.926199},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2919 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2919 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17189322240',
#    'display_phone': '(718) 932-2240',
#    'distance': 8557.109281722222},
#   {'id': '5mJgmAgKpTbCDdpVs7OFxQ',
#    'alias': 'teds-corner-tavern-new-york',
#    'name': "Ted's Corner Tavern",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2KnqiHd3KjNlwg3RNy70Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teds-corner-tavern-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 252,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.7462, 'longitude': -73.9774599},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '523 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['523 3rd Ave', 'New York, NY 10016']},
#    'phone': '+12126892676',
#    'display_phone': '(212) 689-2676',
#    'distance': 4748.58993654257},
#   {'id': 'PiDidGDx15RYgiQFKeFZSg',
#    'alias': 'athena-mediterranean-cuisine-brooklyn-3',
#    'name': 'Athena Mediterranean Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5p17oCLM-Q11wwlnIXLL6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/athena-mediterranean-cuisine-brooklyn-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 463,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 40.66476, 'longitude': -73.98648},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '535 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['535 6th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17189654578',
#    'display_phone': '(718) 965-4578',
#    'distance': 4565.933229923315},
#   {'id': 'Tp3MF3DNXuW41A10PQ2nFw',
#    'alias': 'amali-new-york-3',
#    'name': 'Amali',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gqv-h03jrUykRipL9oZoHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amali-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 537,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 40.7633557384716,
#     'longitude': -73.9686296877489},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '115 E 60th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 E 60th St', 'New York, NY 10022']},
#    'phone': '+12123398363',
#    'display_phone': '(212) 339-8363',
#    'distance': 6792.746363523484},
#   {'id': 'UslCDxX80HX-GQwl5SBr2w',
#    'alias': 'pappas-new-york-2',
#    'name': 'Pappas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jcXQGj2T99IH1I9XHtFccQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pappas-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 113,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.3,
#    'coordinates': {'latitude': 40.72971, 'longitude': -74.00087},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '103 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Macdougal St', 'New York, NY 10012']},
#    'phone': '+16464102911',
#    'display_phone': '(646) 410-2911',
#    'distance': 2759.6639427750706},
#   {'id': 'FxOt8Exq5CA5izlDPFPoUg',
#    'alias': 'gazalas-new-york-26',
#    'name': "Gazala's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YvS_HAgUD5W9BYqFJtJb-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gazalas-new-york-26?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 194,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 40.78458, 'longitude': -73.97706},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '447 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['447 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12127871800',
#    'display_phone': '(212) 787-1800',
#    'distance': 8924.739689194568},
#   {'id': '2LcsDUTlvovnFz-SEcSJTQ',
#    'alias': 'astoria-seafood-long-island-city-3',
#    'name': 'Astoria Seafood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/o0ytLTpKX1lp2_Kq0ReIVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-seafood-long-island-city-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1027,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754, 'longitude': -73.92987},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '37-10 33rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-10 33rd St', 'Long Island City, NY 10016']},
#    'phone': '+17183922680',
#    'display_phone': '(718) 392-2680',
#    'distance': 7657.624763797764},
#   {'id': 'JT-0_-OqmBLYzEvRhU-__w',
#    'alias': 'nick-s-bistro-forest-hills',
#    'name': 'Nick’s Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2r0S3ehEaG5iwRbuzTu9NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nick-s-bistro-forest-hills?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 887,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 40.709937, 'longitude': -73.8483058920307},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '104-20 Metropolitan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['104-20 Metropolitan Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17185446425',
#    'display_phone': '(718) 544-6425',
#    'distance': 12315.529805224396},
#   {'id': 'wPx4aNffBizdYmCG-WLKpQ',
#    'alias': 'loukoumi-taverna-queens',
#    'name': 'Loukoumi Taverna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HAYNGIADhktxYCqg7GbakA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loukoumi-taverna-queens?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 596,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 40.77079605926445, 'longitude': -73.9027408},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45-07 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-07 Ditmars Blvd', 'Queens, NY 11101']},
#    'phone': '+17186263200',
#    'display_phone': '(718) 626-3200',
#    'distance': 10597.322802771218},
#   {'id': 'u2Uw0v1Rqepv0X6nOyICxA',
#    'alias': 'anassa-taverna-nyc-new-york',
#    'name': 'Anassa Taverna NYC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ereKoPg8OJFoQs1Pr3bJfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anassa-taverna-nyc-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 467,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.762037, 'longitude': -73.9660633},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '200 E 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 E 60th St', 'New York, NY 10022']},
#    'phone': '+12123715200',
#    'display_phone': '(212) 371-5200',
#    'distance': 6727.289327628141},
#   {'id': 'N2nwanXq9dDvKLIy7Ovb7g',
#    'alias': 'bahari-estiatorio-astoria',
#    'name': 'Bahari Estiatorio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fmiNcfl5bhbzD_rzv-TpQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bahari-estiatorio-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 705,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.761644675396475,
#     'longitude': -73.92493932115049},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3114 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3114 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17182048968',
#    'display_phone': '(718) 204-8968',
#    'distance': 8555.675350949568},
#   {'id': 'Bn1mZhb501Tvf7_-Pfi9_g',
#    'alias': 'korali-estiatorio-new-york',
#    'name': 'Korali Estiatorio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bH4_MgTtAu98Zb_Vf7XYaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/korali-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 277,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78349, 'longitude': -73.95098},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '1662 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1662 3rd Ave', 'New York, NY 10128']},
#    'phone': '+16469645470',
#    'display_phone': '(646) 964-5470',
#    'distance': 9414.430074483178},
#   {'id': '50ak4CXlbH7UoQlwI3FAAQ',
#    'alias': 'stamna-greek-taverna-bloomfield',
#    'name': 'Stamna Greek Taverna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rxYgTxQUJ1J_rPVPKnCC_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stamna-greek-taverna-bloomfield?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 506,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 40.82803, 'longitude': -74.18677},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1055 Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bloomfield',
#     'zip_code': '07003',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1055 Broad St', 'Bloomfield, NJ 07003']},
#    'phone': '+19733385151',
#    'display_phone': '(973) 338-5151',
#    'distance': 21183.726845020825}],
#  'total': 85,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
# We get back the answer. It contains three keys
# The main one is the "business", which contains a list of the results
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
data['total']
# Out:
# 85

# %%
data['region']
# Out:
# {'center': {'longitude': -73.99429321289062, 'latitude': 40.70544486444615}}

# %%
# This is the key part of the JSON object that contains the
# results. It is a list of dictionaries. Each dictionary
# contains the entry for a single result
data['businesses']
# Out:
# [{'id': 'ZXiT7FuFAkmjg4pXYxb06A',
#   'alias': 'village-taverna-new-york',
#   'name': 'Village Taverna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC3DAd0TXiibbrqx4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/village-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 427,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.73339, 'longitude': -73.99306},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '81 University Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['81 University Pl', 'New York, NY 10003']},
#   'phone': '+12129823457',
#   'display_phone': '(212) 982-3457',
#   'distance': 3109.4021102645056},
#  {'id': '7xV4gzrgaOgQYtPC3FBZig',
#   'alias': 'pylos-new-york',
#   'name': 'Pylos',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XmVtTmflLK_0Ab0azWLZvw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pylos-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1282,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72608, 'longitude': -73.98415},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '128 E 7th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 E 7th St', 'New York, NY 10009']},
#   'phone': '+12124730220',
#   'display_phone': '(212) 473-0220',
#   'distance': 2448.996903034},
#  {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#   'alias': 'taverna-east-village-new-york-3',
#   'name': 'Taverna East Village',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YPv5hWipQLyPOJlBkq6toQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taverna-east-village-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1009,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.73097446325832,
#    'longitude': -73.98250256441592},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '228 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['228 1st Ave', 'New York, NY 10009']},
#   'phone': '+12124320011',
#   'display_phone': '(212) 432-0011',
#   'distance': 3007.6510395580667},
#  {'id': 'MxE0X8ayNGii9zA2i2ZERA',
#   'alias': 'snack-taverna-new-york',
#   'name': 'Snack Taverna',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6fxrI2A_435szRxdU4E-dA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/snack-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 389,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.731033, 'longitude': -74.004814},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '63 Bedford St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['63 Bedford St', 'New York, NY 10014']},
#   'phone': '+12129293499',
#   'display_phone': '(212) 929-3499',
#   'distance': 2980.3515196916433},
#  {'id': '6gDUVNZo0E9lxO2DkAhHOQ',
#   'alias': 'the-greek-new-york-2',
#   'name': 'The Greek',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Trhe-HutmNkEgqib9DBcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-greek-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 556,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.724, 'longitude': -74.010502},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '452 Washington St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['452 Washington St', 'New York, NY 10013']},
#   'phone': '+16464763941',
#   'display_phone': '(646) 476-3941',
#   'distance': 2473.6131928616687},
#  {'id': 'GeoR6dpTUEpdIoyAd68Irg',
#   'alias': 'kyma-new-york',
#   'name': 'Kyma',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k7aFxw1WHfUf6hoDaCEkzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kyma-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 442,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.73904, 'longitude': -73.99283},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '15 W 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['15 W 18th St', 'New York, NY 10011']},
#   'phone': '+12122685555',
#   'display_phone': '(212) 268-5555',
#   'distance': 3748.6220938396277},
#  {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#   'alias': 'mémé-mediterranean-new-york-4',
#   'name': 'Mémé Mediterranean',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fRTQqcUSbotg9nIRyhwdgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 718,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '581 Hudson St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['581 Hudson St', 'New York, NY 10014']},
#   'phone': '+16466928450',
#   'display_phone': '(646) 692-8450',
#   'distance': 3585.669092216312},
#  {'id': '_4Grm99JEHnDWskCHAJfUg',
#   'alias': 'kikis-new-york',
#   'name': "Kiki's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kuIPmGUJswjrTwp0HHwOvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kikis-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 957,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.7144971858255,
#    'longitude': -73.9918553931336},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '130 Division St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 Division St', 'New York, NY 10002']},
#   'phone': '+16468827052',
#   'display_phone': '(646) 882-7052',
#   'distance': 1027.330009136556},
#  {'id': 'lUpyqsKw-IBqsMgYIHZj7Q',
#   'alias': 'balade-new-york',
#   'name': 'Balade',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FjSL4qV2G2hUOtDdIpoPJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/balade-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1143,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'lebanese', 'title': 'Lebanese'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.73028887013061, 'longitude': -73.9830423},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '208 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['208 1st Ave', 'New York, NY 10009']},
#   'phone': '+12125296868',
#   'display_phone': '(212) 529-6868',
#   'distance': 2920.7245499842466},
#  {'id': 'F89nDDlYZ7wbRe8EpLCqBw',
#   'alias': 'avra-48th-street-new-york',
#   'name': 'Avra 48th Street',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TvLumNxdcWX2ZX9MWUwMJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/avra-48th-street-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1097,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.755048569901554,
#    'longitude': -73.97243859999999},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '141 E 48th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['141 E 48th St', 'New York, NY 10017']},
#   'phone': '+12127598550',
#   'display_phone': '(212) 759-8550',
#   'distance': 5814.968474593477},
#  {'id': 'gG0pitVnSaUMGbEL3boF0g',
#   'alias': 'souvlaki-gr-new-york-3',
#   'name': 'Souvlaki GR',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5_A05FjRWekB4KX3pia-DA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1015,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.721196, 'longitude': -73.987118},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '116 Stanton St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['116 Stanton St', 'New York, NY 10002']},
#   'phone': '+12127770116',
#   'display_phone': '(212) 777-0116',
#   'distance': 1853.91424027682},
#  {'id': 'ZD9OPTKRx-BWqXgfqwCy7w',
#   'alias': 'souvlaki-gr-new-york-9',
#   'name': 'Souvlaki GR',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GeswqPMHq4qoZdguNN4iww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-9?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 260,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.75725, 'longitude': -73.96808},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '231 E 53rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['231 E 53rd St', 'New York, NY 10022']},
#   'phone': '+12128320395',
#   'display_phone': '(212) 832-0395',
#   'distance': 6172.961659773376},
#  {'id': 'Rj2ACaJcbroJLPDhRhzvBw',
#   'alias': 'shuka-new-york-3',
#   'name': 'Shuka',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kWone4-EUAAlsf9Q9_eeAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shuka-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1160,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.72707, 'longitude': -74.00283},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '38 MacDougal St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['38 MacDougal St', 'New York, NY 10012']},
#   'phone': '+12124757500',
#   'display_phone': '(212) 475-7500',
#   'distance': 2508.1446558186562},
#  {'id': 'j0n_poMVZnODYOFviLbh0Q',
#   'alias': 'taïm-mediterranean-kitchen-new-york-15',
#   'name': 'taïm mediterranean kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PuLjdgXsq57DQlQU-8OZ5g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ta%C3%AFm-mediterranean-kitchen-new-york-15?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1612,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'kosher', 'title': 'Kosher'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.736002376347, 'longitude': -74.0019588366439},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '222 Waverly Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['222 Waverly Pl', 'New York, NY 10014']},
#   'phone': '+12126911287',
#   'display_phone': '(212) 691-1287',
#   'distance': 3458.7033927339817},
#  {'id': 'B55Ocx5RBWxo6AGSucYSIA',
#   'alias': 'ilili-restaurant-new-york-3',
#   'name': 'ilili Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8I4hisgbMRJnrqszXlSbjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ilili-restaurant-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 2882,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'lebanese', 'title': 'Lebanese'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.74435, 'longitude': -73.98778},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '236 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['236 5th Ave', 'New York, NY 10001']},
#   'phone': '+12126832929',
#   'display_phone': '(212) 683-2929',
#   'distance': 4365.7542899009195},
#  {'id': 'H87m0azdhuw5uo6Y166uUg',
#   'alias': 'loi-estiatorio-new-york',
#   'name': 'Loi Estiatorio',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4YoniqYMSjGK2vJUkPVBbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/loi-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 517,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.7,
#   'coordinates': {'latitude': 40.765385, 'longitude': -73.978002},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '132 W 58th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['132 W 58th St', 'New York, NY 10019']},
#   'phone': '+12127130015',
#   'display_phone': '(212) 713-0015',
#   'distance': 6804.9066611968565},
#  {'id': 'l9b8NbDyhKhnjLKtUwlPwQ',
#   'alias': 'olea-brooklyn-2',
#   'name': 'Olea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yx0TyEWGbiuRW7pJnE1HlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olea-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1069,
#   'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.6877844, 'longitude': -73.9706046},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '171 Lafayette Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['171 Lafayette Ave', 'Brooklyn, NY 11238']},
#   'phone': '+17186437003',
#   'display_phone': '(718) 643-7003',
#   'distance': 2796.9560205637513},
#  {'id': 'niODyKeyStKEut1b6FNlhQ',
#   'alias': 'elenis-new-york-3',
#   'name': "Eleni's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dCCKmA_4zu0kJhaGHN51dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/elenis-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 233,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.736601, 'longitude': -73.985085},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '226 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['226 3rd Ave', 'New York, NY 10003']},
#   'phone': '+12129829030',
#   'display_phone': '(212) 982-9030',
#   'distance': 3550.4406994288756},
#  {'id': '1SaKutXcH38X0KvayyDHUA',
#   'alias': 'barbounia-new-york',
#   'name': 'Barbounia',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ASFe45S4xRsiu4Hc_65FqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barbounia-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1544,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 3.7,
#   'coordinates': {'latitude': 40.7383263, 'longitude': -73.9880646},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '250 Park Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['250 Park Ave S', 'New York, NY 10003']},
#   'phone': '+12129950242',
#   'display_phone': '(212) 995-0242',
#   'distance': 3693.7310578755},
#  {'id': 'blXVGUTB-4epYW9KFsQJ_g',
#   'alias': 'the-greek-kitchen-new-york',
#   'name': 'The Greek Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5-DxNww8ox9c0YZGFeQiPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-greek-kitchen-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 674,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.7697614, 'longitude': -73.9881055},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '889 10th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['889 10th Ave', 'New York, NY 10019']},
#   'phone': '+12125814300',
#   'display_phone': '(212) 581-4300',
#   'distance': 7170.641098602993},
#  {'id': 'h77VtGL7BCXvAALx-ZFbVA',
#   'alias': 'medusa-the-greek-brooklyn',
#   'name': 'Medusa The Greek',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LnL0R5Nzm-PFnVRicbsw0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/medusa-the-greek-brooklyn?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 319,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.67857, 'longitude': -73.97885},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '133 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['133 5th Ave', 'Brooklyn, NY 11217']},
#   'phone': '+13475990749',
#   'display_phone': '(347) 599-0749',
#   'distance': 3266.984226145291},
#  {'id': '5ZG_cpkQ8djxt0f33yMXKA',
#   'alias': 'a-taste-of-greece-river-edge',
#   'name': 'A Taste of Greece',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6TGB09NldK-sNWIttD4PHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-taste-of-greece-river-edge?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 623,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.940180026078, 'longitude': -74.0307347374599},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '935 Kinderkamack Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'River Edge',
#    'zip_code': '07661',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['935 Kinderkamack Rd', 'River Edge, NJ 07661']},
#   'phone': '+12019670029',
#   'display_phone': '(201) 967-0029',
#   'distance': 26280.829997194072},
#  {'id': 'O9LKN5kk17lQWb7mMuiBzw',
#   'alias': 'yasouvlaki-new-york',
#   'name': 'yasouvlaki',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqC_qUlUimCjn0go94BR-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yasouvlaki-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 224,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.7803, 'longitude': -73.95312},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1568 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1568 3rd Ave', 'New York, NY 10128']},
#   'phone': '+19295511010',
#   'display_phone': '(929) 551-1010',
#   'distance': 9017.228544450945},
#  {'id': 'wtfEOjfOWVuugf-SuCC5yA',
#   'alias': 'avra-madison-new-york-2',
#   'name': 'Avra Madison',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LU--AK2gxp2Blv0ah1AfIA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/avra-madison-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 545,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7643, 'longitude': -73.971721},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '14 E 60th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['14 E 60th St', 'New York, NY 10022']},
#   'phone': '+12129370100',
#   'display_phone': '(212) 937-0100',
#   'distance': 6814.558069627135},
#  {'id': 'sI4N411hfsslUJnTkEfqWw',
#   'alias': 'mémé-mediterranean-new-york-12',
#   'name': 'Mémé Mediterranean',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3K8t19LbWK29YF_fr1U12A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-12?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 426,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.760929, 'longitude': -73.994827},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '607 10th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['607 10th Ave', 'New York, NY 10036']},
#   'phone': '+19172620827',
#   'display_phone': '(917) 262-0827',
#   'distance': 6169.03703676964},
#  {'id': 'p5PlsI9rZK5vkQo3njhuGQ',
#   'alias': 'blue-door-seafood-taverna-brooklyn',
#   'name': 'Blue Door Seafood Taverna',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nrqfb8b8KZhaZ8DKNFMeHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-door-seafood-taverna-brooklyn?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 270,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.624602, 'longitude': -74.03035},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8413 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8413 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186808600',
#   'display_phone': '(718) 680-8600',
#   'distance': 9491.271303070647},
#  {'id': 'dy_xfi_3asaGjcVpndh1SA',
#   'alias': 'iris-restaurant-new-york',
#   'name': 'IRIS Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dPWqpOkOp5I6wIAE-VLBsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/iris-restaurant-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 121,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'turkish', 'title': 'Turkish'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.764981, 'longitude': -73.981702},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1740 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1740 Broadway', 'New York, NY 10019']},
#   'phone': '+12129701740',
#   'display_phone': '(212) 970-1740',
#   'distance': 6721.991798716064},
#  {'id': '1hdwhb6kzLxL3Lt3PxoHKA',
#   'alias': 'shoo-shoo-nolita-new-york',
#   'name': 'Shoo Shoo Nolita',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XFGThUONtHSEVxa8ZYgm3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shoo-shoo-nolita-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 334,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.72015, 'longitude': -73.99623},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '371 Broome St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['371 Broome St', 'New York, NY 10013']},
#   'phone': '+16465906800',
#   'display_phone': '(646) 590-6800',
#   'distance': 1632.387824313953},
#  {'id': '6KzJ3JEOQ4QrVbrrRtBxQw',
#   'alias': 'avli-the-little-greek-tavern-bayside-3',
#   'name': 'Avli The Little Greek Tavern',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7VDj0U0vBSJPBvIDK6An4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/avli-the-little-greek-tavern-bayside-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1033,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.765745, 'longitude': -73.77185875889714},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '38-31 Bell Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Bayside',
#    'zip_code': '11361',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['38-31 Bell Blvd', 'Bayside, NY 11361']},
#   'phone': '+17182247575',
#   'display_phone': '(718) 224-7575',
#   'distance': 19904.651739800753},
#  {'id': 'mhhTORjUdXj-UIDjyGmhBg',
#   'alias': 'estiatorio-milos-midtown-new-york-new-york',
#   'name': 'Estiatorio Milos - Midtown New York',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/osgwbo_Kxergv6E-PLMi0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/estiatorio-milos-midtown-new-york-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1144,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.763541894630784,
#    'longitude': -73.97902511983438},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '125 W 55th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['125 W 55th St', 'New York, NY 10019']},
#   'phone': '+12122457400',
#   'display_phone': '(212) 245-7400',
#   'distance': 6586.931698828523},
#  {'id': '-fcbr1p0Uijjg3WpDDn5VA',
#   'alias': 'avlee-greek-kitchen-brooklyn-3',
#   'name': 'Avlee Greek Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KvtWu1I3tzCyUz6ZoWuUnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/avlee-greek-kitchen-brooklyn-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 323,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.679911, 'longitude': -73.994879},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '349 Smith St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['349 Smith St', 'Brooklyn, NY 11231']},
#   'phone': '+17188555125',
#   'display_phone': '(718) 855-5125',
#   'distance': 2839.6625442656896},
#  {'id': 'XDL8GWy3uCB8bdpMiRLRJw',
#   'alias': 'agnanti-astoria',
#   'name': 'Agnanti',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3Fh7ofEEbYx0sS_7wON-3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/agnanti-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 596,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.7809792, 'longitude': -73.9179077},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '19-06 Ditmars Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19-06 Ditmars Blvd', 'Astoria, NY 11105']},
#   'phone': '+17185454554',
#   'display_phone': '(718) 545-4554',
#   'distance': 10582.859511140405},
#  {'id': '7ZecxKox2SiVtsNDWphJZQ',
#   'alias': 'limani-new-york',
#   'name': 'Limani',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XeCx1fz0_LEfl4_jdTo9Og/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/limani-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 581,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 40.7593809598193,
#    'longitude': -73.9778140767212},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '45 Rockerfeller Plz',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10111',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['45 Rockerfeller Plz', 'New York, NY 10111']},
#   'phone': '+12128589200',
#   'display_phone': '(212) 858-9200',
#   'distance': 6156.051468233541},
#  {'id': 'Nj20jEI5OB813dBdSk8WOA',
#   'alias': 'elia-taverna-bronxville',
#   'name': 'Elia Taverna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/smmxVCmd_BTbMrWkzsjjQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/elia-taverna-bronxville?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 289,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.928312, 'longitude': -73.80863},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '502 New Rochelle Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronxville',
#    'zip_code': '10708',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['502 New Rochelle Rd', 'Bronxville, NY 10708']},
#   'phone': '+19146634976',
#   'display_phone': '(914) 663-4976',
#   'distance': 29295.73535886023},
#  {'id': 'oY-tooKEm8F-6Il1JOQzKg',
#   'alias': 'souvlaki-gr-midtown-new-york-3',
#   'name': 'Souvlaki GR Midtown ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jJ98HAr3tUNmdwHmhpQHUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/souvlaki-gr-midtown-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 884,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76465, 'longitude': -73.98029},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '162 W 56th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['162 W 56th St', 'New York, NY 10019']},
#   'phone': '+12129747482',
#   'display_phone': '(212) 974-7482',
#   'distance': 6683.919027849633},
#  {'id': 'JEQ00qBAepe0oSiUBdfIew',
#   'alias': 'taverna-kyclades-astoria-2',
#   'name': 'Taverna Kyclades',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-eEaPAOOBugA7u7LF3kSIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taverna-kyclades-astoria-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 2910,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.77444, 'longitude': -73.90786},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '3601 Ditmars Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3601 Ditmars Blvd', 'Astoria, NY 11105']},
#   'phone': '+17185458666',
#   'display_phone': '(718) 545-8666',
#   'distance': 10578.710613156496},
#  {'id': 'JIWCAWQnRVevwhbyADcLgg',
#   'alias': 'meze-brooklyn-2',
#   'name': 'Meze',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7IhUSTZWX3c86eKTRwqUZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/meze-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 390,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.62523, 'longitude': -74.00211},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6601 13th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11219',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6601 13th Ave', 'Brooklyn, NY 11219']},
#   'phone': '+17182346393',
#   'display_phone': '(718) 234-6393',
#   'distance': 8949.272440642862},
#  {'id': 'ApbLKC5c3xoYn5XOJ85Y3g',
#   'alias': 'aliada-astoria',
#   'name': 'Aliada',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xqPjVzCz7LMuG4c3AGyv1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aliada-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 527,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.76254, 'longitude': -73.926199},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2919 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2919 Broadway', 'Astoria, NY 11106']},
#   'phone': '+17189322240',
#   'display_phone': '(718) 932-2240',
#   'distance': 8557.109281722222},
#  {'id': '5mJgmAgKpTbCDdpVs7OFxQ',
#   'alias': 'teds-corner-tavern-new-york',
#   'name': "Ted's Corner Tavern",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2KnqiHd3KjNlwg3RNy70Ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/teds-corner-tavern-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 252,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.7462, 'longitude': -73.9774599},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '523 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['523 3rd Ave', 'New York, NY 10016']},
#   'phone': '+12126892676',
#   'display_phone': '(212) 689-2676',
#   'distance': 4748.58993654257},
#  {'id': 'PiDidGDx15RYgiQFKeFZSg',
#   'alias': 'athena-mediterranean-cuisine-brooklyn-3',
#   'name': 'Athena Mediterranean Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5p17oCLM-Q11wwlnIXLL6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/athena-mediterranean-cuisine-brooklyn-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 463,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.66476, 'longitude': -73.98648},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '535 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['535 6th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17189654578',
#   'display_phone': '(718) 965-4578',
#   'distance': 4565.933229923315},
#  {'id': 'Tp3MF3DNXuW41A10PQ2nFw',
#   'alias': 'amali-new-york-3',
#   'name': 'Amali',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gqv-h03jrUykRipL9oZoHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amali-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 537,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 40.7633557384716,
#    'longitude': -73.9686296877489},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '115 E 60th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['115 E 60th St', 'New York, NY 10022']},
#   'phone': '+12123398363',
#   'display_phone': '(212) 339-8363',
#   'distance': 6792.746363523484},
#  {'id': 'UslCDxX80HX-GQwl5SBr2w',
#   'alias': 'pappas-new-york-2',
#   'name': 'Pappas',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jcXQGj2T99IH1I9XHtFccQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pappas-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 113,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.3,
#   'coordinates': {'latitude': 40.72971, 'longitude': -74.00087},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '103 Macdougal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['103 Macdougal St', 'New York, NY 10012']},
#   'phone': '+16464102911',
#   'display_phone': '(646) 410-2911',
#   'distance': 2759.6639427750706},
#  {'id': 'FxOt8Exq5CA5izlDPFPoUg',
#   'alias': 'gazalas-new-york-26',
#   'name': "Gazala's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YvS_HAgUD5W9BYqFJtJb-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gazalas-new-york-26?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 194,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 40.78458, 'longitude': -73.97706},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '447 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['447 Amsterdam Ave', 'New York, NY 10024']},
#   'phone': '+12127871800',
#   'display_phone': '(212) 787-1800',
#   'distance': 8924.739689194568},
#  {'id': '2LcsDUTlvovnFz-SEcSJTQ',
#   'alias': 'astoria-seafood-long-island-city-3',
#   'name': 'Astoria Seafood',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/o0ytLTpKX1lp2_Kq0ReIVA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/astoria-seafood-long-island-city-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 1027,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.754, 'longitude': -73.92987},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '37-10 33rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Island City',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37-10 33rd St', 'Long Island City, NY 10016']},
#   'phone': '+17183922680',
#   'display_phone': '(718) 392-2680',
#   'distance': 7657.624763797764},
#  {'id': 'JT-0_-OqmBLYzEvRhU-__w',
#   'alias': 'nick-s-bistro-forest-hills',
#   'name': 'Nick’s Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2r0S3ehEaG5iwRbuzTu9NA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nick-s-bistro-forest-hills?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 887,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'falafel', 'title': 'Falafel'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 40.709937, 'longitude': -73.8483058920307},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '104-20 Metropolitan Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Forest Hills',
#    'zip_code': '11375',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['104-20 Metropolitan Ave', 'Forest Hills, NY 11375']},
#   'phone': '+17185446425',
#   'display_phone': '(718) 544-6425',
#   'distance': 12315.529805224396},
#  {'id': 'wPx4aNffBizdYmCG-WLKpQ',
#   'alias': 'loukoumi-taverna-queens',
#   'name': 'Loukoumi Taverna',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HAYNGIADhktxYCqg7GbakA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/loukoumi-taverna-queens?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 596,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 40.77079605926445, 'longitude': -73.9027408},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '45-07 Ditmars Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Queens',
#    'zip_code': '11101',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['45-07 Ditmars Blvd', 'Queens, NY 11101']},
#   'phone': '+17186263200',
#   'display_phone': '(718) 626-3200',
#   'distance': 10597.322802771218},
#  {'id': 'u2Uw0v1Rqepv0X6nOyICxA',
#   'alias': 'anassa-taverna-nyc-new-york',
#   'name': 'Anassa Taverna NYC',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ereKoPg8OJFoQs1Pr3bJfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anassa-taverna-nyc-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 467,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.762037, 'longitude': -73.9660633},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '200 E 60th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['200 E 60th St', 'New York, NY 10022']},
#   'phone': '+12123715200',
#   'display_phone': '(212) 371-5200',
#   'distance': 6727.289327628141},
#  {'id': 'N2nwanXq9dDvKLIy7Ovb7g',
#   'alias': 'bahari-estiatorio-astoria',
#   'name': 'Bahari Estiatorio',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fmiNcfl5bhbzD_rzv-TpQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bahari-estiatorio-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 705,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.761644675396475,
#    'longitude': -73.92493932115049},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3114 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3114 Broadway', 'Astoria, NY 11106']},
#   'phone': '+17182048968',
#   'display_phone': '(718) 204-8968',
#   'distance': 8555.675350949568},
#  {'id': 'Bn1mZhb501Tvf7_-Pfi9_g',
#   'alias': 'korali-estiatorio-new-york',
#   'name': 'Korali Estiatorio',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bH4_MgTtAu98Zb_Vf7XYaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/korali-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 277,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78349, 'longitude': -73.95098},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '1662 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1662 3rd Ave', 'New York, NY 10128']},
#   'phone': '+16469645470',
#   'display_phone': '(646) 964-5470',
#   'distance': 9414.430074483178},
#  {'id': '50ak4CXlbH7UoQlwI3FAAQ',
#   'alias': 'stamna-greek-taverna-bloomfield',
#   'name': 'Stamna Greek Taverna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rxYgTxQUJ1J_rPVPKnCC_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stamna-greek-taverna-bloomfield?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#   'review_count': 506,
#   'categories': [{'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 40.82803, 'longitude': -74.18677},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1055 Broad St',
#    'address2': '',
#    'address3': '',
#    'city': 'Bloomfield',
#    'zip_code': '07003',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['1055 Broad St', 'Bloomfield, NJ 07003']},
#   'phone': '+19733385151',
#   'display_phone': '(973) 338-5151',
#   'distance': 21183.726845020825}]

# %%
# Let's take a look at the first result
data['businesses'][0]
# Out:
# {'id': 'ZXiT7FuFAkmjg4pXYxb06A',
#  'alias': 'village-taverna-new-york',
#  'name': 'Village Taverna',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC3DAd0TXiibbrqx4g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/village-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#  'review_count': 427,
#  'categories': [{'alias': 'greek', 'title': 'Greek'},
#   {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#  'rating': 3.8,
#  'coordinates': {'latitude': 40.73339, 'longitude': -73.99306},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '81 University Pl',
#   'address2': '',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10003',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['81 University Pl', 'New York, NY 10003']},
#  'phone': '+12129823457',
#  'display_phone': '(212) 982-3457',
#  'distance': 3109.4021102645056}

# %%
# We can put the results directly into a dataframe like that:
# although this is not ideal
df = pd.DataFrame(data['businesses'])

# The issue with the approach above is that some columns (e.g location)
# are composite and instead of containing values, the datafrane now
# contain *dictionaries* as cell entries
df.head(5)
# Out:
#                        id                            alias  \
# 0  ZXiT7FuFAkmjg4pXYxb06A         village-taverna-new-york
# 1  7xV4gzrgaOgQYtPC3FBZig                   pylos-new-york
# 2  apykLG7DTZ-7xnOcZGDZZA  taverna-east-village-new-york-3
# 3  MxE0X8ayNGii9zA2i2ZERA           snack-taverna-new-york
# 4  6gDUVNZo0E9lxO2DkAhHOQ             the-greek-new-york-2
#
#                    name                                          image_url  \
# 0       Village Taverna  https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC...
# 1                 Pylos  https://s3-media1.fl.yelpcdn.com/bphoto/XmVtTm...
# 2  Taverna East Village  https://s3-media2.fl.yelpcdn.com/bphoto/YPv5hW...
# 3         Snack Taverna  https://s3-media3.fl.yelpcdn.com/bphoto/6fxrI2...
# 4             The Greek  https://s3-media3.fl.yelpcdn.com/bphoto/3Trhe-...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/village-taverna-new-y...           427
# 1      False  https://www.yelp.com/biz/pylos-new-york?adjust...          1282
# 2      False  https://www.yelp.com/biz/taverna-east-village-...          1009
# 3      False  https://www.yelp.com/biz/snack-taverna-new-yor...           389
# 4      False  https://www.yelp.com/biz/the-greek-new-york-2?...           556
#
#                                           categories  rating  \
# 0  [{'alias': 'greek', 'title': 'Greek'}, {'alias...     3.8
# 1             [{'alias': 'greek', 'title': 'Greek'}]     4.3
# 2  [{'alias': 'greek', 'title': 'Greek'}, {'alias...     4.1
# 3  [{'alias': 'greek', 'title': 'Greek'}, {'alias...     3.8
# 4  [{'alias': 'greek', 'title': 'Greek'}, {'alias...     4.3
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.73339, 'longitude': -73.99306}  [delivery, pickup]
# 1     {'latitude': 40.72608, 'longitude': -73.98415}  [delivery, pickup]
# 2  {'latitude': 40.73097446325832, 'longitude': -...  [delivery, pickup]
# 3   {'latitude': 40.731033, 'longitude': -74.004814}  [delivery, pickup]
# 4      {'latitude': 40.724, 'longitude': -74.010502}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '81 University Pl', 'address2': '...  +12129823457
# 1   $$$  {'address1': '128 E 7th St', 'address2': None,...  +12124730220
# 2   $$$  {'address1': '228 1st Ave', 'address2': '', 'a...  +12124320011
# 3    $$  {'address1': '63 Bedford St', 'address2': '', ...  +12129293499
# 4   $$$  {'address1': '452 Washington St', 'address2': ...  +16464763941
#
#     display_phone     distance
# 0  (212) 982-3457  3109.402110
# 1  (212) 473-0220  2448.996903
# 2  (212) 432-0011  3007.651040
# 3  (212) 929-3499  2980.351520
# 4  (646) 476-3941  2473.613193

# %%
# In principle, the json_normalize command should be
# able to parse the JSON response and create a dataframe
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html

df = pd.json_normalize(data['businesses'])

# We also drop columns that we do not need
df = df.drop('categories', axis='columns')
df = df.drop('transactions', axis='columns')
df = df.drop('image_url', axis='columns')
df = df.drop('location.address2', axis='columns')
df = df.drop('location.address3', axis='columns')
df = df.drop('location.display_address', axis='columns')

df
# Out:
#                         id                                       alias  \
# 0   ZXiT7FuFAkmjg4pXYxb06A                    village-taverna-new-york
# 1   7xV4gzrgaOgQYtPC3FBZig                              pylos-new-york
# 2   apykLG7DTZ-7xnOcZGDZZA             taverna-east-village-new-york-3
# 3   MxE0X8ayNGii9zA2i2ZERA                      snack-taverna-new-york
# 4   6gDUVNZo0E9lxO2DkAhHOQ                        the-greek-new-york-2
# 5   GeoR6dpTUEpdIoyAd68Irg                               kyma-new-york
# 6   enT7NJ7tLMvUMCWQcsUonw               mémé-mediterranean-new-york-4
# 7   _4Grm99JEHnDWskCHAJfUg                              kikis-new-york
# 8   lUpyqsKw-IBqsMgYIHZj7Q                             balade-new-york
# 9   F89nDDlYZ7wbRe8EpLCqBw                   avra-48th-street-new-york
# 10  gG0pitVnSaUMGbEL3boF0g                      souvlaki-gr-new-york-3
# 11  ZD9OPTKRx-BWqXgfqwCy7w                      souvlaki-gr-new-york-9
# 12  Rj2ACaJcbroJLPDhRhzvBw                            shuka-new-york-3
# 13  j0n_poMVZnODYOFviLbh0Q      taïm-mediterranean-kitchen-new-york-15
# 14  B55Ocx5RBWxo6AGSucYSIA                 ilili-restaurant-new-york-3
# 15  H87m0azdhuw5uo6Y166uUg                     loi-estiatorio-new-york
# 16  l9b8NbDyhKhnjLKtUwlPwQ                             olea-brooklyn-2
# 17  niODyKeyStKEut1b6FNlhQ                           elenis-new-york-3
# 18  1SaKutXcH38X0KvayyDHUA                          barbounia-new-york
# 19  blXVGUTB-4epYW9KFsQJ_g                  the-greek-kitchen-new-york
# 20  h77VtGL7BCXvAALx-ZFbVA                   medusa-the-greek-brooklyn
# 21  5ZG_cpkQ8djxt0f33yMXKA                a-taste-of-greece-river-edge
# 22  O9LKN5kk17lQWb7mMuiBzw                         yasouvlaki-new-york
# 23  wtfEOjfOWVuugf-SuCC5yA                     avra-madison-new-york-2
# 24  sI4N411hfsslUJnTkEfqWw              mémé-mediterranean-new-york-12
# 25  p5PlsI9rZK5vkQo3njhuGQ          blue-door-seafood-taverna-brooklyn
# 26  dy_xfi_3asaGjcVpndh1SA                    iris-restaurant-new-york
# 27  1hdwhb6kzLxL3Lt3PxoHKA                   shoo-shoo-nolita-new-york
# 28  6KzJ3JEOQ4QrVbrrRtBxQw      avli-the-little-greek-tavern-bayside-3
# 29  mhhTORjUdXj-UIDjyGmhBg  estiatorio-milos-midtown-new-york-new-york
# 30  -fcbr1p0Uijjg3WpDDn5VA              avlee-greek-kitchen-brooklyn-3
# 31  XDL8GWy3uCB8bdpMiRLRJw                             agnanti-astoria
# 32  7ZecxKox2SiVtsNDWphJZQ                             limani-new-york
# 33  Nj20jEI5OB813dBdSk8WOA                     elia-taverna-bronxville
# 34  oY-tooKEm8F-6Il1JOQzKg              souvlaki-gr-midtown-new-york-3
# 35  JEQ00qBAepe0oSiUBdfIew                  taverna-kyclades-astoria-2
# 36  JIWCAWQnRVevwhbyADcLgg                             meze-brooklyn-2
# 37  ApbLKC5c3xoYn5XOJ85Y3g                              aliada-astoria
# 38  5mJgmAgKpTbCDdpVs7OFxQ                 teds-corner-tavern-new-york
# 39  PiDidGDx15RYgiQFKeFZSg     athena-mediterranean-cuisine-brooklyn-3
# 40  Tp3MF3DNXuW41A10PQ2nFw                            amali-new-york-3
# 41  UslCDxX80HX-GQwl5SBr2w                           pappas-new-york-2
# 42  FxOt8Exq5CA5izlDPFPoUg                         gazalas-new-york-26
# 43  2LcsDUTlvovnFz-SEcSJTQ          astoria-seafood-long-island-city-3
# 44  JT-0_-OqmBLYzEvRhU-__w                  nick-s-bistro-forest-hills
# 45  wPx4aNffBizdYmCG-WLKpQ                     loukoumi-taverna-queens
# 46  u2Uw0v1Rqepv0X6nOyICxA                 anassa-taverna-nyc-new-york
# 47  N2nwanXq9dDvKLIy7Ovb7g                   bahari-estiatorio-astoria
# 48  Bn1mZhb501Tvf7_-Pfi9_g                  korali-estiatorio-new-york
# 49  50ak4CXlbH7UoQlwI3FAAQ             stamna-greek-taverna-bloomfield
#
#                                    name  is_closed  \
# 0                       Village Taverna      False
# 1                                 Pylos      False
# 2                  Taverna East Village      False
# 3                         Snack Taverna      False
# 4                             The Greek      False
# 5                                  Kyma      False
# 6                    Mémé Mediterranean      False
# 7                                Kiki's      False
# 8                                Balade      False
# 9                      Avra 48th Street      False
# 10                          Souvlaki GR      False
# 11                          Souvlaki GR      False
# 12                                Shuka      False
# 13           taïm mediterranean kitchen      False
# 14                     ilili Restaurant      False
# 15                       Loi Estiatorio      False
# 16                                 Olea      False
# 17                              Eleni's      False
# 18                            Barbounia      False
# 19                    The Greek Kitchen      False
# 20                     Medusa The Greek      False
# 21                    A Taste of Greece      False
# 22                           yasouvlaki      False
# 23                         Avra Madison      False
# 24                   Mémé Mediterranean      False
# 25            Blue Door Seafood Taverna      False
# 26                      IRIS Restaurant      False
# 27                     Shoo Shoo Nolita      False
# 28         Avli The Little Greek Tavern      False
# 29  Estiatorio Milos - Midtown New York      False
# 30                  Avlee Greek Kitchen      False
# 31                              Agnanti      False
# 32                               Limani      False
# 33                         Elia Taverna      False
# 34                 Souvlaki GR Midtown       False
# 35                     Taverna Kyclades      False
# 36                                 Meze      False
# 37                               Aliada      False
# 38                  Ted's Corner Tavern      False
# 39         Athena Mediterranean Cuisine      False
# 40                                Amali      False
# 41                               Pappas      False
# 42                             Gazala's      False
# 43                      Astoria Seafood      False
# 44                        Nick’s Bistro      False
# 45                     Loukoumi Taverna      False
# 46                   Anassa Taverna NYC      False
# 47                    Bahari Estiatorio      False
# 48                    Korali Estiatorio      False
# 49                 Stamna Greek Taverna      False
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/village-taverna-new-y...           427     3.8
# 1   https://www.yelp.com/biz/pylos-new-york?adjust...          1282     4.3
# 2   https://www.yelp.com/biz/taverna-east-village-...          1009     4.1
# 3   https://www.yelp.com/biz/snack-taverna-new-yor...           389     3.8
# 4   https://www.yelp.com/biz/the-greek-new-york-2?...           556     4.3
# 5   https://www.yelp.com/biz/kyma-new-york?adjust_...           442     3.9
# 6   https://www.yelp.com/biz/m%C3%A9m%C3%A9-medite...           718     4.0
# 7   https://www.yelp.com/biz/kikis-new-york?adjust...           957     4.1
# 8   https://www.yelp.com/biz/balade-new-york?adjus...          1143     4.1
# 9   https://www.yelp.com/biz/avra-48th-street-new-...          1097     3.9
# 10  https://www.yelp.com/biz/souvlaki-gr-new-york-...          1015     3.9
# 11  https://www.yelp.com/biz/souvlaki-gr-new-york-...           260     4.4
# 12  https://www.yelp.com/biz/shuka-new-york-3?adju...          1160     4.3
# 13  https://www.yelp.com/biz/ta%C3%AFm-mediterrane...          1612     4.4
# 14  https://www.yelp.com/biz/ilili-restaurant-new-...          2882     4.1
# 15  https://www.yelp.com/biz/loi-estiatorio-new-yo...           517     4.7
# 16  https://www.yelp.com/biz/olea-brooklyn-2?adjus...          1069     4.2
# 17  https://www.yelp.com/biz/elenis-new-york-3?adj...           233     4.3
# 18  https://www.yelp.com/biz/barbounia-new-york?ad...          1544     3.7
# 19  https://www.yelp.com/biz/the-greek-kitchen-new...           674     3.9
# 20  https://www.yelp.com/biz/medusa-the-greek-broo...           319     4.4
# 21  https://www.yelp.com/biz/a-taste-of-greece-riv...           623     4.5
# 22  https://www.yelp.com/biz/yasouvlaki-new-york?a...           224     4.3
# 23  https://www.yelp.com/biz/avra-madison-new-york...           545     4.0
# 24  https://www.yelp.com/biz/m%C3%A9m%C3%A9-medite...           426     4.0
# 25  https://www.yelp.com/biz/blue-door-seafood-tav...           270     3.8
# 26  https://www.yelp.com/biz/iris-restaurant-new-y...           121     4.1
# 27  https://www.yelp.com/biz/shoo-shoo-nolita-new-...           334     4.1
# 28  https://www.yelp.com/biz/avli-the-little-greek...          1033     4.1
# 29  https://www.yelp.com/biz/estiatorio-milos-midt...          1144     4.0
# 30  https://www.yelp.com/biz/avlee-greek-kitchen-b...           323     4.3
# 31  https://www.yelp.com/biz/agnanti-astoria?adjus...           596     3.8
# 32  https://www.yelp.com/biz/limani-new-york?adjus...           581     3.8
# 33  https://www.yelp.com/biz/elia-taverna-bronxvil...           289     3.9
# 34  https://www.yelp.com/biz/souvlaki-gr-midtown-n...           884     4.0
# 35  https://www.yelp.com/biz/taverna-kyclades-asto...          2910     4.2
# 36  https://www.yelp.com/biz/meze-brooklyn-2?adjus...           390     4.2
# 37  https://www.yelp.com/biz/aliada-astoria?adjust...           527     4.1
# 38  https://www.yelp.com/biz/teds-corner-tavern-ne...           252     4.3
# 39  https://www.yelp.com/biz/athena-mediterranean-...           463     4.4
# 40  https://www.yelp.com/biz/amali-new-york-3?adju...           537     3.9
# 41  https://www.yelp.com/biz/pappas-new-york-2?adj...           113     3.3
# 42  https://www.yelp.com/biz/gazalas-new-york-26?a...           194     4.2
# 43  https://www.yelp.com/biz/astoria-seafood-long-...          1027     4.0
# 44  https://www.yelp.com/biz/nick-s-bistro-forest-...           887     4.4
# 45  https://www.yelp.com/biz/loukoumi-taverna-quee...           596     4.3
# 46  https://www.yelp.com/biz/anassa-taverna-nyc-ne...           467     3.5
# 47  https://www.yelp.com/biz/bahari-estiatorio-ast...           705     4.1
# 48  https://www.yelp.com/biz/korali-estiatorio-new...           277     4.0
# 49  https://www.yelp.com/biz/stamna-greek-taverna-...           506     4.1
#
#    price         phone   display_phone      distance  coordinates.latitude  \
# 0     $$  +12129823457  (212) 982-3457   3109.402110             40.733390
# 1    $$$  +12124730220  (212) 473-0220   2448.996903             40.726080
# 2    $$$  +12124320011  (212) 432-0011   3007.651040             40.730974
# 3     $$  +12129293499  (212) 929-3499   2980.351520             40.731033
# 4    $$$  +16464763941  (646) 476-3941   2473.613193             40.724000
# 5    $$$  +12122685555  (212) 268-5555   3748.622094             40.739040
# 6     $$  +16466928450  (646) 692-8450   3585.669092             40.736412
# 7     $$  +16468827052  (646) 882-7052   1027.330009             40.714497
# 8     $$  +12125296868  (212) 529-6868   2920.724550             40.730289
# 9    $$$  +12127598550  (212) 759-8550   5814.968475             40.755049
# 10    $$  +12127770116  (212) 777-0116   1853.914240             40.721196
# 11    $$  +12128320395  (212) 832-0395   6172.961660             40.757250
# 12    $$  +12124757500  (212) 475-7500   2508.144656             40.727070
# 13    $$  +12126911287  (212) 691-1287   3458.703393             40.736002
# 14   $$$  +12126832929  (212) 683-2929   4365.754290             40.744350
# 15   $$$  +12127130015  (212) 713-0015   6804.906661             40.765385
# 16    $$  +17186437003  (718) 643-7003   2796.956021             40.687784
# 17   $$$  +12129829030  (212) 982-9030   3550.440699             40.736601
# 18   $$$  +12129950242  (212) 995-0242   3693.731058             40.738326
# 19    $$  +12125814300  (212) 581-4300   7170.641099             40.769761
# 20    $$  +13475990749  (347) 599-0749   3266.984226             40.678570
# 21    $$  +12019670029  (201) 967-0029  26280.829997             40.940180
# 22    $$  +19295511010  (929) 551-1010   9017.228544             40.780300
# 23  $$$$  +12129370100  (212) 937-0100   6814.558070             40.764300
# 24   $$$  +19172620827  (917) 262-0827   6169.037037             40.760929
# 25    $$  +17186808600  (718) 680-8600   9491.271303             40.624602
# 26   NaN  +12129701740  (212) 970-1740   6721.991799             40.764981
# 27   $$$  +16465906800  (646) 590-6800   1632.387824             40.720150
# 28    $$  +17182247575  (718) 224-7575  19904.651740             40.765745
# 29  $$$$  +12122457400  (212) 245-7400   6586.931699             40.763542
# 30    $$  +17188555125  (718) 855-5125   2839.662544             40.679911
# 31    $$  +17185454554  (718) 545-4554  10582.859511             40.780979
# 32   $$$  +12128589200  (212) 858-9200   6156.051468             40.759381
# 33    $$  +19146634976  (914) 663-4976  29295.735359             40.928312
# 34    $$  +12129747482  (212) 974-7482   6683.919028             40.764650
# 35   $$$  +17185458666  (718) 545-8666  10578.710613             40.774440
# 36    $$  +17182346393  (718) 234-6393   8949.272441             40.625230
# 37    $$  +17189322240  (718) 932-2240   8557.109282             40.762540
# 38    $$  +12126892676  (212) 689-2676   4748.589937             40.746200
# 39    $$  +17189654578  (718) 965-4578   4565.933230             40.664760
# 40   $$$  +12123398363  (212) 339-8363   6792.746364             40.763356
# 41   $$$  +16464102911  (646) 410-2911   2759.663943             40.729710
# 42   NaN  +12127871800  (212) 787-1800   8924.739689             40.784580
# 43   $$$  +17183922680  (718) 392-2680   7657.624764             40.754000
# 44    $$  +17185446425  (718) 544-6425  12315.529805             40.709937
# 45    $$  +17186263200  (718) 626-3200  10597.322803             40.770796
# 46   $$$  +12123715200  (212) 371-5200   6727.289328             40.762037
# 47    $$  +17182048968  (718) 204-8968   8555.675351             40.761645
# 48   $$$  +16469645470  (646) 964-5470   9414.430074             40.783490
# 49    $$  +19733385151  (973) 338-5151  21183.726845             40.828030
#
#     coordinates.longitude        location.address1     location.city  \
# 0              -73.993060         81 University Pl          New York
# 1              -73.984150             128 E 7th St          New York
# 2              -73.982503              228 1st Ave          New York
# 3              -74.004814            63 Bedford St          New York
# 4              -74.010502        452 Washington St          New York
# 5              -73.992830             15 W 18th St          New York
# 6              -74.006160            581 Hudson St          New York
# 7              -73.991855          130 Division St          New York
# 8              -73.983042              208 1st Ave          New York
# 9              -73.972439            141 E 48th St          New York
# 10             -73.987118           116 Stanton St          New York
# 11             -73.968080            231 E 53rd St          New York
# 12             -74.002830          38 MacDougal St          New York
# 13             -74.001959           222 Waverly Pl          New York
# 14             -73.987780              236 5th Ave          New York
# 15             -73.978002            132 W 58th St          New York
# 16             -73.970605        171 Lafayette Ave          Brooklyn
# 17             -73.985085              226 3rd Ave          New York
# 18             -73.988065           250 Park Ave S          New York
# 19             -73.988106             889 10th Ave          New York
# 20             -73.978850              133 5th Ave          Brooklyn
# 21             -74.030735      935 Kinderkamack Rd        River Edge
# 22             -73.953120             1568 3rd Ave          New York
# 23             -73.971721             14 E 60th St          New York
# 24             -73.994827             607 10th Ave          New York
# 25             -74.030350             8413 3rd Ave          Brooklyn
# 26             -73.981702            1740 Broadway          New York
# 27             -73.996230            371 Broome St          New York
# 28             -73.771859          38-31 Bell Blvd           Bayside
# 29             -73.979025            125 W 55th St          New York
# 30             -73.994879             349 Smith St          Brooklyn
# 31             -73.917908       19-06 Ditmars Blvd           Astoria
# 32             -73.977814      45 Rockerfeller Plz          New York
# 33             -73.808630      502 New Rochelle Rd        Bronxville
# 34             -73.980290            162 W 56th St          New York
# 35             -73.907860        3601 Ditmars Blvd           Astoria
# 36             -74.002110            6601 13th Ave          Brooklyn
# 37             -73.926199            2919 Broadway           Astoria
# 38             -73.977460              523 3rd Ave          New York
# 39             -73.986480              535 6th Ave          Brooklyn
# 40             -73.968630            115 E 60th St          New York
# 41             -74.000870         103 Macdougal St          New York
# 42             -73.977060        447 Amsterdam Ave          New York
# 43             -73.929870            37-10 33rd St  Long Island City
# 44             -73.848306  104-20 Metropolitan Ave      Forest Hills
# 45             -73.902741       45-07 Ditmars Blvd            Queens
# 46             -73.966063            200 E 60th St          New York
# 47             -73.924939            3114 Broadway           Astoria
# 48             -73.950980             1662 3rd Ave          New York
# 49             -74.186770            1055 Broad St        Bloomfield
#
#    location.zip_code location.country location.state
# 0              10003               US             NY
# 1              10009               US             NY
# 2              10009               US             NY
# 3              10014               US             NY
# 4              10013               US             NY
# 5              10011               US             NY
# 6              10014               US             NY
# 7              10002               US             NY
# 8              10009               US             NY
# 9              10017               US             NY
# 10             10002               US             NY
# 11             10022               US             NY
# 12             10012               US             NY
# 13             10014               US             NY
# 14             10001               US             NY
# 15             10019               US             NY
# 16             11238               US             NY
# 17             10003               US             NY
# 18             10003               US             NY
# 19             10019               US             NY
# 20             11217               US             NY
# 21             07661               US             NJ
# 22             10128               US             NY
# 23             10022               US             NY
# 24             10036               US             NY
# 25             11209               US             NY
# 26             10019               US             NY
# 27             10013               US             NY
# 28             11361               US             NY
# 29             10019               US             NY
# 30             11231               US             NY
# 31             11105               US             NY
# 32             10111               US             NY
# 33             10708               US             NY
# 34             10019               US             NY
# 35             11105               US             NY
# 36             11219               US             NY
# 37             11106               US             NY
# 38             10016               US             NY
# 39             11215               US             NY
# 40             10022               US             NY
# 41             10012               US             NY
# 42             10024               US             NY
# 43             10016               US             NY
# 44             11375               US             NY
# 45             11101               US             NY
# 46             10022               US             NY
# 47             11106               US             NY
# 48             10128               US             NY
# 49             07003               US             NJ
