# %% [markdown]
# <a href="https://colab.research.google.com/github/mb8655/Python/blob/main/Inserting_Data_in_MySQL_using_PythonPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Inserting and Reading data from MySQL using Pandas
# First let's start with a basic piece of code that fetches the data that we want to insert in the database. For our example, we will get the data about the Citibike stations, using the correspoding API call provided by the Citibike website:

# %%
# !pip install -U -q PyMySQL sqlalchemy

import requests
import pandas as pd
import sqlalchemy

# %%
# Let's get the data from the Citibike API

# This gives information for each station that remains stable over time
url_stations = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"
# This gives the live status of all the stations (e.g., bikes available etc)
url_status = "https://gbfs.citibikenyc.com/gbfs/en/station_status.json"

# We fetch for now just the time-invariant data
results = requests.get(url_stations).json()
results
# Out:
# {'data': {'stations': [{'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1817822909864556798',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91274864321404,
#     'station_id': '1817822909864556798',
#     'short_name': '7082.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.77423301703027,
#     'has_kiosk': True,
#     'name': '23 Ave & 31 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '823ef531-40e6-4397-b973-86bf5b032076',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.93679,
#     'station_id': '823ef531-40e6-4397-b973-86bf5b032076',
#     'short_name': '3862.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.66929,
#     'has_kiosk': True,
#     'name': 'Eastern Pkwy & Troy Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'b4974d89-932c-4a9f-a264-2ea0cf70613e',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.937878,
#     'station_id': 'b4974d89-932c-4a9f-a264-2ea0cf70613e',
#     'short_name': '8458.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.855331,
#     'has_kiosk': True,
#     'name': 'Pinehurst Ave & W 187 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1786700154621508184',
#     'capacity': 29,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94395,
#     'station_id': '1786700154621508184',
#     'short_name': '5656.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7277,
#     'has_kiosk': True,
#     'name': 'N Henry St & Norman Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 78,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.986923,
#     'station_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '5863.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.734232,
#     'has_kiosk': True,
#     'name': 'E 15 St & 3 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '99614ecb-2329-49fa-a13a-fa1ef2bb32d6',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90549,
#     'station_id': '99614ecb-2329-49fa-a13a-fa1ef2bb32d6',
#     'short_name': '8225.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.83999,
#     'has_kiosk': True,
#     'name': 'Clay Ave & Claremont Pkwy'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'ca843847-923a-40b7-80ca-c1c3fff6e818',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.916082,
#     'station_id': 'ca843847-923a-40b7-80ca-c1c3fff6e818',
#     'short_name': '8344.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.848177,
#     'has_kiosk': True,
#     'name': 'Macombs Rd & W 175 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1848241684520917882',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.86781,
#     'station_id': '1848241684520917882',
#     'short_name': '6231.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74399,
#     'has_kiosk': True,
#     'name': '46 Ave & Junction Blvd'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1096fc76-794e-4343-8eb0-0dd6c9a48266',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.88459,
#     'station_id': '1096fc76-794e-4343-8eb0-0dd6c9a48266',
#     'short_name': '8717.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.87207,
#     'has_kiosk': True,
#     'name': 'E 201 St & Briggs Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1817432434869846072',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.95218,
#     'station_id': '1817432434869846072',
#     'short_name': '3286.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.64871,
#     'has_kiosk': True,
#     'name': 'Rogers Ave & Snyder Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '92fc1ad7-0867-4655-b02f-ede65d336b14',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.909831,
#     'station_id': '92fc1ad7-0867-4655-b02f-ede65d336b14',
#     'short_name': '6662.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.758057,
#     'has_kiosk': True,
#     'name': '49 St & 31 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '038b7369-9c6e-4eb2-8569-f7461443302f',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9008,
#     'station_id': '038b7369-9c6e-4eb2-8569-f7461443302f',
#     'short_name': '4120.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.67709,
#     'has_kiosk': True,
#     'name': 'Fulton St & Williams Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '180b83a0-329c-4069-87be-df862cb1baed',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.981073,
#     'station_id': '180b83a0-329c-4069-87be-df862cb1baed',
#     'short_name': '3007.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.642031,
#     'has_kiosk': True,
#     'name': 'Church Ave & Story St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'f833d403-2cf5-424a-a3b3-0314a44b4a67',
#     'capacity': 33,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98672603070736,
#     'station_id': 'f833d403-2cf5-424a-a3b3-0314a44b4a67',
#     'short_name': '5190.09',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.711471394469264,
#     'has_kiosk': True,
#     'name': 'Clinton St & Cherry St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'ca5cc034-a95d-446e-8314-6691589886b1',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90198,
#     'station_id': 'ca5cc034-a95d-446e-8314-6691589886b1',
#     'short_name': '5321.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.71693,
#     'has_kiosk': True,
#     'name': '60 Ave & Fresh Pond Rd'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'fda18503-7488-4b91-b74c-949a90401e83',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.92737478017807,
#     'station_id': 'fda18503-7488-4b91-b74c-949a90401e83',
#     'short_name': '6025.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.73824937345944,
#     'has_kiosk': True,
#     'name': '39 St & 50 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'a2ef8ed2-6031-4049-b7dc-9838ef39889b',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.897263,
#     'station_id': 'a2ef8ed2-6031-4049-b7dc-9838ef39889b',
#     'short_name': '7888.10',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.819999,
#     'has_kiosk': True,
#     'name': 'Dawson St & Intervale Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1828965172312150882',
#     'capacity': 22,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94635,
#     'station_id': '1828965172312150882',
#     'short_name': '3246.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.64868,
#     'has_kiosk': True,
#     'name': 'New York Ave & Snyder Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'eb07bdfc-3a6f-40eb-96d2-0b92ac371619',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94514,
#     'station_id': 'eb07bdfc-3a6f-40eb-96d2-0b92ac371619',
#     'short_name': '3871.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.66939,
#     'has_kiosk': True,
#     'name': 'Eastern Pkwy & Brooklyn Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1869753654337059182',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91099,
#     'station_id': '1869753654337059182',
#     'short_name': '8745.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.87471,
#     'has_kiosk': True,
#     'name': 'Marble Hill Ave & W 225 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1950648049868542106',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.892452880543,
#     'station_id': '1950648049868542106',
#     'short_name': '8582.10',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.86415477605928,
#     'has_kiosk': True,
#     'name': 'Bainbridge Ave & E 193 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '2546c9b9-5b1a-4e9f-a9cc-f8b986b79748',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.932173,
#     'station_id': '2546c9b9-5b1a-4e9f-a9cc-f8b986b79748',
#     'short_name': '8511.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.857994,
#     'has_kiosk': True,
#     'name': 'Broadway & W 192 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '0dd71c6d-11ee-4ad4-ba99-36b9ad36112c',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91387,
#     'station_id': '0dd71c6d-11ee-4ad4-ba99-36b9ad36112c',
#     'short_name': '4023.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.67313,
#     'has_kiosk': True,
#     'name': 'St Marks Ave & Thomas S. Boyland St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1851254468343716806',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.85614,
#     'station_id': '1851254468343716806',
#     'short_name': '5945.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.73715,
#     'has_kiosk': True,
#     'name': '60 Ave & Otis Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'ed279ef2-52ee-4ff2-9a52-edd8137ea034',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.92103672027588,
#     'station_id': 'ed279ef2-52ee-4ff2-9a52-edd8137ea034',
#     'short_name': '6134.13',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.741119944681465,
#     'has_kiosk': True,
#     'name': '44 St & Greenpoint Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1851674198082642572',
#     'capacity': 22,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.84978,
#     'station_id': '1851674198082642572',
#     'short_name': '6053.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7408,
#     'has_kiosk': True,
#     'name': 'Corona Ave & 111 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '33840944-aa92-4d91-9de8-d29e5cd0b2d9',
#     'capacity': 33,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.99127773940563,
#     'station_id': '33840944-aa92-4d91-9de8-d29e5cd0b2d9',
#     'short_name': '4371.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.685424009970184,
#     'has_kiosk': True,
#     'name': 'Warren St & Smith St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1846085439406916338',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.8882,
#     'station_id': '1846085439406916338',
#     'short_name': '6290.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74557,
#     'has_kiosk': True,
#     'name': '41 Ave & 77 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '9394fb49-583f-4426-8d2f-a2b0ffb584d2',
#     'capacity': 49,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.986274,
#     'station_id': '9394fb49-583f-4426-8d2f-a2b0ffb584d2',
#     'short_name': '5445.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.720747,
#     'has_kiosk': True,
#     'name': 'Stanton St & Norfolk St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'fbaffdbd-dab5-4127-9bd5-36bf58093ea8',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91855701804161,
#     'station_id': 'fbaffdbd-dab5-4127-9bd5-36bf58093ea8',
#     'short_name': '8559.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.86169883507865,
#     'has_kiosk': True,
#     'name': '9 Ave & W 204 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '7779e057-b33e-46a7-8a1e-8c28bcd9a558',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91493,
#     'station_id': '7779e057-b33e-46a7-8a1e-8c28bcd9a558',
#     'short_name': '4325.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.68491,
#     'has_kiosk': True,
#     'name': 'Thomas S. Boyland St & Macon St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1859438049977968878',
#     'capacity': 31,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94510813442648,
#     'station_id': '1859438049977968878',
#     'short_name': '8123.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.83402740143528,
#     'has_kiosk': True,
#     'name': 'Broadway & W 157 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1862008701134683118',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.88953,
#     'station_id': '1862008701134683118',
#     'short_name': '8430.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.85307,
#     'has_kiosk': True,
#     'name': 'Arthur Ave & E 183 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dc6a86-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 79,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98602213,
#     'station_id': '66dc6a86-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '6131.1',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74096374,
#     'has_kiosk': True,
#     'name': 'E 24 St & Park Ave S'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1828966626550010820',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.89081,
#     'station_id': '1828966626550010820',
#     'short_name': '6718.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.75886,
#     'has_kiosk': True,
#     'name': '77 St & 31 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1794852638057746848',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90321,
#     'station_id': '1794852638057746848',
#     'short_name': '5611.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.72655,
#     'has_kiosk': True,
#     'name': '63 St & Borden Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'f34ea09d-32f9-492c-9124-99059bc0b5dd',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.899558,
#     'station_id': 'f34ea09d-32f9-492c-9124-99059bc0b5dd',
#     'short_name': '7220.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.778089,
#     'has_kiosk': True,
#     'name': 'Steinway St & 19 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'c80c55c4-d623-42d7-8acf-6bfa68a84ecb',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.905158,
#     'station_id': 'c80c55c4-d623-42d7-8acf-6bfa68a84ecb',
#     'short_name': '8103.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.832678,
#     'has_kiosk': True,
#     'name': '3 Ave & E 169 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'c2bb1874-bcb7-47c5-aa7d-05423b9087e8',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94763,
#     'station_id': 'c2bb1874-bcb7-47c5-aa7d-05423b9087e8',
#     'short_name': '3984.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.67234,
#     'has_kiosk': True,
#     'name': 'Sterling Pl & New York Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '493850bd-125b-49f5-932b-bf999504fb06',
#     'capacity': 18,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.907521,
#     'station_id': '493850bd-125b-49f5-932b-bf999504fb06',
#     'short_name': '7952.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.82188,
#     'has_kiosk': True,
#     'name': 'Cauldwell Ave & E 161 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '6fd61eee-d0ef-4580-9704-bd06b82bcb61',
#     'capacity': 33,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.972628,
#     'station_id': '6fd61eee-d0ef-4580-9704-bd06b82bcb61',
#     'short_name': '6732.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.761573,
#     'has_kiosk': True,
#     'name': 'E 56 St & Madison Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1814548067447122618',
#     'capacity': 35,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.95863,
#     'station_id': '1814548067447122618',
#     'short_name': '5676.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.72693,
#     'has_kiosk': True,
#     'name': 'Calyer St & West St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1834145589124844432',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.87509,
#     'station_id': '1834145589124844432',
#     'short_name': '6433.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.75085,
#     'has_kiosk': True,
#     'name': '92 St & 37 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'a3d72b5b-9587-4f33-9722-c01e20a9b358',
#     'capacity': 29,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.92825,
#     'station_id': 'a3d72b5b-9587-4f33-9722-c01e20a9b358',
#     'short_name': '4680.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.69502,
#     'has_kiosk': True,
#     'name': 'Bushwick Ave & Dekalb Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '2637fed8-1e2a-460b-83eb-3eb32ace0f4e',
#     'capacity': 50,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98255586624146,
#     'station_id': '2637fed8-1e2a-460b-83eb-3eb32ace0f4e',
#     'short_name': '6398.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74848023448579,
#     'has_kiosk': True,
#     'name': 'E 35 St & Madison Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '7aa86431-bbc5-4d9c-8198-9630c9d32a22',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.984276,
#     'station_id': '7aa86431-bbc5-4d9c-8198-9630c9d32a22',
#     'short_name': '3135.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.644367,
#     'has_kiosk': True,
#     'name': 'Chester Ave & 12 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '6d766daf-9298-4059-a329-1818582d495f',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.94093804061413,
#     'station_id': '6d766daf-9298-4059-a329-1818582d495f',
#     'short_name': '6001.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.73866345465306,
#     'has_kiosk': True,
#     'name': 'Borden Ave & Review Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1840540852548303628',
#     'capacity': 18,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.86483,
#     'station_id': '1840540852548303628',
#     'short_name': '6869.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.76521,
#     'has_kiosk': True,
#     'name': 'Butler St & 27 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '8aad788d-c7eb-4fca-a426-c39f47741a6f',
#     'capacity': 28,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9505,
#     'station_id': '8aad788d-c7eb-4fca-a426-c39f47741a6f',
#     'short_name': '3839.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.66811,
#     'has_kiosk': True,
#     'name': 'President St & Nostrand Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1862788202397235246',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90467,
#     'station_id': '1862788202397235246',
#     'short_name': '8741.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.87449,
#     'has_kiosk': True,
#     'name': 'Bailey Ave & W 229 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1871698223344654662',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.961241,
#     'station_id': '1871698223344654662',
#     'short_name': '5053.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.706732,
#     'has_kiosk': True,
#     'name': 'Lee Ave & Taylor St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '053312f2-e77e-4674-b28b-ad357fbcb4ee',
#     'capacity': 65,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98655101656914,
#     'station_id': '053312f2-e77e-4674-b28b-ad357fbcb4ee',
#     'short_name': '6747.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.76171227910671,
#     'has_kiosk': True,
#     'name': '8 Ave & W 49 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1786697771181570266',
#     'capacity': 45,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.96594,
#     'station_id': '1786697771181570266',
#     'short_name': '5388.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.716425,
#     'has_kiosk': True,
#     'name': 'Kent Ave & Grand St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'd265dbc7-ef55-4f5b-8a2b-f2015dc71fb8',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9321455,
#     'station_id': 'd265dbc7-ef55-4f5b-8a2b-f2015dc71fb8',
#     'short_name': '6688.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7596276,
#     'has_kiosk': True,
#     'name': 'Crescent St & 35 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '64f0f28c-bedc-42d5-b107-ecdd48fc30cd',
#     'capacity': 103,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98486793041229,
#     'station_id': '64f0f28c-bedc-42d5-b107-ecdd48fc30cd',
#     'short_name': '6708.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.76017739537783,
#     'has_kiosk': True,
#     'name': 'Broadway & W 48 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '525535e3-dde3-47b4-9c2e-0174eaa4f2bb',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90417,
#     'station_id': '525535e3-dde3-47b4-9c2e-0174eaa4f2bb',
#     'short_name': '5611.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.72558,
#     'has_kiosk': True,
#     'name': '61 St & Borden Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1860188747953293684',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.88426,
#     'station_id': '1860188747953293684',
#     'short_name': '8325.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.84605,
#     'has_kiosk': True,
#     'name': 'Southern Blvd & E 180 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'a2cf5872-bd4c-4311-832e-d62fd779ecc3',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.95968,
#     'station_id': 'a2cf5872-bd4c-4311-832e-d62fd779ecc3',
#     'short_name': '3480.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.65563,
#     'has_kiosk': True,
#     'name': 'Parkside Ave & Flatbush Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '0fde06c2-632c-46a9-8866-f4e855604f74',
#     'capacity': 68,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98734897375107,
#     'station_id': '0fde06c2-632c-46a9-8866-f4e855604f74',
#     'short_name': '6560.15',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7529728216068,
#     'has_kiosk': True,
#     'name': 'Broadway & W 38 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '38af3d1a-9916-46cf-b22e-86fc8648bf30',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.915585,
#     'station_id': '38af3d1a-9916-46cf-b22e-86fc8648bf30',
#     'short_name': '8016.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.825716,
#     'has_kiosk': True,
#     'name': 'Park Ave & E 162 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1840504138040045682',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.87535,
#     'station_id': '1840504138040045682',
#     'short_name': '6701.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.75874,
#     'has_kiosk': True,
#     'name': 'Jackson Mill Rd & 93 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dc8a3d-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 79,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98409214,
#     'station_id': '66dc8a3d-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '6089.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74025878,
#     'has_kiosk': True,
#     'name': 'Lexington Ave & E 24 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'bcb08532-f0d5-4c0e-ad8a-4ddacc204791',
#     'capacity': 18,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91693,
#     'station_id': 'bcb08532-f0d5-4c0e-ad8a-4ddacc204791',
#     'short_name': '4560.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.69122,
#     'has_kiosk': True,
#     'name': 'Madison St & Evergreen Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '69f84045-48f9-4c6c-90d3-0503e5ed39e9',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.96579,
#     'station_id': '69f84045-48f9-4c6c-90d3-0503e5ed39e9',
#     'short_name': '4116.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.6769694,
#     'has_kiosk': True,
#     'name': 'Prospect Pl & Underhill Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '640a9a95-194f-42f5-8d88-1df67129f388',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.902185,
#     'station_id': '640a9a95-194f-42f5-8d88-1df67129f388',
#     'short_name': '8171.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.837119,
#     'has_kiosk': True,
#     'name': 'E 171 St & 3 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1838070843306263244',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.85763,
#     'station_id': '1838070843306263244',
#     'short_name': '6683.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.75788,
#     'has_kiosk': True,
#     'name': '112 St & Northern Blvd'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66de6346-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 35,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98901629,
#     'station_id': '66de6346-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4330.09',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.6843549,
#     'has_kiosk': True,
#     'name': 'Hoyt St & Warren St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'b4f990dd-36bb-46b3-9eea-4b980bd43c2d',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90108,
#     'station_id': 'b4f990dd-36bb-46b3-9eea-4b980bd43c2d',
#     'short_name': '8586.09',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.86294,
#     'has_kiosk': True,
#     'name': 'Jerome Ave & W Fordham Rd'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'ff745407-c087-4c0d-a965-98baf078f292',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.90128,
#     'station_id': 'ff745407-c087-4c0d-a965-98baf078f292',
#     'short_name': '5392.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.71832,
#     'has_kiosk': True,
#     'name': '63 St & 59 Dr'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '00967b8f-1a4d-4131-a65a-17fa8ca89e28',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.89764,
#     'station_id': '00967b8f-1a4d-4131-a65a-17fa8ca89e28',
#     'short_name': '6225.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74446,
#     'has_kiosk': True,
#     'name': '41 Ave & 67 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dd1f44-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.95394,
#     'station_id': '66dd1f44-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '5785.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.73026,
#     'has_kiosk': True,
#     'name': 'Greenpoint Ave & Manhattan Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '3e1bdcec-e762-4e83-b447-007f05923cce',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9225403,
#     'station_id': '3e1bdcec-e762-4e83-b447-007f05923cce',
#     'short_name': '7186.15',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7774552,
#     'has_kiosk': True,
#     'name': '19 St & 24 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 37,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.99548059,
#     'station_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4829.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.70037867,
#     'has_kiosk': True,
#     'name': 'Columbia Heights & Cranberry St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '62b97c1e-9d06-4c5e-b9c3-d76099e37fe4',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.96902144,
#     'station_id': '62b97c1e-9d06-4c5e-b9c3-d76099e37fe4',
#     'short_name': '4157.15',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.67767534,
#     'has_kiosk': True,
#     'name': 'Prospect Pl & Vanderbilt Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dbef15-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 37,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9999786,
#     'station_id': '66dbef15-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4614.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.69165183,
#     'has_kiosk': True,
#     'name': 'Atlantic Ave & Furman St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dd24ca-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 47,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.93540375,
#     'station_id': '66dd24ca-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '6227.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.74469738,
#     'has_kiosk': True,
#     'name': '31 St & Thomson Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'e85c3165-ad0a-44a3-9683-d8cf7575f465',
#     'capacity': 30,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.97058,
#     'station_id': 'e85c3165-ad0a-44a3-9683-d8cf7575f465',
#     'short_name': '3230.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.648481,
#     'has_kiosk': True,
#     'name': 'Caton Ave & E 10 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '83a5d761-57d0-4cd6-aa2b-7eb350120d99',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.886659,
#     'station_id': '83a5d761-57d0-4cd6-aa2b-7eb350120d99',
#     'short_name': '8020.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.827629,
#     'has_kiosk': True,
#     'name': 'Home St & Westchester Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1876800925490112950',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.89322,
#     'station_id': '1876800925490112950',
#     'short_name': '8293.12',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.84616,
#     'has_kiosk': True,
#     'name': 'Arthur Ave & E Tremont Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'b4a320d6-2611-4940-96ca-17fb297ec826',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.91906,
# ...
#     'lat': 40.75614,
#     'has_kiosk': True,
#     'name': '34 Ave & 108 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '04d557d6-6bc3-4244-b0f1-81ed1449ccd6',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.89192,
#     'station_id': '04d557d6-6bc3-4244-b0f1-81ed1449ccd6',
#     'short_name': '8799.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.87812,
#     'has_kiosk': True,
#     'name': 'Goulden Ave & W 205 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66db88f5-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 39,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98631746,
#     'station_id': '66db88f5-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4596.09',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.69236178,
#     'has_kiosk': True,
#     'name': 'Lawrence St & Willoughby St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '063e7e78-b810-4a2f-8045-a82a0d69d752',
#     'capacity': 45,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.99067759513855,
#     'station_id': '063e7e78-b810-4a2f-8045-a82a0d69d752',
#     'short_name': '5343.11',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.717318403855785,
#     'has_kiosk': True,
#     'name': 'Orchard St & Grand St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dbeded-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 25,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9557689392,
#     'station_id': '66dbeded-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4222.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.680342423,
#     'has_kiosk': True,
#     'name': 'Lefferts Pl & Franklin Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '5780ae63-54e5-48e3-a00c-9c403cb75401',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -74.007168,
#     'station_id': '5780ae63-54e5-48e3-a00c-9c403cb75401',
#     'short_name': '3347.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.651354,
#     'has_kiosk': True,
#     'name': '41 St & 4 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1786375069262703476',
#     'capacity': 31,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.950815,
#     'station_id': '1786375069262703476',
#     'short_name': '5666.11',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.725819,
#     'has_kiosk': True,
#     'name': 'Norman Ave & Leonard St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1923987214021052830',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.905986,
#     'station_id': '1923987214021052830',
#     'short_name': '6234.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.744577,
#     'has_kiosk': True,
#     'name': '59 St & 41 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'd33261e6-600e-4756-ad03-a9facbd8ace1',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.93172398209572,
#     'station_id': 'd33261e6-600e-4756-ad03-a9facbd8ace1',
#     'short_name': '6185.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7443653191867,
#     'has_kiosk': True,
#     'name': '33 St & Queens Blvd'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '285ad3c2-3ffe-45bb-8765-9c20a69641a6',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.9342,
#     'station_id': '285ad3c2-3ffe-45bb-8765-9c20a69641a6',
#     'short_name': '7132.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.77485,
#     'has_kiosk': True,
#     'name': '27 Ave & 3 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66ddee56-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.99917254,
#     'station_id': '66ddee56-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4380.08',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.6847514,
#     'has_kiosk': True,
#     'name': 'Henry St & Degraw St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '5736cd70-be41-483e-8d82-721874f40e6e',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.93896,
#     'station_id': '5736cd70-be41-483e-8d82-721874f40e6e',
#     'short_name': '3975.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.67297,
#     'has_kiosk': True,
#     'name': 'Albany Ave & Park Pl'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1835247196073118026',
#     'capacity': 20,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.87587,
#     'station_id': '1835247196073118026',
#     'short_name': '6978.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.7702,
#     'has_kiosk': True,
#     'name': 'Ditmars Blvd & 94 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66de482a-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 19,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -74.00785041,
#     'station_id': '66de482a-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4202.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.6794327,
#     'has_kiosk': True,
#     'name': 'Richards St & Delavan St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '0dc63044-e19c-474d-9df1-c3e504d03b07',
#     'capacity': 48,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.97455215454102,
#     'station_id': '0dc63044-e19c-474d-9df1-c3e504d03b07',
#     'short_name': '5769.06',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.72984830346529,
#     'has_kiosk': True,
#     'name': 'Ave C & E 16 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dd1585-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 39,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.95242,
#     'station_id': '66dd1585-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '5411.07',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.71924,
#     'has_kiosk': True,
#     'name': 'Union Ave & N 12 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1846086665080867236',
#     'capacity': 21,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.86012,
#     'station_id': '1846086665080867236',
#     'short_name': '6105.02',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.73988,
#     'has_kiosk': True,
#     'name': '100 St & Lewis Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'e8df73bd-5d3d-47c9-b04d-bcec4db5540f',
#     'capacity': 65,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -74.00495,
#     'station_id': 'e8df73bd-5d3d-47c9-b04d-bcec4db5540f',
#     'short_name': '5065.14',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.70838,
#     'has_kiosk': True,
#     'name': 'Cliff St & Fulton St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '1885439359712500016',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.8985,
#     'station_id': '1885439359712500016',
#     'short_name': '8531.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.85941,
#     'has_kiosk': True,
#     'name': 'Grand Concourse & E 184 St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '90c35466-db3c-4b0d-993e-6e92883773b4',
#     'capacity': 72,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -74.00473,
#     'station_id': '90c35466-db3c-4b0d-993e-6e92883773b4',
#     'short_name': '5610.09',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.72431,
#     'has_kiosk': True,
#     'name': '6 Ave & Broome St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 33,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.99724900722504,
#     'station_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '5492.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.722103786686034,
#     'has_kiosk': True,
#     'name': 'Cleveland Pl & Spring St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '7a725e59-49be-4c1d-9c3d-3b3a8ed1232f',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.907107,
#     'station_id': '7a725e59-49be-4c1d-9c3d-3b3a8ed1232f',
#     'short_name': '6735.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.760083,
#     'has_kiosk': True,
#     'name': '50 St & 30 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': 'de6f4206-3aa9-4cb9-aae0-8547d2cd6854',
#     'capacity': 23,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.93581,
#     'station_id': 'de6f4206-3aa9-4cb9-aae0-8547d2cd6854',
#     'short_name': '5099.03',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.707174,
#     'has_kiosk': True,
#     'name': 'White St & Johnson Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dea894-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 49,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -74.01122331619263,
#     'station_id': '66dea894-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '5288.12',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.714851505262516,
#     'has_kiosk': True,
#     'name': 'Murray St & Greenwich St'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66de8a86-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 59,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.97982001304626,
#     'station_id': '66de8a86-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '6740.01',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.76132983124814,
#     'has_kiosk': True,
#     'name': 'W 52 St & 6 Ave'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '66dbc60f-0aca-11e7-82f6-3863bb44ef7c',
#     'capacity': 27,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.97431458,
#     'station_id': '66dbc60f-0aca-11e7-82f6-3863bb44ef7c',
#     'short_name': '4354.05',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.68539567,
#     'has_kiosk': True,
#     'name': 'S Portland Ave & Hanson Pl'},
#    {'region_id': '71',
#     'eightd_station_services': [],
#     'external_id': '993fc83f-52c6-43f4-bb49-4abe4ad48150',
#     'capacity': 24,
#     'station_type': 'classic',
#     'eightd_has_key_dispenser': False,
#     'lon': -73.98013919591904,
#     'station_id': '993fc83f-52c6-43f4-bb49-4abe4ad48150',
#     'short_name': '3579.04',
#     'electric_bike_surcharge_waiver': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'rental_uris': {'android': 'https://bkn.lft.to/lastmile_qr_scan',
#      'ios': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'lat': 40.659490558938955,
#     'has_kiosk': True,
#     'name': 'Windsor Pl & Howard Pl'},
#    ...]},
#  'last_updated': 1741824763,
#  'ttl': 60,
#  'version': '1.1'}

# %%
# We only need a subset of the data in the JSON returned by the Citibike API, so we keep only what we need
data = results["data"]["stations"]
len(data)
# Out:
# 2233

# %%
df = pd.DataFrame(data)
df.head(5)
# Out:
#   region_id eightd_station_services                           external_id  \
# 0        71                      []                   1817822909864556798
# 1        71                      []  823ef531-40e6-4397-b973-86bf5b032076
# 2        71                      []  b4974d89-932c-4a9f-a264-2ea0cf70613e
# 3        71                      []                   1786700154621508184
# 4        71                      []  66db6963-0aca-11e7-82f6-3863bb44ef7c
#
#    capacity station_type  eightd_has_key_dispenser        lon  \
# 0        27      classic                     False -73.912749
# 1        24      classic                     False -73.936790
# 2        20      classic                     False -73.937878
# 3        29      classic                     False -73.943950
# 4        78      classic                     False -73.986923
#
#                              station_id short_name  \
# 0                   1817822909864556798    7082.08
# 1  823ef531-40e6-4397-b973-86bf5b032076    3862.07
# 2  b4974d89-932c-4a9f-a264-2ea0cf70613e    8458.03
# 3                   1786700154621508184    5656.03
# 4  66db6963-0aca-11e7-82f6-3863bb44ef7c    5863.07
#
#    electric_bike_surcharge_waiver     rental_methods  \
# 0                           False  [KEY, CREDITCARD]
# 1                           False  [KEY, CREDITCARD]
# 2                           False  [KEY, CREDITCARD]
# 3                           False  [KEY, CREDITCARD]
# 4                           False  [KEY, CREDITCARD]
#
#                                          rental_uris        lat  has_kiosk  \
# 0  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  40.774233       True
# 1  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  40.669290       True
# 2  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  40.855331       True
# 3  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  40.727700       True
# 4  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  40.734232       True
#
#                        name
# 0            23 Ave & 31 St
# 1   Eastern Pkwy & Troy Ave
# 2  Pinehurst Ave & W 187 St
# 3   N Henry St & Norman Ave
# 4           E 15 St & 3 Ave

# %%
# We drop the 'rental methods' columns,
# as they contains multiple values and
# we cannot insert lists in a database cell.
df.drop(
    ["rental_methods", "eightd_station_services", "rental_uris"],
    axis="columns",
    inplace=True,
)
df.head(5)
# Out:
#   region_id                           external_id  capacity station_type  \
# 0        71                   1817822909864556798        27      classic
# 1        71  823ef531-40e6-4397-b973-86bf5b032076        24      classic
# 2        71  b4974d89-932c-4a9f-a264-2ea0cf70613e        20      classic
# 3        71                   1786700154621508184        29      classic
# 4        71  66db6963-0aca-11e7-82f6-3863bb44ef7c        78      classic
#
#    eightd_has_key_dispenser        lon                            station_id  \
# 0                     False -73.912749                   1817822909864556798
# 1                     False -73.936790  823ef531-40e6-4397-b973-86bf5b032076
# 2                     False -73.937878  b4974d89-932c-4a9f-a264-2ea0cf70613e
# 3                     False -73.943950                   1786700154621508184
# 4                     False -73.986923  66db6963-0aca-11e7-82f6-3863bb44ef7c
#
#   short_name  electric_bike_surcharge_waiver        lat  has_kiosk  \
# 0    7082.08                           False  40.774233       True
# 1    3862.07                           False  40.669290       True
# 2    8458.03                           False  40.855331       True
# 3    5656.03                           False  40.727700       True
# 4    5863.07                           False  40.734232       True
#
#                        name
# 0            23 Ave & 31 St
# 1   Eastern Pkwy & Troy Ave
# 2  Pinehurst Ave & W 187 St
# 3   N Henry St & Norman Ave
# 4           E 15 St & 3 Ave

# %% [markdown]
# ##Writing a Pandas Dataframe in a MySQL Table

# %%
from sqlalchemy import create_engine, text

conn_string = "mysql+pymysql://{user}:{password}@{host}/".format(
    host="db.ipeirotis.org", user="student", password="dwdstudent2025"
)

engine = create_engine(conn_string)

# %%
# Query to create a database
# In this example, we will try to create the (existing) database "public"
# But in general, we can give any name to the database
db_name = "public"
create_db_query = (
    f"CREATE DATABASE IF NOT EXISTS {db_name} DEFAULT CHARACTER SET 'utf8'"
)

# Create a database
with engine.connect() as con:
    con.execute(text(create_db_query))


# And lets switch to the database
with engine.connect() as con:
    con.execute(text(f"USE {db_name}"))

# %%
# To avoid conflicts between people writing in the same database, we add a random suffix in the tables
# We only create the variable once while running the notebook
import uuid

if "suffix" not in globals():
  suffix = str(uuid.uuid4())[:8]
print(suffix)
# Out:
# 3e20d832

# %% [markdown]
# Create Table and Store Data in Database using the to_sql command
# Then we create the table where we will store our data. Since we already have the data in a Pandas DataFrame, it is very easy to put the data in a database.

# %%
drop_table_sql = f'''
DROP TABLE IF EXISTS {db_name}.{table_name};
'''
table_name = f"Stations_{suffix}"
# Create a table
# See http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html for the documentation

# This step is optional, but it is good practice to define explicitly the
# data types before storing things in a database. In many cases, this can be ommitted, though.

create_table_query = f"""CREATE TABLE IF NOT EXISTS {db_name}.{table_name}
                                (legacy_id int,
                                station_id varchar(100),
                                region_id int,
                                external_id varchar(50),
                                lat float,
                                lon float,
                                short_name varchar(10),
                                name varchar(250),
                                station_type varchar(10),
                                capacity int,
                                electric_bike_surcharge_waiver bool,
                                eightd_has_key_dispenser bool,
                                has_kiosk bool,
                                PRIMARY KEY(station_id)
                                )"""

with engine.connect() as con:
  con.execute(text(create_table_query))

# %%
sql = f"""SELECT * FROM {db_name}.{table_name}"""

with engine.connect() as con:
    df2 = pd.read_sql(sql.format(db_name=db_name, table_name=table_name), con=con)
df2
# Out:
#      legacy_id                            station_id  region_id  \
# 0         None  00284700-9d22-42ce-8485-113fed9879c1       71.0
# 1         None  002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f       71.0
# 2         None  00967b8f-1a4d-4131-a65a-17fa8ca89e28       71.0
# 3         None  0096fecb-3a56-4585-9204-aa9554f7bc49       71.0
# 4         None  00d3e65e-b614-4408-aaa9-939ed96ce645       71.0
# ...        ...                                   ...        ...
# 2228      None  ff9581d3-3e1a-463a-bdab-d8150c468be2       71.0
# 2229      None  ffaa8f6a-a4ea-4d3a-a57c-f42f77cd4581       71.0
# 2230      None  ffae66ec-7c16-436f-bd0a-eedf81d580e7       71.0
# 2231      None  ffef95fa-600b-4f08-b2ce-e8eb034ebfd8       71.0
# 2232      None  fffb18be-14b3-412f-a808-107a98cd9e58       71.0
#
#                                external_id      lat      lon short_name  \
# 0     00284700-9d22-42ce-8485-113fed9879c1  40.7641 -73.9107    6879.04
# 1     002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f  40.8142 -73.9039    7830.03
# 2     00967b8f-1a4d-4131-a65a-17fa8ca89e28  40.7445 -73.8976    6225.03
# 3     0096fecb-3a56-4585-9204-aa9554f7bc49  40.7248 -73.9843    5626.06
# 4     00d3e65e-b614-4408-aaa9-939ed96ce645  40.7359 -74.0009    5955.12
# ...                                    ...      ...      ...        ...
# 2228  ff9581d3-3e1a-463a-bdab-d8150c468be2  40.7746 -73.9237    7126.01
# 2229  ffaa8f6a-a4ea-4d3a-a57c-f42f77cd4581  40.6785 -73.9137    4138.04
# 2230  ffae66ec-7c16-436f-bd0a-eedf81d580e7  40.8766 -73.8837    8778.01
# 2231  ffef95fa-600b-4f08-b2ce-e8eb034ebfd8  40.7435 -73.9186    6209.08
# 2232  fffb18be-14b3-412f-a808-107a98cd9e58  40.8567 -73.9027    8494.01
#
#                                       name station_type  capacity  \
# 0                           28 Ave & 44 St      classic        19
# 1                  Prospect Ave & E 151 St      classic        21
# 2                           41 Ave & 67 St      classic        20
# 3                           E 5 St & Ave A      classic        48
# 4                 Perry St & Greenwich Ave      classic        53
# ...                                    ...          ...       ...
# 2228                    21 St & Hoyt Ave S      classic        33
# 2229      Thomas S. Boyland St & Fulton St      classic        24
# 2230  E Mosholu Pkwy & Van Cortlandt Ave E      classic        22
# 2231                   46 St & Queens Blvd      classic        33
# 2232                 E 182 St & Morris Ave      classic        19
#
#       electric_bike_surcharge_waiver  eightd_has_key_dispenser  has_kiosk
# 0                                  0                         0          1
# 1                                  0                         0          1
# 2                                  0                         0          1
# 3                                  0                         0          1
# 4                                  0                         0          1
# ...                              ...                       ...        ...
# 2228                               0                         0          1
# 2229                               0                         0          1
# 2230                               0                         0          1
# 2231                               0                         0          1
# 2232                               0                         0          1
#
# [2233 rows x 13 columns]

# %%
df.to_sql(
    name=table_name,
    schema=db_name,
    con=engine,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1932                 if not evt_handled:
# -> 1933                     self.dialect.do_executemany(
#    1934                         cursor,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     171     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172         rowcount = cursor.executemany(statement, parameters)
#     173         if context is not None:
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in executemany(self, query, args)
#     181             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182             return self._do_execute_many(
#     183                 q_prefix,
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219             sql += v
# --> 220         rows += self.execute(sql + postfix)
#     221         self.rowcount = rows
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     152
# --> 153         result = self._query(query)
#     154         self._executed = query
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in _query(self, q)
#     321         self._clear_result()
# --> 322         conn.query(q)
#     323         self._do_get_result()
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     562         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564         return self._affected_rows
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     824             result = MySQLResult(self)
# --> 825             result.read()
#     826         self._result = result
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in read(self)
#    1198         try:
# -> 1199             first_packet = self.connection._read_packet()
#    1200
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     774                 self._result.unbuffered_active = False
# --> 775             packet.raise_for_error()
#     776         return packet
#
# /usr/local/lib/python3.11/dist-packages/pymysql/protocol.py in raise_for_error(self)
#     218             print("errno =", errno)
# --> 219         err.raise_mysql_exception(self._data)
#     220
#
# /usr/local/lib/python3.11/dist-packages/pymysql/err.py in raise_mysql_exception(data)
#     149         errorclass = InternalError if errno < 1000 else OperationalError
# --> 150     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1817822909864556798' for key 'Stations_3e20d832.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-51-47ac345feaf4> in <cell line: 0>()
# ----> 1 df.to_sql(
#       2     name=table_name,
#       3     schema=db_name,
#       4     con=engine,
#       5     if_exists="append",
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2016         )
#    2017
# -> 2018         total_inserted = sql_engine.insert_records(
#    2019             table=table,
#    2020             con=self.con,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565             if re.search(msg, err_text):
#    1566                 raise ValueError("inf cannot be used with MySQL") from err
# -> 1567             raise err
#    1568
#    1569
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1556
#    1557         try:
# -> 1558             return table.insert(chunksize=chunksize, method=method)
#    1559         except exc.StatementError as err:
#    1560             # GH34431
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in insert(self, chunksize, method)
#    1117
#    1118                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119                 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120                 # GH 46891
#    1121                 if num_inserted is not None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#    1008         """
#    1009         data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010         result = conn.execute(self.table.insert(), data)
#    1011         return result.rowcount
#    1012
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
# -> 1416             return meth(
#    1417                 self,
#    1418                 distilled_parameters,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, distilled_params, execution_options)
#     521             if TYPE_CHECKING:
#     522                 assert isinstance(self, Executable)
# --> 523             return connection._execute_clauseelement(
#     524                 self, distilled_params, execution_options
#     525             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1636             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637         )
# -> 1638         ret = self._execute_context(
#    1639             dialect,
#    1640             dialect.execution_ctx_cls._init_compiled,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841             return self._exec_insertmany_context(dialect, context)
#    1842         else:
# -> 1843             return self._exec_single_context(
#    1844                 dialect, context, statement, parameters
#    1845             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1981
#    1982         except BaseException as e:
# -> 1983             self._handle_dbapi_exception(
#    1984                 e, str_statement, effective_parameters, cursor, context
#    1985             )
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350             elif should_wrap:
#    2351                 assert sqlalchemy_exception is not None
# -> 2352                 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353             else:
#    2354                 assert exc_info[1] is not None
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1931                             break
#    1932                 if not evt_handled:
# -> 1933                     self.dialect.do_executemany(
#    1934                         cursor,
#    1935                         str_statement,
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     170
#     171     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172         rowcount = cursor.executemany(statement, parameters)
#     173         if context is not None:
#     174             context._rowcount = rowcount
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in executemany(self, query, args)
#     180             q_postfix = m.group(3) or ""
#     181             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182             return self._do_execute_many(
#     183                 q_prefix,
#     184                 q_values,
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218                 sql += b","
#     219             sql += v
# --> 220         rows += self.execute(sql + postfix)
#     221         self.rowcount = rows
#     222         return rows
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     151         query = self.mogrify(query, args)
#     152
# --> 153         result = self._query(query)
#     154         self._executed = query
#     155         return result
#
# /usr/local/lib/python3.11/dist-packages/pymysql/cursors.py in _query(self, q)
#     320         conn = self._get_db()
#     321         self._clear_result()
# --> 322         conn.query(q)
#     323         self._do_get_result()
#     324         return self.rowcount
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     561             sql = sql.encode(self.encoding, "surrogateescape")
#     562         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564         return self._affected_rows
#     565
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     823         else:
#     824             result = MySQLResult(self)
# --> 825             result.read()
#     826         self._result = result
#     827         if result.server_status is not None:
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in read(self)
#    1197     def read(self):
#    1198         try:
# -> 1199             first_packet = self.connection._read_packet()
#    1200
#    1201             if first_packet.is_ok_packet():
#
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     773             if self._result is not None and self._result.unbuffered_active is True:
#     774                 self._result.unbuffered_active = False
# --> 775             packet.raise_for_error()
#     776         return packet
#     777
#
# /usr/local/lib/python3.11/dist-packages/pymysql/protocol.py in raise_for_error(self)
#     217         if DEBUG:
#     218             print("errno =", errno)
# --> 219         err.raise_mysql_exception(self._data)
#     220
#     221     def dump(self):
#
# /usr/local/lib/python3.11/dist-packages/pymysql/err.py in raise_mysql_exception(data)
#     148     if errorclass is None:
#     149         errorclass = InternalError if errno < 1000 else OperationalError
# --> 150     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1817822909864556798' for key 'Stations_3e20d832.PRIMARY'")
# [SQL: INSERT INTO public.`Stations_3e20d832` (region_id, external_id, capacity, station_type, eightd_has_key_dispenser, lon, station_id, short_name, electric_bike_surcharge_waiver, lat, has_kiosk, name) VALUES (%(region_id)s, %(external_id)s, %(capacity)s, %(station_type)s, %(eightd_has_key_dispenser)s, %(lon)s, %(station_id)s, %(short_name)s, %(electric_bike_surcharge_waiver)s, %(lat)s, %(has_kiosk)s, %(name)s)]
# [parameters: [{'region_id': '71', 'external_id': '1817822909864556798', 'capacity': 27, 'station_type': 'classic', 'eightd_has_key_dispenser': 0, 'lon': -73.91274864321404, 'station_id': '1817822909864556798', 'short_name': '7082.08', 'electric_bike_surcharge_waiver': 0, 'lat': 40.77423301703027, 'has_kiosk': 1, 'name': '23 Ave & 31 St'}, {'region_id': '71', 'external_id': '823ef531-40e6-4397-b973-86bf5b032076', 'capacity': 24, 'station_type': 'classic', 'eightd_has_key_dispenser': 0, 'lon': -73.93679, 'station_id': '823ef531-40e6-4397-b973-86bf5b032076', 'short_name': '3862.07', 'electric_bike_surcharge_waiver': 0, 'lat': 40.66929, 'has_kiosk': 1, 'name': 'Eastern Pkwy & Troy Ave'}, {'region_id': '71', 'external_id': 'b4974d89-932c-4a9f-a264-2ea0cf70613e', 'capacity': 20, 'station_type': 'classic', 'eightd_has_key_dispenser': 0, 'lon': -73.937878, 'station_id': 'b4974d89-932c-4a9f-a264-2ea0cf70613e', 'short_name': '8458.03', 'electric_bike_surcharge_waiver': 0, 'lat': 40.855331, 'has_kiosk': 1, 'name': 'Pinehurst Ave & W 187 St'}, {'region_id': '71', 'external_id': '1786700154621508184', 'capacity': 29, 'station_type': 'classic', 'eightd_has_key_dispenser': 0, 'lon': -73.94395, 'station_id': '1786700154621508184', 'short_name': '5656.03', 'electric_bike_surcharge_waiver': 0, 'lat': 40.7277, 'has_kiosk': 1, 'name': 'N Henry St & Norman Ave'}, {'region_id': '71', 'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c', 'capacity': 78, 'station_type': 'classic', 'eightd_has_ke...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# Once we have the data in the table, we also specify a primary key
# If we had FOREIGN KEYS we can add them in the same way

# add_key_query = f"ALTER TABLE {table_name} ADD PRIMARY KEY(station_id)"
# print(add_key_query)

# with engine.connect() as con:
#  con.execute(text(add_key_query))

# %% [markdown]
# #Reading from a SQL Database in Python using the read_sql command in Pandas
# We can similarly read from the database using Pandas

# %%
query = text(f"SELECT * FROM {db_name}.{table_name}")
print(query)
# Out:
# SELECT * FROM public.Stations_3e20d832

# %%
with engine.connect() as con:
  df2 = pd.read_sql(query, con=con)
df2.head(5)
# Out:
#   legacy_id                            station_id  region_id  \
# 0      None  00284700-9d22-42ce-8485-113fed9879c1       71.0
# 1      None  002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f       71.0
# 2      None  00967b8f-1a4d-4131-a65a-17fa8ca89e28       71.0
# 3      None  0096fecb-3a56-4585-9204-aa9554f7bc49       71.0
# 4      None  00d3e65e-b614-4408-aaa9-939ed96ce645       71.0
#
#                             external_id      lat      lon short_name  \
# 0  00284700-9d22-42ce-8485-113fed9879c1  40.7641 -73.9107    6879.04
# 1  002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f  40.8142 -73.9039    7830.03
# 2  00967b8f-1a4d-4131-a65a-17fa8ca89e28  40.7445 -73.8976    6225.03
# 3  0096fecb-3a56-4585-9204-aa9554f7bc49  40.7248 -73.9843    5626.06
# 4  00d3e65e-b614-4408-aaa9-939ed96ce645  40.7359 -74.0009    5955.12
#
#                        name station_type  capacity  \
# 0            28 Ave & 44 St      classic        19
# 1   Prospect Ave & E 151 St      classic        21
# 2            41 Ave & 67 St      classic        20
# 3            E 5 St & Ave A      classic        48
# 4  Perry St & Greenwich Ave      classic        53
#
#    electric_bike_surcharge_waiver  eightd_has_key_dispenser  has_kiosk
# 0                               0                         0          1
# 1                               0                         0          1
# 2                               0                         0          1
# 3                               0                         0          1
# 4                               0                         0          1

# %% [markdown]
# #Export Data from Database to CSV or Excel
# And remember that from Pandas it is also possible to export in other formats, such as Excel of CSV.

# %%
# The necessary library to write in Excel
# !sudo pip3 install -U openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
df2.to_excel("citibike.xlsx")
df2.to_csv("citibike.csv")

# %% [markdown]
# #Cleanup
# Finally, let's clean up and delete the table that we created

# %%
drop_table_query = f"DROP TABLE IF EXISTS {db_name}.{table_name}"
print(drop_table_query)

with engine.connect() as con:
  con.execute(text(drop_table_query))
# Out:
# DROP TABLE IF EXISTS public.Stations_3e20d832
