# %% [markdown]
# <a href="https://colab.research.google.com/github/mb8655/Python/blob/main/Google_Maps_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Google Maps API
# This a relatively simple API, that does not require any authentication.
#
# The documentation is available at https://developers.google.com/maps/documentation/geocoding/intro
#
# At the simplest version, the endpoint is http://maps.googleapis.com/maps/api/geocode/json and you can put as parameter the "address".
#
# For example, the following call will return the analysis for the address "44 West 4th, Ste 8-84, Manhattan, NY, USA"

# %%
import requests
import time

# %%
import requests

GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'
params = {
    'address': '4 Johnson Dr',
    'key': 'AIzaSyAwAQwNRabOhjJxgB9zkogV-BKgbAnjxUk'
}

resp = requests.get(GOOGLE_MAPS_API_URL, params = params)
resp.json()
# Out:
# {'results': [{'address_components': [{'long_name': '4',
#      'short_name': '4',
#      'types': ['street_number']},
#     {'long_name': "Johnson's Drive",
#      'short_name': "Johnson's Dr",
#      'types': ['route']},
#     {'long_name': 'Elmstead Market',
#      'short_name': 'Elmstead Market',
#      'types': ['locality', 'political']},
#     {'long_name': 'Colchester',
#      'short_name': 'Colchester',
#      'types': ['postal_town']},
#     {'long_name': 'Essex',
#      'short_name': 'Essex',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'England',
#      'short_name': 'England',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United Kingdom',
#      'short_name': 'GB',
#      'types': ['country', 'political']},
#     {'long_name': 'CO7 7AL',
#      'short_name': 'CO7 7AL',
#      'types': ['postal_code']}],
#    'formatted_address': "4 Johnson's Dr, Elmstead Market, Colchester CO7 7AL, UK",
#    'geometry': {'location': {'lat': 51.88255299999999, 'lng': 0.997181},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 51.8839690302915,
#       'lng': 0.9985103302915018},
#      'southwest': {'lat': 51.8812710697085, 'lng': 0.9958123697084977}}},
#    'navigation_points': [{'location': {'latitude': 51.8826251,
#       'longitude': 0.9971599}}],
#    'place_id': 'ChIJc9I4fK8P2UcRrU-XiikARo0',
#    'types': ['premise', 'street_address']}],
#  'status': 'OK'}

# %%
#other examples

def call_google_api(address):

    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'
    params = {
        'address': address,
        'region': 'usa',
        'key': 'AIzaSyAwAQwNRabOhjJxgB9zkogV-BKgbAnjxUk'
    }
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)

    results = req.json()

    # Use the first result
    if 'results' in results and len(results['results'])>0:
        result = results['results'][0]
        return result
    else:
        # We got nothing back, let's wait a bit
        time.sleep(2)
        return None

# %%
call_google_api("Soho, New York, NY")
# Out:
# {'address_components': [{'long_name': 'SoHo',
#    'short_name': 'SoHo',
#    'types': ['neighborhood', 'political']},
#   {'long_name': 'Manhattan',
#    'short_name': 'Manhattan',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': 'New York',
#    'short_name': 'New York',
#    'types': ['locality', 'political']},
#   {'long_name': 'New York County',
#    'short_name': 'New York County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'New York',
#    'short_name': 'NY',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']}],
#  'formatted_address': 'SoHo, New York, NY, USA',
#  'geometry': {'bounds': {'northeast': {'lat': 40.7283442, 'lng': -73.9958967},
#    'southwest': {'lat': 40.7189454, 'lng': -74.0054619}},
#   'location': {'lat': 40.7245908, 'lng': -74.00191740000001},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 40.7283442, 'lng': -73.9958967},
#    'southwest': {'lat': 40.7189454, 'lng': -74.0054619}}},
#  'place_id': 'ChIJ8-JRXoxZwokRGPiQ9Ek0L84',
#  'types': ['neighborhood', 'political']}

# %%
call_google_api("Jupiter, Florida")
# Out:
# {'address_components': [{'long_name': 'Jupiter',
#    'short_name': 'Jupiter',
#    'types': ['locality', 'political']},
#   {'long_name': 'Palm Beach County',
#    'short_name': 'Palm Beach County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Florida',
#    'short_name': 'FL',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']}],
#  'formatted_address': 'Jupiter, FL, USA',
#  'geometry': {'bounds': {'northeast': {'lat': 26.9708801, 'lng': -80.056935},
#    'southwest': {'lat': 26.882486, 'lng': -80.181378}},
#   'location': {'lat': 26.9318533, 'lng': -80.1023696},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 26.9708801, 'lng': -80.056935},
#    'southwest': {'lat': 26.882486, 'lng': -80.181378}}},
#  'place_id': 'ChIJfW8aRDUz2YgRIZqJ_29IUdw',
#  'types': ['locality', 'political']}

# %%
def get_formatted_address(address):
    google_result = call_google_api(address)
    if google_result == None:
        return None
    return google_result['formatted_address']

# %%
def get_lon_lat(address):
    google_result = call_google_api(address)
    if google_result == None:
        return None
    return google_result['geometry']['location']

# %%
address = "547 Riverside Drive, New York, NY"
get_formatted_address(address)
# Out:
# '547 Riverside Dr, New York, NY 10027, USA'

# %%
address2 = '416 philadelphia drive, jupiter florida'
get_formatted_address(address2)
# Out:
# '416 Philadelphia Dr, Jupiter, FL 33458, USA'

# %%
get_lon_lat(address2)
# Out:
# {'lat': 26.9393118, 'lng': -80.1041219}

# %%
get_lon_lat(address)
# Out:
# {'lat': 40.8151021, 'lng': -73.9609174}

# %%
address = "44 W 4th Street, New York"
get_formatted_address(address)
# Out:
# '44 W 4th St, New York, NY 10012, USA'

# %%
address = "44 W Fourth Street, New York"
get_formatted_address(address)
# Out:
# '44 W 4th St, New York, NY 10012, USA'

# %%
address = "84 Wooster, Ste 703, New York"
get_formatted_address(address)
# Out:
# '84 Wooster St #703, New York, NY 10012, USA'

# %% [markdown]
# ##Exercise
# Below you can find a list of 50 addresses in New York. The addresses do not contain the zip code, and are not well-formatted. Using the Google Maps API, as listed above, generate the well-formatted address for each address. Also generate the long/lat coordinates for the address.
#
# Important: The Google API listed above is not authenticated. To avoid abuse, when it receives large number of requests, it tends to return nothing. You may want to structure your code to check for this behavior, and retry if necessary.

# %%
address_list = ['2508A BROADWAY, QUEENS',  '1859 WESTCHESTER AVENUE, BRONX',
                '113 WEST  116 STREET, MANHATTAN',  '157 PROSPECT PARK SOUTH WEST, BROOKLYN',
                '12707 MERRICK BOULEVARD, QUEENS',  '422 EAST   75 STREET, MANHATTAN',
                '253 WEST   42 STREET, MANHATTAN',  '1027 WESTCHESTER AVE, BRONX',
                '811 9 AVENUE, MANHATTAN',  '717 KINGS HIGHWAY, BROOKLYN',
                '13529 40TH RD, QUEENS',  '4417 NEW UTRECHT AVE, BROOKLYN',  '1688 EAST   16 STREET, BROOKLYN',
                '1634 CROSBY AVE, BRONX',  '218 PARKSIDE AVE, BROOKLYN',  '1307 ARTHUR KILL ROAD, STATEN ISLAND',
                '1162 FIRST AVENUE, MANHATTAN',  '5814 ROOSEVELT AVE, QUEENS',  '872 A FLATBUSH AVE, BROOKLYN',
                '631 WILSON AVE, BROOKLYN',  '1093 JACKSON AVENUE, QUEENS',  '465 WEST   51 STREET, MANHATTAN',
                '345 ADAMS ST, BROOKLYN',  '1374 BOSTON ROAD, BRONX',  '71 7 AVENUE SOUTH, MANHATTAN',
                '520 BAY ST, STATEN ISLAND',  '623 GRAND STREET, BROOKLYN',  '11000 ROCKAWAY BOULEVARD, QUEENS',
                '2927 40 ROAD, QUEENS',  '570 8 AVENUE, MANHATTAN',  '4819 VERNON BLVD, QUEENS',
                '1 WORLDS FAIR MARINA, QUEENS',  '2342 ARTHUR AVENUE, BRONX',  '54 PEARL STREET, MANHATTAN',
                '4012 QUEENS BOULEVARD, QUEENS',  '691 TENTH AVE, MANHATTAN',  '226 E 14TH ST, MANHATTAN',
                '3 GREENWICH AVENUE, MANHATTAN',  '2172 86TH ST, BROOKLYN',  '875 10 AVENUE, MANHATTAN',
                'NKA JFK INTERNATIONAL AIRPORT, QUEENS',  '70 SOUTH ST, MANHATTAN',  '3520 FARRINGTON ST, QUEENS',
                '12696 WILLETS POINT BOULEVARD, QUEENS',  '925 ALLERTON AVENUE, BRONX',  '98 3 AVENUE, MANHATTAN',
                '8805 ASTORIA BLVD, QUEENS',  '12 PENN STATION, MANHATTAN',  '138 DIVISION STREET, MANHATTAN',
                '7047 PARSONS BOULEVARD, QUEENS']

# %%
# prompt: generate the well-formatted address for each address above. Also generate the long/lat coordinates for the address.

import pandas as pd

formatted_addresses = []
lon_lats = []

for address in address_list:
  formatted_address = get_formatted_address(address)
  lon_lat = get_lon_lat(address)
  formatted_addresses.append(formatted_address)
  lon_lats.append(lon_lat)

df = pd.DataFrame({'Original Address': address_list, 'Formatted Address': formatted_addresses, 'Lon/Lat': lon_lats})
df
# Out:
#                           Original Address  \
# 0                   2508A BROADWAY, QUEENS
# 1           1859 WESTCHESTER AVENUE, BRONX
# 2          113 WEST  116 STREET, MANHATTAN
# 3   157 PROSPECT PARK SOUTH WEST, BROOKLYN
# 4          12707 MERRICK BOULEVARD, QUEENS
# 5          422 EAST   75 STREET, MANHATTAN
# 6          253 WEST   42 STREET, MANHATTAN
# 7              1027 WESTCHESTER AVE, BRONX
# 8                  811 9 AVENUE, MANHATTAN
# 9              717 KINGS HIGHWAY, BROOKLYN
# 10                   13529 40TH RD, QUEENS
# 11          4417 NEW UTRECHT AVE, BROOKLYN
# 12         1688 EAST   16 STREET, BROOKLYN
# 13                  1634 CROSBY AVE, BRONX
# 14              218 PARKSIDE AVE, BROOKLYN
# 15    1307 ARTHUR KILL ROAD, STATEN ISLAND
# 16            1162 FIRST AVENUE, MANHATTAN
# 17              5814 ROOSEVELT AVE, QUEENS
# 18            872 A FLATBUSH AVE, BROOKLYN
# 19                631 WILSON AVE, BROOKLYN
# 20             1093 JACKSON AVENUE, QUEENS
# 21         465 WEST   51 STREET, MANHATTAN
# 22                  345 ADAMS ST, BROOKLYN
# 23                 1374 BOSTON ROAD, BRONX
# 24            71 7 AVENUE SOUTH, MANHATTAN
# 25               520 BAY ST, STATEN ISLAND
# 26              623 GRAND STREET, BROOKLYN
# 27        11000 ROCKAWAY BOULEVARD, QUEENS
# 28                    2927 40 ROAD, QUEENS
# 29                 570 8 AVENUE, MANHATTAN
# 30                4819 VERNON BLVD, QUEENS
# 31            1 WORLDS FAIR MARINA, QUEENS
# 32               2342 ARTHUR AVENUE, BRONX
# 33              54 PEARL STREET, MANHATTAN
# 34           4012 QUEENS BOULEVARD, QUEENS
# 35                691 TENTH AVE, MANHATTAN
# 36                226 E 14TH ST, MANHATTAN
# 37           3 GREENWICH AVENUE, MANHATTAN
# 38                  2172 86TH ST, BROOKLYN
# 39                875 10 AVENUE, MANHATTAN
# 40   NKA JFK INTERNATIONAL AIRPORT, QUEENS
# 41                  70 SOUTH ST, MANHATTAN
# 42              3520 FARRINGTON ST, QUEENS
# 43   12696 WILLETS POINT BOULEVARD, QUEENS
# 44              925 ALLERTON AVENUE, BRONX
# 45                  98 3 AVENUE, MANHATTAN
# 46               8805 ASTORIA BLVD, QUEENS
# 47              12 PENN STATION, MANHATTAN
# 48          138 DIVISION STREET, MANHATTAN
# 49          7047 PARSONS BOULEVARD, QUEENS
#
#                                     Formatted Address  \
# 0              2508A Broadway, Astoria, NY 11106, USA
# 1          1859 Westchester Ave, Bronx, NY 10472, USA
# 2             113 W 116th St, New York, NY 10026, USA
# 3   157 Prospect Park Southwest, Brooklyn, NY 1121...
# 4          12707 Merrick Blvd, Jamaica, NY 11434, USA
# 5              422 E 75th St, New York, NY 10021, USA
# 6              253 W 42nd St, New York, NY 10036, USA
# 7          1027 Westchester Ave, Bronx, NY 10459, USA
# 8                811 9th Ave, New York, NY 10019, USA
# 9              717 Kings Hwy, Brooklyn, NY 11223, USA
# 10            135-29 40th Rd, Flushing, NY 11354, USA
# 11      4417 New Utrecht Ave, Brooklyn, NY 11219, USA
# 12     1688 East 16th Street, Brooklyn, NY 11229, USA
# 13              1634 Crosby Ave, Bronx, NY 10461, USA
# 14          218 Parkside Ave, Brooklyn, NY 11226, USA
# 15  1307 Arthur Kill Rd, Staten Island, NY 10312, USA
# 16             1162 1st Ave., New York, NY 10065, USA
# 17        5814 Roosevelt Ave, Woodside, NY 11377, USA
# 18         872A Flatbush Ave, Brooklyn, NY 11226, USA
# 19            631 Wilson Ave, Brooklyn, NY 11207, USA
# 20  1093 Jackson Ave, Long Island City, NY 11101, USA
# 21             465 W 51st St, New York, NY 10019, USA
# 22              345 Adams St, Brooklyn, NY 11201, USA
# 23               1374 Boston Rd, Bronx, NY 10456, USA
# 24              71 7th Ave S, New York, NY 10014, USA
# 25           520 Bay St, Staten Island, NY 10304, USA
# 26              623 Grand St, Brooklyn, NY 11211, USA
# 27  11000 Rockaway Blvd, South Ozone Park, NY 1142...
# 28     29-27 40th Rd, Long Island City, NY 11101, USA
# 29               570 8th Ave, New York, NY 10018, USA
# 30  48-19 Vernon Blvd, Long Island City, NY 11101,...
# 31                 1 Marina Rd, Corona, NY 11368, USA
# 32              2342 Arthur Ave, Bronx, NY 10458, USA
# 33               54 Pearl St, New York, NY 10004, USA
# 34        40-12 Queens Blvd, Sunnyside, NY 11104, USA
# 35              691 10th Ave, New York, NY 10036, USA
# 36             226 E 14th St, New York, NY 10003, USA
# 37           3 Greenwich Ave, New York, NY 10014, USA
# 38              2172 86th St, Brooklyn, NY 11214, USA
# 39              875 10th Ave, New York, NY 10019, USA
# 40  John F. Kennedy International Airport (JFK), Q...
# 41               70 South St, New York, NY 10270, USA
# 42       35-20 Farrington St, Flushing, NY 11354, USA
# 43    12696 Willets Point Blvd, Queens, NY 11368, USA
# 44             925 Allerton Ave, Bronx, NY 10469, USA
# 45                 98 Third Ave, Bronx, NY 10451, USA
# 46        88-05 Astoria Blvd, Flushing, NY 11370, USA
# 47              Penn Station, New York, NY 10119, USA
# 48           138 Division St, New York, NY 10002, USA
# 49   70-47 Parsons Blvd, Fresh Meadows, NY 11365, USA
#
#                                               Lon/Lat
# 0             {'lat': 40.7631113, 'lng': -73.9282437}
# 1      {'lat': 40.83280990000001, 'lng': -73.8639364}
# 2             {'lat': 40.8025601, 'lng': -73.9502641}
# 3             {'lat': 40.6547785, 'lng': -73.9735675}
# 4             {'lat': 40.6816968, 'lng': -73.7651812}
# 5             {'lat': 40.7691615, 'lng': -73.9537079}
# 6      {'lat': 40.7572074, 'lng': -73.98914979999999}
# 7             {'lat': 40.8241622, 'lng': -73.8932458}
# 8   {'lat': 40.76587550000001, 'lng': -73.98753359...
# 9      {'lat': 40.6065992, 'lng': -73.96504999999999}
# 10            {'lat': 40.7588885, 'lng': -73.8306151}
# 11            {'lat': 40.6401676, 'lng': -73.9941059}
# 12            {'lat': 40.6084776, 'lng': -73.9575062}
# 13            {'lat': 40.8450565, 'lng': -73.8305802}
# 14            {'lat': 40.6552345, 'lng': -73.9605156}
# 15            {'lat': 40.5655321, 'lng': -74.1840474}
# 16            {'lat': 40.7624127, 'lng': -73.9596064}
# 17              {'lat': 40.74514, 'lng': -73.9060669}
# 18            {'lat': 40.6508378, 'lng': -73.9590922}
# 19            {'lat': 40.6897595, 'lng': -73.9060594}
# 20            {'lat': 40.7432644, 'lng': -73.9516319}
# 21     {'lat': 40.7653447, 'lng': -73.99075069999999}
# 22             {'lat': 40.692752, 'lng': -73.9885422}
# 23     {'lat': 40.8323407, 'lng': -73.89811379999999}
# 24      {'lat': 40.732236, 'lng': -74.00331299999999}
# 25            {'lat': 40.6290899, 'lng': -74.0769641}
# 26     {'lat': 40.7115484, 'lng': -73.94714619999999}
# 27     {'lat': 40.6738714, 'lng': -73.83268509999999}
# 28            {'lat': 40.7514151, 'lng': -73.9351158}
# 29     {'lat': 40.7547171, 'lng': -73.99133599999999}
# 30     {'lat': 40.7434607, 'lng': -73.95344949999999}
# 31              {'lat': 40.761224, 'lng': -73.857806}
# 32            {'lat': 40.8541344, 'lng': -73.8884775}
# 33     {'lat': 40.7033808, 'lng': -74.01135219999999}
# 34            {'lat': 40.7433503, 'lng': -73.9239126}
# 35            {'lat': 40.7630974, 'lng': -73.9933266}
# 36     {'lat': 40.7326152, 'lng': -73.98620609999999}
# 37            {'lat': 40.7338471, 'lng': -73.9998667}
# 38            {'lat': 40.6019756, 'lng': -73.9944656}
# 39             {'lat': 40.7693748, 'lng': -73.988709}
# 40            {'lat': 40.6446124, 'lng': -73.7797278}
# 41            {'lat': 40.7051725, 'lng': -74.0053083}
# 42     {'lat': 40.7637988, 'lng': -73.83181119999999}
# 43            {'lat': 40.7579786, 'lng': -73.8419918}
# 44            {'lat': 40.8657387, 'lng': -73.8602861}
# 45     {'lat': 40.8096187, 'lng': -73.92936399999999}
# 46             {'lat': 40.7643619, 'lng': -73.880911}
# 47              {'lat': 40.750568, 'lng': -73.993519}
# 48             {'lat': 40.714555, 'lng': -73.9915134}
# 49            {'lat': 40.7309922, 'lng': -73.8100284}
