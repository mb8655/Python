# %% [markdown]
# <a href="https://colab.research.google.com/github/mb8655/Python/blob/main/Common_DataFrames_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Common Pandas Operations
# We will use the data set from NYC OpenData called "New York City Leading Causes of Death".

# %%
# %matplotlib inline
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# #Fetching the data
# We fetch the data in JSON format using the NYC OpenData API:

# %%
# Data set: New York City Leading Causes of Death
# https://data.cityofnewyork.us/Health/New-York-City-Leading-Causes-of-Death/jb7j-dtam
url = 'http://data.cityofnewyork.us/api/views/jb7j-dtam/rows.json'
results = requests.get(url).json()

# %%
# view data dict
results.keys()
# Out:
# dict_keys(['meta', 'data'])

# %% [markdown]
# dict_keys(['meta', 'data'])
# There are two main fields in the returned JSON. The meta part that describes the metadata, and the actual data.

# %%
#view the metadata
results['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'locked', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'clientContext', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
results['data']
# Out:
# [['row-qupq-7iik.acsp',
#   '00000000-0000-0000-85AB-5F87A996A300',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Other Race/ Ethnicity',
#   '11',
#   '.',
#   '.'],
#  ['row-s8an-xgaf.eb4t',
#   '00000000-0000-0000-5DC3-A9FF70A70774',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Not Stated/Unknown',
#   '70',
#   '.',
#   '.'],
#  ['row-68me_j7hb_a7yy',
#   '00000000-0000-0000-FDE0-47C6EDC2A52E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Black Non-Hispanic',
#   '213',
#   '25',
#   '33'],
#  ['row-bh3s_5dw5_zhf5',
#   '00000000-0000-0000-3231-0B9575966E6B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Atherosclerosis (I70)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-bp6v-stuc~hy7b',
#   '00000000-0000-0000-BBA7-44D13389B1EE',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Black Non-Hispanic',
#   '1852',
#   '176.5',
#   '148.4'],
#  ['row-n3xk~tgc4.hipr',
#   '00000000-0000-0000-B22A-B79FD922E8A3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'White Non-Hispanic',
#   '501',
#   '35',
#   '20.7'],
#  ['row-u636~efzv_gzaz',
#   '00000000-0000-0000-A223-D806245A9818',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'M',
#   'Asian and Pacific Islander',
#   '36',
#   '7.4',
#   '7.7'],
#  ['row-a5qn.fmq9_g2up',
#   '00000000-0000-0000-A962-3F42BB5EE529',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'F',
#   'Not Stated/Unknown',
#   '53',
#   '.',
#   '.'],
#  ['row-can3.6c34~6wmk',
#   '00000000-0000-0000-09B4-32DE26D2986D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Hispanic',
#   '1349',
#   '112.7',
#   '143.8'],
#  ['row-mbru-2n2b_uf9d',
#   '00000000-0000-0000-DDF3-23B2BF75689E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Septicemia (A40-A41)',
#   'F',
#   'White Non-Hispanic',
#   '107',
#   '7.5',
#   '4.3'],
#  ['row-u9kr~trjf.jyb5',
#   '00000000-0000-0000-4167-B287B7865385',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'White Non-Hispanic',
#   '253',
#   '17.9',
#   '11.1'],
#  ['row-e7ur-eubk~yx85',
#   '00000000-0000-0000-E465-9D5A96FCB39C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Chronic Liver Disease and Cirrhosis (K70, K73)',
#   'M',
#   'Hispanic',
#   '167',
#   '14.5',
#   '18.8'],
#  ['row-xqd6.ecpw_vn82',
#   '00000000-0000-0000-A856-F924CD727166',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Hispanic',
#   '199',
#   '16.7',
#   '26.6'],
#  ['row-ta4a.hjpj~da36',
#   '00000000-0000-0000-BB81-F100DF4DC68D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Not Stated/Unknown',
#   '5',
#   '.',
#   '.'],
#  ['row-6rqy_5z6v~cskq',
#   '00000000-0000-0000-2A4E-5A98840AFD93',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Asian and Pacific Islander',
#   '35',
#   '5.8',
#   '6.3'],
#  ['row-e9fc.h3ms.aq5f',
#   '00000000-0000-0000-CEEA-49B21588AAE6',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Asian and Pacific Islander',
#   '37',
#   '6.7',
#   '8'],
#  ['row-yz2t_j9ng~fgrh',
#   '00000000-0000-0000-83B5-5BB4BF0E460D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Atherosclerosis (I70)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-4gq6.4muk_wt9k',
#   '00000000-0000-0000-5DAA-658F2DB41A3E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Asian and Pacific Islander',
#   '622',
#   '115.1',
#   '138.4'],
#  ['row-p6t9.t5bc~hjha',
#   '00000000-0000-0000-44ED-400FC4BAC2A3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Asian and Pacific Islander',
#   '73',
#   '13.7',
#   '19.1'],
#  ['row-ixc3~tr8m_7hyv',
#   '00000000-0000-0000-A689-FFD77085B59D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'M',
#   'Not Stated/Unknown',
#   '21',
#   '.',
#   '.'],
#  ['row-6x2b-jday-v3dt',
#   '00000000-0000-0000-3F3A-CE036DFEB134',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'White Non-Hispanic',
#   '199',
#   '14',
#   '6.8'],
#  ['row-8xj9.bz3c-aqz2',
#   '00000000-0000-0000-79C2-1FE2B6D385A5',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   "Alzheimer's Disease (G30)",
#   'F',
#   'White Non-Hispanic',
#   '231',
#   '16.3',
#   '7.2'],
#  ['row-bj2t.8w7m.vh56',
#   '00000000-0000-0000-E886-DDC8A7420040',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-ppva~beas~9d9x',
#   '00000000-0000-0000-4C54-DDA319E1EB97',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Hispanic',
#   '152',
#   '12.9',
#   '16.4'],
#  ['row-xpy2-bx9f-xtjd',
#   '00000000-0000-0000-DA9B-6838E3AEE909',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Asian and Pacific Islander',
#   '30',
#   '5.6',
#   '7.9'],
#  ['row-f9g2_yfze~d6ww',
#   '00000000-0000-0000-4F1D-315CDB4987F4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Asian and Pacific Islander',
#   '95',
#   '16.6',
#   '22.9'],
#  ['row-dec7_mt7m-9aqt',
#   '00000000-0000-0000-2A1B-0756EDBECFB0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'All Other Causes',
#   'M',
#   'White Non-Hispanic',
#   '2034',
#   '151.6',
#   '130.9'],
#  ['row-9zkr~jasc~3mx2',
#   '00000000-0000-0000-114C-6CF7255EE6D7',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Not Stated/Unknown',
#   '36',
#   '.',
#   '.'],
#  ['row-w3zy.f96a-ycy9',
#   '00000000-0000-0000-8EBB-F13E85FC1C7B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Asian and Pacific Islander',
#   '71',
#   '12.4',
#   '14.2'],
#  ['row-uk39~ehbh-v7ad',
#   '00000000-0000-0000-9C32-4D73EC18A0B0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Hispanic',
#   '204',
#   '16.3',
#   '18.5'],
#  ['row-ezeq-hyes_e2w5',
#   '00000000-0000-0000-23CE-5A7E4514C86A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Asian and Pacific Islander',
#   '394',
#   '70.1',
#   '89.7'],
#  ['row-mciw_q3mg~udbc',
#   '00000000-0000-0000-C22D-1CE9A0425124',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Not Stated/Unknown',
#   '106',
#   '.',
#   '.'],
#  ['row-pk3s_e2d4.fwf3',
#   '00000000-0000-0000-9270-99478FA28732',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Hispanic',
#   '196',
#   '17.5',
#   '20'],
#  ['row-uc7x-7zkw.xn3c',
#   '00000000-0000-0000-7D4C-6F3C78ADBCA0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Assault (Homicide: Y87.1, X85-Y09)',
#   'M',
#   'Hispanic',
#   '114',
#   '10.5',
#   '9.9'],
#  ['row-qe96~ecst~4eak',
#   '00000000-0000-0000-BABC-999DB443B47A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Asian and Pacific Islander',
#   '56',
#   '11.6',
#   '16.2'],
#  ['row-e3ze-u4sr_srks',
#   '00000000-0000-0000-F7B9-F913C3F2A3B2',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Hispanic',
#   '116',
#   '9.2',
#   '10.1'],
#  ['row-34nv.78cg_rqsu',
#   '00000000-0000-0000-5BE3-2A75911E5AD8',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Not Stated/Unknown',
#   '8',
#   '.',
#   '.'],
#  ['row-99pa_39ti.pu7u',
#   '00000000-0000-0000-05E0-2CF9FE11A0ED',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'All Other Causes',
#   'M',
#   'Black Non-Hispanic',
#   '1375',
#   '159.3',
#   '177.8'],
#  ['row-px3e~e7u9-3bxe',
#   '00000000-0000-0000-71E5-2496086D8623',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Black Non-Hispanic',
#   '137',
#   '16.1',
#   '22'],
#  ['row-67iq~7trj~xub2',
#   '00000000-0000-0000-F925-FB70A6A5CBE8',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'All Other Causes',
#   'M',
#   'Hispanic',
#   '1167',
#   '102.1',
#   '150'],
#  ['row-7b5j-twyu_tky6',
#   '00000000-0000-0000-296D-3A4DA96E0037',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Not Stated/Unknown',
#   '70',
#   '.',
#   '.'],
#  ['row-yggc-m3gu~4mq5',
#   '00000000-0000-0000-0261-8227FC2A1534',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Asian and Pacific Islander',
#   '25',
#   '5.2',
#   '8.3'],
#  ['row-jgr8-y4h9_nvdv',
#   '00000000-0000-0000-AA35-3C011678F891',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'All Other Causes',
#   'M',
#   'White Non-Hispanic',
#   '1749',
#   '130.7',
#   '115.9'],
#  ['row-8khv_izpa~y2ja',
#   '00000000-0000-0000-9046-5A5DAD662F23',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'White Non-Hispanic',
#   '618',
#   '45.9',
#   '36.7'],
#  ['row-ew74~zd8k.tz9i',
#   '00000000-0000-0000-84E1-B3DDC0344DEB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'All Other Causes',
#   'F',
#   'Hispanic',
#   '1007',
#   '82.7',
#   '94.6'],
#  ['row-sb9w~b2um_4htn',
#   '00000000-0000-0000-6AB4-6BB49FED524B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)',
#   'F',
#   'Not Stated/Unknown',
#   '8',
#   '.',
#   '.'],
#  ['row-dz82-53fi.464y',
#   '00000000-0000-0000-71E0-873EF486FF5E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'White Non-Hispanic',
#   '229',
#   '15.9',
#   '9.5'],
#  ['row-6dae_4dbu.jwa9',
#   '00000000-0000-0000-EA18-C9BE79C3606F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Asian and Pacific Islander',
#   '48',
#   '9.6',
#   '14.1'],
#  ['row-tjth-t7ba~xp6c',
#   '00000000-0000-0000-7B9F-790D082A935D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Not Stated/Unknown',
#   '45',
#   '.',
#   '.'],
#  ['row-t58r-5iwn_my62',
#   '00000000-0000-0000-CA5D-B4C9DAE73978',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'White Non-Hispanic',
#   '290',
#   '21.7',
#   '18.2'],
#  ['row-5x5z-29we~k6qy',
#   '00000000-0000-0000-7298-2111FFBCD3D7',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'White Non-Hispanic',
#   '3518',
#   '245.2',
#   '167.4'],
#  ['row-9xv6_tumu.8dxx',
#   '00000000-0000-0000-1205-C803AEC20518',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'All Other Causes',
#   'M',
#   'Asian and Pacific Islander',
#   '308',
#   '59.2',
#   '77.2'],
#  ['row-kznr_ckh9~bxf8',
#   '00000000-0000-0000-20E7-9366160F5171',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Asian and Pacific Islander',
#   '105',
#   '18.3',
#   '25'],
#  ['row-ttvn_aac6~7wqb',
#   '00000000-0000-0000-BB0F-15D9638B7178',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Other Race/ Ethnicity',
#   '7',
#   '.',
#   '.'],
#  ['row-q4fc_exv8_xmfx',
#   '00000000-0000-0000-7150-78D2F7DF08EB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Hispanic',
#   '122',
#   '10.3',
#   '11.3'],
#  ['row-f2jh.6zxz~hxuq',
#   '00000000-0000-0000-90AB-F33C9B92931C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Hispanic',
#   '1080',
#   '97.7',
#   '165.9'],
#  ['row-z78d~vhzf-kfua',
#   '00000000-0000-0000-C6E0-83137A4A9430',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)',
#   'M',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-tu8v-39hk.9a93',
#   '00000000-0000-0000-F0AB-E2B6CB8406BB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-myci~hamc~akw8',
#   '00000000-0000-0000-6F92-EEA8BA564AD7',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Assault (Homicide: Y87.1, X85-Y09)',
#   'M',
#   'Other Race/ Ethnicity',
#   '5',
#   '.',
#   '.'],
#  ['row-fgdj_qi4n~sfw9',
#   '00000000-0000-0000-0D4A-025016A8D765',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Atherosclerosis (I70)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-vgba_uv8e_rifn',
#   '00000000-0000-0000-720B-060FB41DB400',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)',
#   'M',
#   'Asian and Pacific Islander',
#   '14',
#   '2.8',
#   '4.9'],
#  ['row-ptea-tn4t~dbmb',
#   '00000000-0000-0000-7D24-EC30A4A1759C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'M',
#   'Black Non-Hispanic',
#   '1320',
#   '154.3',
#   '175'],
#  ['row-3ayp~w49a_hh5i',
#   '00000000-0000-0000-7557-ED82D96E47EC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Insitu or Benign / Uncertain Neoplasms (D00-D48)',
#   'F',
#   'Not Stated/Unknown',
#   '5',
#   '.',
#   '.'],
#  ['row-7jjv~hk63.6tvx',
#   '00000000-0000-0000-8C8A-D8B6928BE797',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'F',
#   'Black Non-Hispanic',
#   '107',
#   '10.2',
#   '8.7'],
#  ['row-5sk6~ktdd~pfny',
#   '00000000-0000-0000-41ED-14DF9EAB5700',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'Not Stated/Unknown',
#   '11',
#   '.',
#   '.'],
#  ['row-d3sa_zvpm~tj8a',
#   '00000000-0000-0000-1312-782AED1529B7',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Not Stated/Unknown',
#   '12',
#   '.',
#   '.'],
#  ['row-383h-cahe_yjsj',
#   '00000000-0000-0000-677C-8CF669C3069B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Hispanic',
#   '111',
#   '9.9',
#   '18.3'],
#  ['row-yxv2-ttvn~xizf',
#   '00000000-0000-0000-C823-3AD823D98F01',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Not Stated/Unknown',
#   '76',
#   '.',
#   '.'],
#  ['row-h28m-wkq6.2s65',
#   '00000000-0000-0000-ADC0-681887123184',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-5s5w.etya~w5ew',
#   '00000000-0000-0000-8083-01F7A9BD0E76',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-4ins.3t65_5kvx',
#   '00000000-0000-0000-CC04-4040155D3C78',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Asian and Pacific Islander',
#   '70',
#   '13',
#   '17.5'],
#  ['row-9ug6-3bfz.sb3p',
#   '00000000-0000-0000-7F2E-DF0A6ACAA0F6',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Hispanic',
#   '222',
#   '17.8',
#   '19.8'],
#  ['row-z2c9_vt3f.hss5',
#   '00000000-0000-0000-9969-0D6A6FF2931A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'F',
#   'Hispanic',
#   '63',
#   '5',
#   '4.9'],
#  ['row-eycg.4zna~gep6',
#   '00000000-0000-0000-E9DC-8C7D66166D0D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-fmw5-yk3u_65za',
#   '00000000-0000-0000-23DA-BAD989EB2B3B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Hispanic',
#   '60',
#   '4.8',
#   '5.1'],
#  ['row-xfin~nv7a-ebys',
#   '00000000-0000-0000-AEF1-24A6FDCBEF77',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Asian and Pacific Islander',
#   '89',
#   '15.8',
#   '19.2'],
#  ['row-i4sv.gfdj.i63g',
#   '00000000-0000-0000-21FC-70978A35A130',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Certain Conditions originating in the Perinatal Period (P00-P96)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-h846~fi5t~utsc',
#   '00000000-0000-0000-6C80-592BE7E8ABC8',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Hispanic',
#   '177',
#   '16.2',
#   '27.6'],
#  ['row-e95s.m36c.445c',
#   '00000000-0000-0000-9E40-69E15FD4856B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Black Non-Hispanic',
#   '220',
#   '21',
#   '17.9'],
#  ['row-rr6a.x5zx-nkd4',
#   '00000000-0000-0000-6B7B-800F1BFF4D25',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Asian and Pacific Islander',
#   '58',
#   '11.3',
#   '15.8'],
#  ['row-7u9j_a86c~h4mj',
#   '00000000-0000-0000-9BBB-4978A3481B1E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-7j24.jphm~cmxp',
#   '00000000-0000-0000-E0E3-CA39BD3D39B9',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'All Other Causes',
#   'M',
#   'Black Non-Hispanic',
#   '1216',
#   '143.2',
#   '163.5'],
#  ['row-jztv.gevv~2sit',
#   '00000000-0000-0000-C498-B354506010B2',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'All Other Causes',
#   'F',
#   'Not Stated/Unknown',
#   '79',
#   '.',
#   '.'],
#  ['row-k2kw.t484.uudw',
#   '00000000-0000-0000-4766-39985BAB1C23',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'White Non-Hispanic',
#   '4085',
#   '303.5',
#   '244.3'],
#  ['row-aupt~7r4r-cesn',
#   '00000000-0000-0000-CED5-ADC90C6AE7AE',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Asian and Pacific Islander',
#   '428',
#   '83.1',
#   '115.2'],
#  ['row-dyse~mwbk_sm49',
#   '00000000-0000-0000-3090-1E8FE85108BE',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'White Non-Hispanic',
#   '292',
#   '21.7',
#   '18.1'],
#  ['row-xuz2~yyhj_bwt7',
#   '00000000-0000-0000-0A39-889A926FF9EB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Asian and Pacific Islander',
#   '76',
#   '14.1',
#   '20.9'],
#  ['row-gnck.qgpt-2nme',
#   '00000000-0000-0000-B1EE-B6280D8BCB4D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Hispanic',
#   '1045',
#   '85.9',
#   '98.5'],
#  ['row-s2iq-je9q_vntu',
#   '00000000-0000-0000-EB75-DB416A954A83',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Not Stated/Unknown',
#   '9',
#   '.',
#   '.'],
#  ['row-2m5a.grt9~fh46',
#   '00000000-0000-0000-69C5-7E7BF4199C07',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Black Non-Hispanic',
#   '223',
#   '26.1',
#   '25.8'],
#  ['row-3ykd~cwh6-nxue',
#   '00000000-0000-0000-96DD-E9844DA03D1E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Asian and Pacific Islander',
#   '30',
#   '5.3',
#   '6.6'],
#  ['row-8e3w~7dcf_afjp',
#   '00000000-0000-0000-F95B-3390783535A4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'White Non-Hispanic',
#   '629',
#   '43.8',
#   '23.1'],
#  ['row-a5ds~r6gw~6wte',
#   '00000000-0000-0000-C515-62C0EE88B6AB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Not Stated/Unknown',
#   '47',
#   '.',
#   '.'],
#  ['row-t365.uccc-r2cv',
#   '00000000-0000-0000-533A-5EFB1DB28FF2',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Other Race/ Ethnicity',
#   '11',
#   '.',
#   '.'],
#  ['row-ubbp_7rub.9s95',
#   '00000000-0000-0000-E677-1CC4D63F7716',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'M',
#   'Other Race/ Ethnicity',
#   '6',
#   '.',
#   '.'],
#  ['row-46wq.m5tb~gcjr',
#   '00000000-0000-0000-FD17-22206F7AD79D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Viral Hepatitis (B15-B19)',
#   'M',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-gfy3.ub2m~q5wf',
#   '00000000-0000-0000-1043-57940DAB607B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'White Non-Hispanic',
#   '458',
#   '31.9',
#   '19.1'],
#  ['row-6s7w.y2gu-8ucr',
#   '00000000-0000-0000-6121-0F0BFA21E19C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'All Other Causes',
#   'M',
#   'White Non-Hispanic',
#   '1818',
#   '135.1',
#   '118.5'],
#  ['row-vy7v.e48x.4y37',
#   '00000000-0000-0000-4DDC-21DA5AAB5A3A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Hispanic',
#   '58',
#   '4.8',
#   '5.2'],
#  ['row-tq7q_bgi4.vhay',
#   '00000000-0000-0000-474C-5B5230E55A49',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'All Other Causes',
#   'F',
#   'Hispanic',
#   '1082',
#   '86.7',
#   '94'],
#  ['row-5tbt_9rcv~wniw',
#   '00000000-0000-0000-5BB8-83C2ABD45557',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'All Other Causes',
#   'F',
#   'White Non-Hispanic',
#   '2578',
#   '181.9',
#   '110.7'],
#  ['row-uhin~t2bu~6kad',
#   '00000000-0000-0000-0022-7C96E51B02BD',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-hq7t~dt3h.2q77',
#   '00000000-0000-0000-4646-F151CF46D8F3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Other Race/ Ethnicity',
#   '31',
#   '.',
#   '.'],
#  ['row-4djn.xgqv-e4xr',
#   '00000000-0000-0000-CD49-F69494A65D32',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Assault (Homicide: Y87.1, X85-Y09)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-thny~uj7z~gvxj',
#   '00000000-0000-0000-7A6C-1B57DF338495',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'Asian and Pacific Islander',
#   '63',
#   '11.4',
#   '12.8'],
#  ['row-2d39_4as5-9zkx',
#   '00000000-0000-0000-F8B3-3FC5F09D880D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'White Non-Hispanic',
#   '372',
#   '25.9',
#   '14.4'],
#  ['row-9xsp.h3yq~gnk6',
#   '00000000-0000-0000-C603-7FF5771FF9D4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Asian and Pacific Islander',
#   '46',
#   '8.1',
#   '10.2'],
#  ['row-vgse~46sq.mm8r',
#   '00000000-0000-0000-257B-FDE9A19AE580',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Hispanic',
#   '103',
#   '8.8',
#   '10.1'],
#  ['row-9vs2-v9fr.fqde',
#   '00000000-0000-0000-FBC1-9E1F9366552A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'White Non-Hispanic',
#   '271',
#   '20.2',
#   '18.4'],
#  ['row-sc2x-x7rg_u9sy',
#   '00000000-0000-0000-A005-33B08C8EAB2D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Chronic Liver Disease and Cirrhosis (K70, K73)',
#   'M',
#   'Asian and Pacific Islander',
#   '18',
#   '3.5',
#   '3.1'],
#  ['row-izp9.uani_8urt',
#   '00000000-0000-0000-6A8D-C0E6299B9DF2',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'All Other Causes',
#   'F',
#   'Hispanic',
#   '820',
#   '70.2',
#   '85.6'],
#  ['row-zcfb-fivm_8tpb',
#   '00000000-0000-0000-ACE7-7AF43957E92C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Black Non-Hispanic',
#   '137',
#   '16.1',
#   '22.7'],
#  ['row-t9yx~a4iz~33n5',
#   '00000000-0000-0000-D24F-6DCAE4D3D770',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'White Non-Hispanic',
#   '521',
#   '36.6',
#   '21.6'],
#  ['row-xfpb_pm6e~8khk',
#   '00000000-0000-0000-6B15-B4E2099B9F24',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-4tpp_hvkr~d7zr',
#   '00000000-0000-0000-D95B-43A11AC6BE53',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Certain Conditions originating in the Perinatal Period (P00-P96)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-zybi~ng2x.tc9g',
#   '00000000-0000-0000-6D1E-5E46DB6CA153',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Other Race/ Ethnicity',
#   '32',
#   '.',
#   '.'],
#  ['row-nf8a_ye5j_ghc7',
#   '00000000-0000-0000-743C-C9AE5E18F7B0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'M',
#   'Hispanic',
#   '188',
#   '15.9',
#   '16.6'],
#  ['row-8xdp~7vkd~fhrq',
#   '00000000-0000-0000-AD6C-39AC48726336',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Asian and Pacific Islander',
#   '43',
#   '8.9',
#   '16.7'],
#  ['row-bc94-i5ue-bs8x',
#   '00000000-0000-0000-937E-F7B6250E3171',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'White Non-Hispanic',
#   '347',
#   '25.9',
#   '21.8'],
#  ['row-3y3y.5g3u-qnfb',
#   '00000000-0000-0000-E2AA-E7E60D7B63DC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Other Race/ Ethnicity',
#   '5',
#   '.',
#   '.'],
#  ['row-3hrg_v3sd~g5sx',
#   '00000000-0000-0000-1E4D-F60236F512D6',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-bby7_egbh-4hiz',
#   '00000000-0000-0000-BE5E-D82885744E96',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Mental and Behavioral Disorders due to Use of Alcohol (F10)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-xqfp_jnsh_u9bg',
#   '00000000-0000-0000-8CBF-3F7FD84BE005',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Black Non-Hispanic',
#   '1918',
#   '183.2',
#   '163.3'],
#  ['row-xvyv_9p5t_dhf7',
#   '00000000-0000-0000-D3DE-B22C2D23291B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'F',
#   'Asian and Pacific Islander',
#   '327',
#   '56',
#   '65'],
#  ['row-86kk~2khk_4c9s',
#   '00000000-0000-0000-D514-0CFB292234D3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Asian and Pacific Islander',
#   '344',
#   '64.6',
#   '73.8'],
#  ['row-j2rr~ds7a-7q3h',
#   '00000000-0000-0000-69B5-3DE1FB75B077',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Other Race/ Ethnicity',
#   '19',
#   '.',
#   '.'],
#  ['row-iypp~bsyz.w5kb',
#   '00000000-0000-0000-5DFD-D1FED064FDDF',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'M',
#   'Not Stated/Unknown',
#   '17',
#   '.',
#   '.'],
#  ['row-pg2i_uatp-63u6',
#   '00000000-0000-0000-DB8E-78DCDA402464',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'All Other Causes',
#   'M',
#   'Other Race/ Ethnicity',
#   '74',
#   '.',
#   '.'],
#  ['row-u9f7~8iia~5p3z',
#   '00000000-0000-0000-E503-8D5C23017162',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   "Alzheimer's Disease (G30)",
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-ttxb.cdkr.5vft',
#   '00000000-0000-0000-F893-CA314C17DE23',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Asian and Pacific Islander',
#   '58',
#   '11.4',
#   '15.5'],
#  ['row-jjgq~jetb_kjr6',
#   '00000000-0000-0000-C517-981FD2977CB3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Asian and Pacific Islander',
#   '60',
#   '11.4',
#   '14.3'],
#  ['row-snui-2viq-whmv',
#   '00000000-0000-0000-34FA-326E4A1486F1',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Black Non-Hispanic',
#   '267',
#   '25.5',
#   '23.6'],
#  ['row-2aph-abrt.ytwv',
#   '00000000-0000-0000-0A34-2CE8E9494979',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Asian and Pacific Islander',
#   '48',
#   '9.4',
#   '13.3'],
#  ['row-th7w~ykdv_7utm',
#   '00000000-0000-0000-12D5-F1CE4AF44F9E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-43h3.67yz_yn89',
#   '00000000-0000-0000-7220-E49B18DEF8ED',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Other Race/ Ethnicity',
#   '8',
#   '.',
#   '.'],
#  ['row-qbs5.4qdt-5x3r',
#   '00000000-0000-0000-3D30-2F2E9730CD3E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Hispanic',
#   '101',
#   '8.2',
#   '9.5'],
#  ['row-5jtk-ibjf-wepy',
#   '00000000-0000-0000-CBC5-6B24117DFD79',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Asian and Pacific Islander',
#   '31',
#   '6.2',
#   '9.8'],
#  ['row-75qw_s56u-52ak',
#   '00000000-0000-0000-10E9-C14830E44352',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Other Race/ Ethnicity',
#   '7',
#   '.',
#   '.'],
#  ['row-z8ux.3asn-qjq4',
#   '00000000-0000-0000-2E56-5104547E1CAA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-sz72-5rkg~t7ej',
#   '00000000-0000-0000-67BA-A1B9BD54596C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Certain Conditions originating in the Perinatal Period (P00-P96)',
#   'M',
#   'Not Stated/Unknown',
#   '25',
#   '.',
#   '.'],
#  ['row-ugui~jgc8_5rpn',
#   '00000000-0000-0000-6595-A420DD6D2212',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'F',
#   'Asian and Pacific Islander',
#   '33',
#   '5.6',
#   '5.8'],
#  ['row-wsmg-p9kr.egud',
#   '00000000-0000-0000-9DA8-FFBC6C84532D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Asian and Pacific Islander',
#   '402',
#   '68.8',
#   '81.2'],
#  ['row-nj6f_4p7m_dqq8',
#   '00000000-0000-0000-4BAA-01A108CC692D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Not Stated/Unknown',
#   '15',
#   '.',
#   '.'],
#  ['row-b49c-pd6c-8bm5',
#   '00000000-0000-0000-01B9-9AD24567178A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'White Non-Hispanic',
#   '7050',
#   '491.4',
#   '250.7'],
#  ['row-xqa3-x4gn.pepf',
#   '00000000-0000-0000-1723-D16F185456A8',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Black Non-Hispanic',
#   '154',
#   '18.1',
#   '22.8'],
#  ['row-836s-iuwr~s28h',
#   '00000000-0000-0000-90C2-7D95B4CAB925',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Septicemia (A40-A41)',
#   'F',
#   'Asian and Pacific Islander',
#   '16',
#   '2.7',
#   '2.9'],
#  ['row-n99f-wqps.qfns',
#   '00000000-0000-0000-B64B-D793F47BF9AD',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'Other Race/ Ethnicity',
#   '5',
#   '.',
#   '.'],
#  ['row-7yuf~br4d_bcc4',
#   '00000000-0000-0000-F98E-167368FA955B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Hispanic',
#   '1348',
#   '110',
#   '131.8'],
#  ['row-6jax_x78a~y8rf',
#   '00000000-0000-0000-D2CB-E109C71C336F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-3js6.hr8y-crut',
#   '00000000-0000-0000-7D13-62B39EC4606D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'White Non-Hispanic',
#   '156',
#   '11.6',
#   '9.3'],
#  ['row-pzbh~2agg.q7t8',
#   '00000000-0000-0000-2977-23DD715FF853',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'M',
#   'Hispanic',
#   '1199',
#   '102.6',
#   '150.5'],
#  ['row-cfzb_6b3v~yxeq',
#   '00000000-0000-0000-406B-F93463A385FC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Not Stated/Unknown',
#   '86',
#   '.',
#   '.'],
#  ['row-qzbz~b6k6-9rcv',
#   '00000000-0000-0000-29BD-7AA801372FDA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'White Non-Hispanic',
#   '529',
#   '39.4',
#   '32.7'],
#  ['row-4ap5-bvuq-zmui',
#   '00000000-0000-0000-6643-0FE981958848',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Septicemia (A40-A41)',
#   'F',
#   'White Non-Hispanic',
#   '135',
#   '9.5',
#   '5'],
#  ['row-fqy6-eiey~8xk7',
#   '00000000-0000-0000-4371-11A7214FCBBD',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   "Alzheimer's Disease (G30)",
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-8gmw_sfcf~yryk',
#   '00000000-0000-0000-290D-2D19EDC4AD79',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-ezp3_q4bt_q9yd',
#   '00000000-0000-0000-B62E-8F69A7B3848D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Black Non-Hispanic',
#   '2269',
#   '217.1',
#   '183.9'],
#  ['row-3iyh.7wdq.4rst',
#   '00000000-0000-0000-9997-270DDB190B06',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Hispanic',
#   '1382',
#   '123.1',
#   '227.9'],
#  ['row-r9qu.xxya_ndtt',
#   '00000000-0000-0000-53EF-666941B1854A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'White Non-Hispanic',
#   '142',
#   '10.6',
#   '8.8'],
#  ['row-s9cb_5gjf~t6a6',
#   '00000000-0000-0000-306D-39D3AB6FA6F4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Hispanic',
#   '1327',
#   '121.7',
#   '238.4'],
#  ['row-ib8z.y45n.76wv',
#   '00000000-0000-0000-549B-A1A582E3D03C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Not Stated/Unknown',
#   '5',
#   '.',
#   '.'],
#  ['row-uujc~hja6.ve7e',
#   '00000000-0000-0000-C56B-E6457E1F5316',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'All Other Causes',
#   'M',
#   'Hispanic',
#   '988',
#   '90.6',
#   '142.6'],
#  ['row-5zbz_qe3i-m3jr',
#   '00000000-0000-0000-86B8-027ACD92F9FA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Hispanic',
#   '132',
#   '11.9',
#   '22.8'],
#  ['row-heue-57vg-evnw',
#   '00000000-0000-0000-9C6A-8A669B847EA7',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'All Other Causes',
#   'F',
#   'Asian and Pacific Islander',
#   '214',
#   '40.2',
#   '50.3'],
#  ['row-eiu2.5xut~7qjc',
#   '00000000-0000-0000-D794-46227F59B1AE',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'White Non-Hispanic',
#   '231',
#   '16.1',
#   '9.8'],
#  ['row-g6wn-d5ws_857m',
#   '00000000-0000-0000-0926-EF0F90990A34',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Chronic Liver Disease and Cirrhosis (K70, K73)',
#   'M',
#   'Not Stated/Unknown',
#   '10',
#   '.',
#   '.'],
#  ['row-9kjw~tcen.kru9',
#   '00000000-0000-0000-655A-EBA800603CBF',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)',
#   'M',
#   'Asian and Pacific Islander',
#   '14',
#   '2.8',
#   '3'],
#  ['row-zxtx.m3aq~ezi2',
#   '00000000-0000-0000-49A2-512E96608BCB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Certain Conditions originating in the Perinatal Period (P00-P96)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-i6k3~5ts4~fb2z',
#   '00000000-0000-0000-5907-377DF7DAE641',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Asian and Pacific Islander',
#   '18',
#   '3.3',
#   '4.6'],
#  ['row-syzj.cjyh_xr32',
#   '00000000-0000-0000-7915-ABC0E76D5314',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Hispanic',
#   '221',
#   '17.7',
#   '19.6'],
#  ['row-73u5-v4yt_dzhy',
#   '00000000-0000-0000-FEE8-F56CF6857DDA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'F',
#   'Black Non-Hispanic',
#   '102',
#   '9.7',
#   '8.5'],
#  ['row-3qxn_pgeu~cpjj',
#   '00000000-0000-0000-E564-BFBD01BA9D84',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'F',
#   'Black Non-Hispanic',
#   '227',
#   '21.7',
#   '20'],
#  ['row-j676-3nrn_egbh',
#   '00000000-0000-0000-8ED9-9C4667B2A4CF',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'All Other Causes',
#   'M',
#   'Asian and Pacific Islander',
#   '221',
#   '45.7',
#   '61.2'],
#  ['row-vmgy.tz9v-pbuf',
#   '00000000-0000-0000-C2A6-7A079A62E19D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Black Non-Hispanic',
#   '204',
#   '19.5',
#   '16.9'],
#  ['row-rj3u~ccev.fs8p',
#   '00000000-0000-0000-547D-EC04EEF82F59',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'White Non-Hispanic',
#   '258',
#   '19.2',
#   '16.4'],
#  ['row-yqwf.fe45.8wxg',
#   '00000000-0000-0000-EAFC-225C44A366FE',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'White Non-Hispanic',
#   '5168',
#   '384.2',
#   '319.8'],
#  ['row-wg59_ihz4.qfmq',
#   '00000000-0000-0000-926E-6D3B940AB95E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'M',
#   'Hispanic',
#   '138',
#   '12.1',
#   '12.9'],
#  ['row-ajw2_tzms-qq6w',
#   '00000000-0000-0000-BAFE-BEEB90809B9F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'White Non-Hispanic',
#   '238',
#   '16.7',
#   '10.4'],
#  ['row-zwrs_dn4n-p752',
#   '00000000-0000-0000-F78A-7A7433DDACBA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Asian and Pacific Islander',
#   '473',
#   '95',
#   '123.5'],
#  ['row-n2uw.24r9~f7es',
#   '00000000-0000-0000-3D26-3A9961C2A352',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'M',
#   'Not Stated/Unknown',
#   '13',
#   '.',
#   '.'],
#  ['row-tar9.bbng~su2g',
#   '00000000-0000-0000-38ED-040575B45E97',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-uscu_axwm.y49v',
#   '00000000-0000-0000-44D5-C8C02C5F35CD',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Asian and Pacific Islander',
#   '448',
#   '81.6',
#   '108.7'],
#  ['row-ht5k_s6m5.k2y8',
#   '00000000-0000-0000-BE51-6D1D9570288F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Hispanic',
#   '168',
#   '13.8',
#   '16.7'],
#  ['row-j3za.vgim.jcdt',
#   '00000000-0000-0000-15C9-15F5C7390535',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'All Other Causes',
#   'M',
#   'Hispanic',
#   '1067',
#   '95',
#   '138.1'],
#  ['row-hzn3_v475_4xjp',
#   '00000000-0000-0000-1119-8EC5610611A0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'White Non-Hispanic',
#   '3361',
#   '250.4',
#   '214.3'],
#  ['row-ge2a_ef2m.x88b',
#   '00000000-0000-0000-B854-58988AF79C90',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Black Non-Hispanic',
#   '154',
#   '18.1',
#   '21.7'],
#  ['row-9q29~fy7y.rtyx',
#   '00000000-0000-0000-ED31-25BA7F78472E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'White Non-Hispanic',
#   '265',
#   '19.7',
#   '16.4'],
#  ['row-npt3~isiu.cymx',
#   '00000000-0000-0000-DE38-CE1A30A1CEC4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'White Non-Hispanic',
#   '371',
#   '27.6',
#   '23.3'],
#  ['row-6v5k~mzje_nj5f',
#   '00000000-0000-0000-B252-E14B4560C06D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'Asian and Pacific Islander',
#   '54',
#   '10.4',
#   '13.7'],
#  ['row-6srn~4t7w_v82i',
#   '00000000-0000-0000-F9C4-A672960DD9CC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'White Non-Hispanic',
#   '246',
#   '18.3',
#   '15.6'],
#  ['row-s2u5.xtqy.ik9t',
#   '00000000-0000-0000-415A-B1D3C980661C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Septicemia (A40-A41)',
#   'M',
#   'Other Race/ Ethnicity',
#   '6',
#   '.',
#   '.'],
#  ['row-b3em~6mtb.knj2',
#   '00000000-0000-0000-161C-7CA1A0948810',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-6i7a-w3rp-hc4m',
#   '00000000-0000-0000-F894-7BF66EB4119C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Asian and Pacific Islander',
#   '496',
#   '102.5',
#   '157.8'],
#  ['row-gi6w-m3dq-hr6k',
#   '00000000-0000-0000-F376-A8D061650946',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'M',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-85nh~xpt9_ae79',
#   '00000000-0000-0000-F092-70B7228C4DF1',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Black Non-Hispanic',
#   '2722',
#   '258.6',
#   '247.3'],
#  ['row-jrk3.rb28~gsk8',
#   '00000000-0000-0000-ACBD-BB3D3310CC53',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Other Race/ Ethnicity',
#   '6',
#   '.',
#   '.'],
#  ['row-u7vm-m6rb~4p7e',
#   '00000000-0000-0000-3128-15707F1CC155',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Black Non-Hispanic',
#   '356',
#   '41.9',
#   '41.8'],
#  ['row-j4uu~axp8_era5',
#   '00000000-0000-0000-8FB3-7A5924B456CC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Black Non-Hispanic',
#   '206',
#   '19.6',
#   '17.7'],
#  ['row-7uvw~cg5a~knaa',
#   '00000000-0000-0000-31B4-773C72A7EB8F',
# ...
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'M',
#   'Other Race/ Ethnicity',
#   '24',
#   '.',
#   '.'],
#  ['row-g5yc-63gx-uv5c',
#   '00000000-0000-0000-96C9-863A51C1B9F3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'White Non-Hispanic',
#   '5016',
#   '354.1',
#   '179.8'],
#  ['row-pma7~jfz4~fuw7',
#   '00000000-0000-0000-5ACB-45431D084298',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-6w9u~rhwm~dfkr',
#   '00000000-0000-0000-9240-A2B41CB5AEBF',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ['row-c5kc-5xk7.qjpq',
#   '00000000-0000-0000-DB1C-98CFA39E606E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-zgrn.z5uf_65r5',
#   '00000000-0000-0000-6B30-677B26C8B395',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'White Non-Hispanic',
#   '240',
#   '16.9',
#   '10.3'],
#  ['row-ui6z_ipyf~jbut',
#   '00000000-0000-0000-EFBC-46CB6445B9D4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Asian and Pacific Islander',
#   '30',
#   '5.5',
#   '7.4'],
#  ['row-dpcp-fy4s_e7i2',
#   '00000000-0000-0000-CD08-25D01796449F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Not Stated/Unknown',
#   '5',
#   '.',
#   '.'],
#  ['row-gvwe-vj4w-qu4z',
#   '00000000-0000-0000-8C10-BFE7A760A54C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Hispanic',
#   '71',
#   '6.1',
#   '7.1'],
#  ['row-wmf7-izee-ucee',
#   '00000000-0000-0000-AF3D-16FB2BC84269',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   "Alzheimer's Disease (G30)",
#   'F',
#   'White Non-Hispanic',
#   '276',
#   '19.5',
#   '8.6'],
#  ['row-s5dg.yney_dz4m',
#   '00000000-0000-0000-91B6-1867F187DE65',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Not Stated/Unknown',
#   '9',
#   '.',
#   '.'],
#  ['row-egne.ap5u~iyyt',
#   '00000000-0000-0000-DE9B-1C3C2A989E93',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Not Stated/Unknown',
#   '11',
#   '.',
#   '.'],
#  ['row-8566~rrnb-qxgr',
#   '00000000-0000-0000-A264-AE8193D7E544',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'White Non-Hispanic',
#   '437',
#   '32.5',
#   '26.4'],
#  ['row-cq3p.ni4k_q88i',
#   '00000000-0000-0000-7DB1-3CF873D8C13B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Intentional Self-Harm (Suicide: X60-X84, Y87.0)',
#   'F',
#   'Other Race/ Ethnicity',
#   '5',
#   '.',
#   '.'],
#  ['row-y5md-masy-yua5',
#   '00000000-0000-0000-4D49-30D6032242C1',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'All Other Causes',
#   'M',
#   'Other Race/ Ethnicity',
#   '27',
#   '.',
#   '.'],
#  ['row-vu8j.vxn6~7epy',
#   '00000000-0000-0000-1FD7-ECC8B98CC918',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Black Non-Hispanic',
#   '1756',
#   '167.6',
#   '156.3'],
#  ['row-6r5f-hxnd~58pi',
#   '00000000-0000-0000-4D52-F96F0151EC7C',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Chronic Liver Disease and Cirrhosis (K70, K73)',
#   'M',
#   'Other Race/ Ethnicity',
#   '10',
#   '.',
#   '.'],
#  ['row-jmxm_i8bf_zvne',
#   '00000000-0000-0000-D84F-50562ECA8D57',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Asian and Pacific Islander',
#   '554',
#   '108.5',
#   '158.8'],
#  ['row-64dk.fqea-2ava',
#   '00000000-0000-0000-C390-101420C0B316',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'All Other Causes',
#   'M',
#   'Hispanic',
#   '1069',
#   '96.7',
#   '139.5'],
#  ['row-84bc-fy22~x9h5',
#   '00000000-0000-0000-3ADF-A7C1981677A0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Black Non-Hispanic',
#   '1735',
#   '165.7',
#   '151.1'],
#  ['row-r3xj-kzez~4bhs',
#   '00000000-0000-0000-F8DF-43FFEBB482EC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'White Non-Hispanic',
#   '3184',
#   '237.7',
#   '200.7'],
#  ['row-xhmi_k3dq-wtcc',
#   '00000000-0000-0000-029E-1B77D963AC43',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'Other Race/ Ethnicity',
#   '8',
#   '.',
#   '.'],
#  ['row-h2v8.xfw6~2ha4',
#   '00000000-0000-0000-80AE-3864713FBFDA',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Black Non-Hispanic',
#   '178',
#   '20.9',
#   '27.7'],
#  ['row-xrfg_zsm8~k2at',
#   '00000000-0000-0000-7568-ABE05F33924F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Black Non-Hispanic',
#   '186',
#   '21.5',
#   '25.4'],
#  ['row-74md~rjn8~r5b7',
#   '00000000-0000-0000-3218-CEDD6A4B014D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'Asian and Pacific Islander',
#   '34',
#   '5.8',
#   '6.4'],
#  ['row-d7ca_5nw2_hp57',
#   '00000000-0000-0000-BE4E-006131004AC8',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'White Non-Hispanic',
#   '3371',
#   '238',
#   '161.1'],
#  ['row-zbue~iqtq.m45r',
#   '00000000-0000-0000-E2A2-BDBC6A8390D6',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Diabetes Mellitus (E10-E14)',
#   'M',
#   'Hispanic',
#   '172',
#   '15.3',
#   '25.4'],
#  ['row-9mmu-gxqg_2sgy',
#   '00000000-0000-0000-CF55-5F4362E5951D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'F',
#   'White Non-Hispanic',
#   '390',
#   '27.1',
#   '15.2'],
#  ['row-f6mb_j6i5_4r52',
#   '00000000-0000-0000-6F19-D122053F5FFC',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Hispanic',
#   '156',
#   '13.2',
#   '16.8'],
#  ['row-wq3q.swnf.2rwh',
#   '00000000-0000-0000-BD0D-77B0F8BC1BA1',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'White Non-Hispanic',
#   '169',
#   '11.9',
#   '7.4'],
#  ['row-2y7q.tjxq_tt8w',
#   '00000000-0000-0000-B6B4-7497B4A920AB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Black Non-Hispanic',
#   '242',
#   '28',
#   '33.9'],
#  ['row-3r5k-p89q-92xu',
#   '00000000-0000-0000-A108-9E222D222D30',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Black Non-Hispanic',
#   '200',
#   '23.4',
#   '28.1'],
#  ['row-hrxh.zdm8-4z29',
#   '00000000-0000-0000-BDB4-20E835C3AE36',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Viral Hepatitis (B15-B19)',
#   'M',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-5fq6~bzhd~nn6x',
#   '00000000-0000-0000-0DD4-68AB131E6899',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'F',
#   'Not Stated/Unknown',
#   '36',
#   '.',
#   '.'],
#  ['row-sz9k_3sth-e7zc',
#   '00000000-0000-0000-A7CA-2C54624D0D9A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'M',
#   'Black Non-Hispanic',
#   '134',
#   '15.8',
#   '20.9'],
#  ['row-zx3y.gp9j-id69',
#   '00000000-0000-0000-1785-07FDCEDFAD9A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'White Non-Hispanic',
#   '286',
#   '21.4',
#   '18.8'],
#  ['row-th27_ftsq-swcu',
#   '00000000-0000-0000-B58E-019ED7B10E6D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Hispanic',
#   '1180',
#   '105.1',
#   '172.2'],
#  ['row-54nn~gs5f~txtw',
#   '00000000-0000-0000-931E-AAD0B68F9E55',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Hispanic',
#   '140',
#   '12.3',
#   '21.4'],
#  ['row-km73_qt72-ccwc',
#   '00000000-0000-0000-FD49-5C01FE33BA46',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Not Stated/Unknown',
#   '6',
#   '.',
#   '.'],
#  ['row-x4k4.62me-n9gn',
#   '00000000-0000-0000-F4B8-EF60F3EC983B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Black Non-Hispanic',
#   '295',
#   '28',
#   '26.9'],
#  ['row-bqp2_ju59~2euu',
#   '00000000-0000-0000-BEAE-C190428C14E4',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'All Other Causes',
#   'F',
#   'Other Race/ Ethnicity',
#   '38',
#   '.',
#   '.'],
#  ['row-qkwf.2kss.b8uw',
#   '00000000-0000-0000-2C47-9E5F76D03F2A',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Cerebrovascular Disease (Stroke: I60-I69)',
#   'M',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-qwwd~vzes-bpyu',
#   '00000000-0000-0000-BFE4-2D20E8E15CCB',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'All Other Causes',
#   'M',
#   'Not Stated/Unknown',
#   '32',
#   '.',
#   '.'],
#  ['row-tbj7~yxnz.zje6',
#   '00000000-0000-0000-FBA1-F62057E157F0',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Hispanic',
#   '228',
#   '18.7',
#   '23.1'],
#  ['row-fu53_4zh7_vrji',
#   '00000000-0000-0000-0586-E5ED5C33948E',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'F',
#   'White Non-Hispanic',
#   '162',
#   '11.3',
#   '7.3'],
#  ['row-p3v7.te34~zrgy',
#   '00000000-0000-0000-1798-724E4C7C3670',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Not Stated/Unknown',
#   '12',
#   '.',
#   '.'],
#  ['row-sapw.8pte-esms',
#   '00000000-0000-0000-9936-788912CAD547',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'M',
#   'Black Non-Hispanic',
#   '184',
#   '21.4',
#   '26.1'],
#  ['row-hg9h-hhhq_st4x',
#   '00000000-0000-0000-8EDB-836E7BE30D55',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'White Non-Hispanic',
#   '3356',
#   '250.9',
#   '213.7'],
#  ['row-phv4_7cdh-3tb7',
#   '00000000-0000-0000-D568-A863D0E5B268',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'White Non-Hispanic',
#   '4495',
#   '335.1',
#   '277'],
#  ['row-pcu3.x9rc_3m3z',
#   '00000000-0000-0000-38DF-0B7395E777F3',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Essential Hypertension and Renal Diseases (I10, I12)',
#   'F',
#   'Black Non-Hispanic',
#   '225',
#   '21.5',
#   '18.7'],
#  ['row-8wv8.63di~vmpw',
#   '00000000-0000-0000-1D8C-77D9108732A9',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Hispanic',
#   '190',
#   '16.3',
#   '22.3'],
#  ['row-5s38~6sbm~i7j6',
#   '00000000-0000-0000-E51A-E47902919E1D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#   'M',
#   'Not Stated/Unknown',
#   '16',
#   '.',
#   '.'],
#  ['row-tg5c.27mu-q7xp',
#   '00000000-0000-0000-D054-DFF9067D3C3B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'All Other Causes',
#   'F',
#   'Black Non-Hispanic',
#   '1483',
#   '141.9',
#   '127.3'],
#  ['row-8mj2-h8us~t8gr',
#   '00000000-0000-0000-FDB6-2FDFE1708F50',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2013',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Not Stated/Unknown',
#   '18',
#   '.',
#   '.'],
#  ['row-j3b8_r6am-z3si',
#   '00000000-0000-0000-0759-A1E1F6B7AC81',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2011',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Black Non-Hispanic',
#   '410',
#   '39.2',
#   '34.7'],
#  ['row-yif3_eiai-rhai',
#   '00000000-0000-0000-D64B-8165759222C5',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Certain Conditions originating in the Perinatal Period (P00-P96)',
#   'F',
#   'Not Stated/Unknown',
#   '.',
#   '.',
#   '.'],
#  ['row-paab_3tmq.53rc',
#   '00000000-0000-0000-2EBB-3F4080E2B275',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#   'M',
#   'Hispanic',
#   '218',
#   '20',
#   '23.1'],
#  ['row-tctg~ne52~63n5',
#   '00000000-0000-0000-3FA8-709BFE51B9CF',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   "Alzheimer's Disease (G30)",
#   'F',
#   'White Non-Hispanic',
#   '205',
#   '14.3',
#   '6.5'],
#  ['row-8q5g-wnam_yrh6',
#   '00000000-0000-0000-09BA-A183C3F08525',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2010',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'M',
#   'Other Race/ Ethnicity',
#   '6',
#   '.',
#   '.'],
#  ['row-bpv2_kk7p.cjv6',
#   '00000000-0000-0000-4986-44838B537F1D',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2009',
#   'Influenza (Flu) and Pneumonia (J09-J18)',
#   'F',
#   'Asian and Pacific Islander',
#   '83',
#   '15.1',
#   '20.3'],
#  ['row-wh22.eeva.abr6',
#   '00000000-0000-0000-9206-69B2C9734796',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Malignant Neoplasms (Cancer: C00-C97)',
#   'M',
#   'Not Stated/Unknown',
#   '73',
#   '.',
#   '.'],
#  ['row-vs9b.rzre.p7dt',
#   '00000000-0000-0000-28B3-22F8323775A6',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2007',
#   'Chronic Lower Respiratory Diseases (J40-J47)',
#   'F',
#   'Black Non-Hispanic',
#   '163',
#   '15.5',
#   '14.8'],
#  ['row-upm5.s9sf_f2pm',
#   '00000000-0000-0000-CCF0-90308257D17F',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2012',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'M',
#   'Black Non-Hispanic',
#   '1940',
#   '226.8',
#   '280.7'],
#  ['row-n729.kuhd-i9pn',
#   '00000000-0000-0000-697E-CE6CFEAF1789',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Diseases of Heart (I00-I09, I11, I13, I20-I51)',
#   'F',
#   'Black Non-Hispanic',
#   '2194',
#   '209.1',
#   '169.1'],
#  ['row-93qv.928m.kqax',
#   '00000000-0000-0000-C537-DA6B58EA1461',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'All Other Causes',
#   'F',
#   'Hispanic',
#   '1135',
#   '89.6',
#   '96'],
#  ['row-c6rk-vfy3-736g',
#   '00000000-0000-0000-F33A-4554106CB375',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2014',
#   'Chronic Liver Disease and Cirrhosis (K70, K73)',
#   'M',
#   'Hispanic',
#   '164',
#   '13.7',
#   '16.7'],
#  ['row-tnii~ew8m.ip53',
#   '00000000-0000-0000-10DA-A32BD011116B',
#   0,
#   1733776505,
#   None,
#   1733776505,
#   None,
#   '{ }',
#   '2008',
#   'Diabetes Mellitus (E10-E14)',
#   'F',
#   'Other Race/ Ethnicity',
#   '.',
#   '.',
#   '.'],
#  ...]

# %% [markdown]
# #Creating a DataFrame from JSON data
# Let's create a pandas dataframe from the results["data"] part.

# %%
df = pd.DataFrame(results['data'])
df.head()
# Out:
#                    0                                     1   2           3   \
# 0  row-qupq-7iik.acsp  00000000-0000-0000-85AB-5F87A996A300   0  1733776505
# 1  row-s8an-xgaf.eb4t  00000000-0000-0000-5DC3-A9FF70A70774   0  1733776505
# 2  row-68me_j7hb_a7yy  00000000-0000-0000-FDE0-47C6EDC2A52E   0  1733776505
# 3  row-bh3s_5dw5_zhf5  00000000-0000-0000-3231-0B9575966E6B   0  1733776505
# 4  row-bp6v-stuc~hy7b  00000000-0000-0000-BBA7-44D13389B1EE   0  1733776505
#
#      4           5     6    7     8   \
# 0  None  1733776505  None  { }  2007
# 1  None  1733776505  None  { }  2010
# 2  None  1733776505  None  { }  2007
# 3  None  1733776505  None  { }  2007
# 4  None  1733776505  None  { }  2014
#
#                                                9  10                     11  \
# 0                     Diabetes Mellitus (E10-E14)  M  Other Race/ Ethnicity
# 1  Diseases of Heart (I00-I09, I11, I13, I20-I51)  F     Not Stated/Unknown
# 2       Cerebrovascular Disease (Stroke: I60-I69)  M     Black Non-Hispanic
# 3                           Atherosclerosis (I70)  F  Other Race/ Ethnicity
# 4           Malignant Neoplasms (Cancer: C00-C97)  F     Black Non-Hispanic
#
#      12     13     14
# 0    11      .      .
# 1    70      .      .
# 2   213     25     33
# 3     .      .      .
# 4  1852  176.5  148.4

# %% [markdown]
# #Adding Column Names
# Hm, this is kind of ugly without column names...
#
# We need to peek at the "meta" part to find information about the columns.

# %%
#column names are in the metadata

columns = results["meta"]["view"]["columns"]
columns
# Out:
# [{'id': -1,
#   'name': 'sid',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'id',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'position',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': 286671897,
#   'name': 'Year',
#   'dataTypeName': 'text',
#   'description': 'The year of death.\n',
#   'fieldName': 'year',
#   'position': 1,
#   'renderTypeName': 'text',
#   'tableColumnId': 16422631,
#   'width': 148,
#   'cachedContents': {'largest': '2014',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': '2011', 'count': '141'},
#     {'item': '2007', 'count': '141'},
#     {'item': '2010', 'count': '138'},
#     {'item': '2014', 'count': '136'},
#     {'item': '2008', 'count': '136'},
#     {'item': '2009', 'count': '135'},
#     {'item': '2012', 'count': '134'},
#     {'item': '2013', 'count': '133'}],
#    'smallest': '2007',
#    'not_null': '1097',
#    'count': '1094',
#    'cardinality': '8'},
#   'format': {'displayStyle': 'plain', 'align': 'left'}},
#  {'id': 286671898,
#   'name': 'Leading Cause',
#   'dataTypeName': 'text',
#   'description': 'The cause of death.\n',
#   'fieldName': 'leading_cause',
#   'position': 2,
#   'renderTypeName': 'text',
#   'tableColumnId': 16422634,
#   'width': 432,
#   'cachedContents': {'largest': 'Viral Hepatitis (B15-B19)',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': 'Malignant Neoplasms (Cancer: C00-C97)', 'count': '96'},
#     {'item': 'Influenza (Flu) and Pneumonia (J09-J18)', 'count': '96'},
#     {'item': 'Diseases of Heart (I00-I09, I11, I13, I20-I51)', 'count': '96'},
#     {'item': 'All Other Causes', 'count': '96'},
#     {'item': 'Diabetes Mellitus (E10-E14)', 'count': '92'},
#     {'item': 'Cerebrovascular Disease (Stroke: I60-I69)', 'count': '90'},
#     {'item': 'Chronic Lower Respiratory Diseases (J40-J47)', 'count': '88'},
#     {'item': 'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#      'count': '80'},
#     {'item': 'Essential Hypertension and Renal Diseases (I10, I12)',
#      'count': '75'},
#     {'item': 'Human Immunodeficiency Virus Disease (HIV: B20-B24)',
#      'count': '43'},
#     {'item': 'Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)',
#      'count': '39'},
#     {'item': 'Intentional Self-Harm (Suicide: X60-X84, Y87.0)', 'count': '38'},
#     {'item': "Alzheimer's Disease (G30)", 'count': '32'},
#     {'item': 'Chronic Liver Disease and Cirrhosis (K70, K73)', 'count': '29'},
#     {'item': 'Certain Conditions originating in the Perinatal Period (P00-P96)',
#      'count': '26'},
#     {'item': 'Assault (Homicide: Y87.1, X85-Y09)', 'count': '20'},
#     {'item': 'Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)',
#      'count': '17'},
#     {'item': 'Septicemia (A40-A41)', 'count': '13'},
#     {'item': 'Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)',
#      'count': '8'},
#     {'item': 'Viral Hepatitis (B15-B19)', 'count': '5'}],
#    'smallest': 'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)',
#    'not_null': '1095',
#    'count': '1094',
#    'cardinality': '26'},
#   'format': {'displayStyle': 'plain', 'align': 'left'}},
#  {'id': 286671899,
#   'name': 'Sex',
#   'dataTypeName': 'text',
#   'description': "The decedent's sex.\n",
#   'fieldName': 'sex',
#   'position': 3,
#   'renderTypeName': 'text',
#   'tableColumnId': 16422633,
#   'width': 136,
#   'cachedContents': {'largest': 'M',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': 'F', 'count': '554'}, {'item': 'M', 'count': '540'}],
#    'smallest': 'F',
#    'not_null': '1094',
#    'count': '1094',
#    'cardinality': '2'},
#   'format': {'displayStyle': 'plain', 'align': 'left'}},
#  {'id': 286671900,
#   'name': 'Race Ethnicity',
#   'dataTypeName': 'text',
#   'description': "The decedent's ethnicity.\n",
#   'fieldName': 'race_ethnicity',
#   'position': 4,
#   'renderTypeName': 'text',
#   'tableColumnId': 16422632,
#   'width': 208,
#   'cachedContents': {'largest': 'White Non-Hispanic',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': 'Not Stated/Unknown', 'count': '200'},
#     {'item': 'Other Race/ Ethnicity', 'count': '186'},
#     {'item': 'Black Non-Hispanic', 'count': '178'},
#     {'item': 'Hispanic', 'count': '177'},
#     {'item': 'Asian and Pacific Islander', 'count': '177'},
#     {'item': 'White Non-Hispanic', 'count': '176'}],
#    'smallest': 'Asian and Pacific Islander',
#    'not_null': '1094',
#    'count': '1094',
#    'cardinality': '6'},
#   'format': {'displayStyle': 'plain', 'align': 'left'}},
#  {'id': 286671901,
#   'name': 'Deaths',
#   'dataTypeName': 'text',
#   'description': 'The number of people who died due to cause of death.\n',
#   'fieldName': 'deaths',
#   'position': 5,
#   'renderTypeName': 'text',
#   'tableColumnId': 40844762,
#   'width': 100,
#   'cachedContents': {'largest': '99',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': '.', 'count': '138'},
#     {'item': '5', 'count': '28'},
#     {'item': '8', 'count': '22'},
#     {'item': '6', 'count': '21'},
#     {'item': '7', 'count': '15'},
#     {'item': '10', 'count': '15'},
#     {'item': '14', 'count': '11'},
#     {'item': '11', 'count': '11'},
#     {'item': '9', 'count': '10'},
#     {'item': '18', 'count': '8'},
#     {'item': '36', 'count': '7'},
#     {'item': '17', 'count': '7'},
#     {'item': '43', 'count': '6'},
#     {'item': '13', 'count': '6'},
#     {'item': '191', 'count': '6'},
#     {'item': '12', 'count': '6'},
#     {'item': '70', 'count': '6'},
#     {'item': '29', 'count': '6'},
#     {'item': '50', 'count': '6'},
#     {'item': '15', 'count': '6'}],
#    'smallest': '.',
#    'not_null': '1094',
#    'count': '1094',
#    'cardinality': '465'},
#   'format': {'displayStyle': 'plain', 'align': 'right'}},
#  {'id': 286671902,
#   'name': 'Death Rate',
#   'dataTypeName': 'text',
#   'description': 'The death rate within the sex and Race/ethnicity category\n',
#   'fieldName': 'death_rate',
#   'position': 6,
#   'renderTypeName': 'text',
#   'tableColumnId': 40844763,
#   'width': 100,
#   'cachedContents': {'largest': '99.2',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': '.', 'count': '386'},
#     {'item': '17.3', 'count': '7'},
#     {'item': '13', 'count': '7'},
#     {'item': '5.8', 'count': '6'},
#     {'item': '18', 'count': '6'},
#     {'item': '16.3', 'count': '6'},
#     {'item': '11.4', 'count': '6'},
#     {'item': '6.7', 'count': '6'},
#     {'item': '16.9', 'count': '5'},
#     {'item': '8.3', 'count': '5'},
#     {'item': '18.3', 'count': '5'},
#     {'item': '12.8', 'count': '5'},
#     {'item': '14.5', 'count': '5'},
#     {'item': '15.8', 'count': '5'},
#     {'item': '16.1', 'count': '5'},
#     {'item': '23.4', 'count': '4'},
#     {'item': '12.7', 'count': '4'},
#     {'item': '17.2', 'count': '4'},
#     {'item': '26.1', 'count': '4'},
#     {'item': '13.8', 'count': '4'}],
#    'smallest': '.',
#    'not_null': '1094',
#    'count': '1094',
#    'cardinality': '442'},
#   'format': {'displayStyle': 'plain', 'align': 'right'}},
#  {'id': 286671903,
#   'name': 'Age Adjusted Death Rate',
#   'dataTypeName': 'text',
#   'description': 'The age-adjusted death rate within the sex and Race/ethnicity category\n',
#   'fieldName': 'age_adjusted_death_rate',
#   'position': 7,
#   'renderTypeName': 'text',
#   'tableColumnId': 40844764,
#   'width': 100,
#   'cachedContents': {'largest': '99.9',
#    'non_null': '1094',
#    'null': '0',
#    'top': [{'item': '.', 'count': '386'},
#     {'item': '21.4', 'count': '6'},
#     {'item': '17.9', 'count': '6'},
#     {'item': '6.3', 'count': '6'},
#     {'item': '16.8', 'count': '5'},
#     {'item': '14.1', 'count': '5'},
#     {'item': '20.6', 'count': '5'},
#     {'item': '5.1', 'count': '5'},
#     {'item': '17.6', 'count': '5'},
#     {'item': '8.5', 'count': '5'},
#     {'item': '14.8', 'count': '5'},
#     {'item': '8.7', 'count': '5'},
#     {'item': '8.1', 'count': '5'},
#     {'item': '16.4', 'count': '5'},
#     {'item': '7.2', 'count': '5'},
#     {'item': '7.4', 'count': '5'},
#     {'item': '20.9', 'count': '4'},
#     {'item': '9.3', 'count': '4'},
#     {'item': '22.8', 'count': '4'},
#     {'item': '16.9', 'count': '4'}],
#    'smallest': '.',
#    'not_null': '1094',
#    'count': '1094',
#    'cardinality': '427'},
#   'format': {'displayStyle': 'plain', 'align': 'right'}}]

# %%
#create a list of column names
header = [c['fieldName'] for c in columns]

header
# Out:
# [':sid',
#  ':id',
#  ':position',
#  ':created_at',
#  ':created_meta',
#  ':updated_at',
#  ':updated_meta',
#  ':meta',
#  'year',
#  'leading_cause',
#  'sex',
#  'race_ethnicity',
#  'deaths',
#  'death_rate',
#  'age_adjusted_death_rate']

# %%
#pass the list into the dataframe to create the column names
df = pd.DataFrame(results['data'], columns=header)
df.head()
# Out:
#                  :sid                                   :id  :position  \
# 0  row-qupq-7iik.acsp  00000000-0000-0000-85AB-5F87A996A300          0
# 1  row-s8an-xgaf.eb4t  00000000-0000-0000-5DC3-A9FF70A70774          0
# 2  row-68me_j7hb_a7yy  00000000-0000-0000-FDE0-47C6EDC2A52E          0
# 3  row-bh3s_5dw5_zhf5  00000000-0000-0000-3231-0B9575966E6B          0
# 4  row-bp6v-stuc~hy7b  00000000-0000-0000-BBA7-44D13389B1EE          0
#
#    :created_at :created_meta  :updated_at :updated_meta :meta  year  \
# 0   1733776505          None   1733776505          None   { }  2007
# 1   1733776505          None   1733776505          None   { }  2010
# 2   1733776505          None   1733776505          None   { }  2007
# 3   1733776505          None   1733776505          None   { }  2007
# 4   1733776505          None   1733776505          None   { }  2014
#
#                                     leading_cause sex         race_ethnicity  \
# 0                     Diabetes Mellitus (E10-E14)   M  Other Race/ Ethnicity
# 1  Diseases of Heart (I00-I09, I11, I13, I20-I51)   F     Not Stated/Unknown
# 2       Cerebrovascular Disease (Stroke: I60-I69)   M     Black Non-Hispanic
# 3                           Atherosclerosis (I70)   F  Other Race/ Ethnicity
# 4           Malignant Neoplasms (Cancer: C00-C97)   F     Black Non-Hispanic
#
#   deaths death_rate age_adjusted_death_rate
# 0     11          .                       .
# 1     70          .                       .
# 2    213         25                      33
# 3      .          .                       .
# 4   1852      176.5                   148.4

# %% [markdown]
# #Deleting Columns and/or Rows
# We do not need all these columns. Let's drop a few that we will definitely not use. For that, we will use the drop command

# %%
df.drop(labels= [':sid', ':position', ':meta', ':created_meta', ':updated_meta'],
        axis='columns', inplace=True)

df.head()
# Out:
#                                     :id  :created_at  :updated_at  year  \
# 0  00000000-0000-0000-85AB-5F87A996A300   1733776505   1733776505  2007
# 1  00000000-0000-0000-5DC3-A9FF70A70774   1733776505   1733776505  2010
# 2  00000000-0000-0000-FDE0-47C6EDC2A52E   1733776505   1733776505  2007
# 3  00000000-0000-0000-3231-0B9575966E6B   1733776505   1733776505  2007
# 4  00000000-0000-0000-BBA7-44D13389B1EE   1733776505   1733776505  2014
#
#                                     leading_cause sex         race_ethnicity  \
# 0                     Diabetes Mellitus (E10-E14)   M  Other Race/ Ethnicity
# 1  Diseases of Heart (I00-I09, I11, I13, I20-I51)   F     Not Stated/Unknown
# 2       Cerebrovascular Disease (Stroke: I60-I69)   M     Black Non-Hispanic
# 3                           Atherosclerosis (I70)   F  Other Race/ Ethnicity
# 4           Malignant Neoplasms (Cancer: C00-C97)   F     Black Non-Hispanic
#
#   deaths death_rate age_adjusted_death_rate
# 0     11          .                       .
# 1     70          .                       .
# 2    213         25                      33
# 3      .          .                       .
# 4   1852      176.5                   148.4

# %% [markdown]
# #Common Patterns: axis and inplace
# The axis='columns' says that we are looking to drop columns. If we had axis='index' we would be dropping rows with the passed id's. The ids for the row is the index value for the row.
#
# The inplace=True specifies that we will not be creating a new dataframe, but we just replace the current one, with the new dataframe that has fewer columns.

# %%
df
# Out:
#                                        :id  :created_at  :updated_at  year  \
# 0     00000000-0000-0000-85AB-5F87A996A300   1733776505   1733776505  2007
# 1     00000000-0000-0000-5DC3-A9FF70A70774   1733776505   1733776505  2010
# 2     00000000-0000-0000-FDE0-47C6EDC2A52E   1733776505   1733776505  2007
# 3     00000000-0000-0000-3231-0B9575966E6B   1733776505   1733776505  2007
# 4     00000000-0000-0000-BBA7-44D13389B1EE   1733776505   1733776505  2014
# ...                                    ...          ...          ...   ...
# 1089  00000000-0000-0000-2259-D3EC931A567A   1733776505   1733776505  2013
# 1090  00000000-0000-0000-D33D-9EA1CAB15A3A   1733776505   1733776505  2009
# 1091  00000000-0000-0000-8F6B-49D2BDC18CF3   1733776505   1733776505  2008
# 1092  00000000-0000-0000-E015-C94191CE3EEC   1733776505   1733776505  2010
# 1093  00000000-0000-0000-4FAB-41F56BB3458E   1733776505   1733776505  2013
#
#                                           leading_cause sex  \
# 0                           Diabetes Mellitus (E10-E14)   M
# 1        Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 2             Cerebrovascular Disease (Stroke: I60-I69)   M
# 3                                 Atherosclerosis (I70)   F
# 4                 Malignant Neoplasms (Cancer: C00-C97)   F
# ...                                                 ...  ..
# 1089                                   All Other Causes   M
# 1090     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 1091  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 1092       Chronic Lower Respiratory Diseases (J40-J47)   M
# 1093  Nephritis, Nephrotic Syndrome and Nephrisis (N...   F
#
#              race_ethnicity deaths death_rate age_adjusted_death_rate
# 0     Other Race/ Ethnicity     11          .                       .
# 1        Not Stated/Unknown     70          .                       .
# 2        Black Non-Hispanic    213         25                      33
# 3     Other Race/ Ethnicity      .          .                       .
# 4        Black Non-Hispanic   1852      176.5                   148.4
# ...                     ...    ...        ...                     ...
# 1089     White Non-Hispanic   2293      170.3                   143.3
# 1090     Not Stated/Unknown     94          .                       .
# 1091     Not Stated/Unknown      9          .                       .
# 1092               Hispanic    149         13                    23.9
# 1093     Black Non-Hispanic     93        8.9                     7.6
#
# [1094 rows x 10 columns]

# %% [markdown]
# #Renaming Columns
# We do not like some of these column names. Let's rename them.
#
# We will use a dictionary, for specifying the existing and the new names for the columns.

# %%
# this dict specifies as a key the existing name and new name

renaming_dict ={
    ':id': 'key',
    ':created_at': 'created_at',
    ':updated_at': 'updated_at'
}

df.rename(columns=renaming_dict, inplace=True)
df.head()
# Out:
#                                     key  created_at  updated_at  year  \
# 0  00000000-0000-0000-85AB-5F87A996A300  1733776505  1733776505  2007
# 1  00000000-0000-0000-5DC3-A9FF70A70774  1733776505  1733776505  2010
# 2  00000000-0000-0000-FDE0-47C6EDC2A52E  1733776505  1733776505  2007
# 3  00000000-0000-0000-3231-0B9575966E6B  1733776505  1733776505  2007
# 4  00000000-0000-0000-BBA7-44D13389B1EE  1733776505  1733776505  2014
#
#                                     leading_cause sex         race_ethnicity  \
# 0                     Diabetes Mellitus (E10-E14)   M  Other Race/ Ethnicity
# 1  Diseases of Heart (I00-I09, I11, I13, I20-I51)   F     Not Stated/Unknown
# 2       Cerebrovascular Disease (Stroke: I60-I69)   M     Black Non-Hispanic
# 3                           Atherosclerosis (I70)   F  Other Race/ Ethnicity
# 4           Malignant Neoplasms (Cancer: C00-C97)   F     Black Non-Hispanic
#
#   deaths death_rate age_adjusted_death_rate
# 0     11          .                       .
# 1     70          .                       .
# 2    213         25                      33
# 3      .          .                       .
# 4   1852      176.5                   148.4

# %%
#view the dataframe data types
df.dtypes
# Out:
# key                        object
# created_at                  int64
# updated_at                  int64
# year                       object
# leading_cause              object
# sex                        object
# race_ethnicity             object
# deaths                     object
# death_rate                 object
# age_adjusted_death_rate    object
# dtype: object

# %%
# convert data type year
df['year'] = pd.to_numeric(df['year'])
df.dtypes
# Out:
# key                        object
# created_at                  int64
# updated_at                  int64
# year                        int64
# leading_cause              object
# sex                        object
# race_ethnicity             object
# deaths                     object
# death_rate                 object
# age_adjusted_death_rate    object
# dtype: object

# %% [markdown]
# ##Sometimes, during the conversion of data, the cells contain values that cannot be properly converted. We can specify how we want pandas to handle such cases. By default, it will raise an exception, and will not allow us to convert the data to a new data type.

# %%
#this one will cause an error, since 'deaths' contain non-numeric values
#df['deaths'] = pd.to_numeric(df['deaths'])

# %% [markdown]
# ##We can pass the errors command to specify what should happen. From the documentation of to_numeric, we get:
#
# If ‘raise’, then invalid parsing will raise an exception
# If ‘coerce’, then invalid parsing will be set as NaN
# If ‘ignore’, then invalid parsing will return the input

# %%
df['deaths'] = pd.to_numeric(df['deaths'], errors='coerce')
df['death_rate'] = pd.to_numeric(df['death_rate'], errors='coerce')
df['age_adjusted_death_rate'] = pd.to_numeric(df['age_adjusted_death_rate'], errors='coerce')
df.dtypes
# Out:
# key                         object
# created_at                   int64
# updated_at                   int64
# year                         int64
# leading_cause               object
# sex                         object
# race_ethnicity              object
# deaths                     float64
# death_rate                 float64
# age_adjusted_death_rate    float64
# dtype: object

# %%
# review the dataframe with the changes
df
# Out:
#                                        key  created_at  updated_at  year  \
# 0     00000000-0000-0000-85AB-5F87A996A300  1733776505  1733776505  2007
# 1     00000000-0000-0000-5DC3-A9FF70A70774  1733776505  1733776505  2010
# 2     00000000-0000-0000-FDE0-47C6EDC2A52E  1733776505  1733776505  2007
# 3     00000000-0000-0000-3231-0B9575966E6B  1733776505  1733776505  2007
# 4     00000000-0000-0000-BBA7-44D13389B1EE  1733776505  1733776505  2014
# ...                                    ...         ...         ...   ...
# 1089  00000000-0000-0000-2259-D3EC931A567A  1733776505  1733776505  2013
# 1090  00000000-0000-0000-D33D-9EA1CAB15A3A  1733776505  1733776505  2009
# 1091  00000000-0000-0000-8F6B-49D2BDC18CF3  1733776505  1733776505  2008
# 1092  00000000-0000-0000-E015-C94191CE3EEC  1733776505  1733776505  2010
# 1093  00000000-0000-0000-4FAB-41F56BB3458E  1733776505  1733776505  2013
#
#                                           leading_cause sex  \
# 0                           Diabetes Mellitus (E10-E14)   M
# 1        Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 2             Cerebrovascular Disease (Stroke: I60-I69)   M
# 3                                 Atherosclerosis (I70)   F
# 4                 Malignant Neoplasms (Cancer: C00-C97)   F
# ...                                                 ...  ..
# 1089                                   All Other Causes   M
# 1090     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 1091  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 1092       Chronic Lower Respiratory Diseases (J40-J47)   M
# 1093  Nephritis, Nephrotic Syndrome and Nephrisis (N...   F
#
#              race_ethnicity  deaths  death_rate  age_adjusted_death_rate
# 0     Other Race/ Ethnicity    11.0         NaN                      NaN
# 1        Not Stated/Unknown    70.0         NaN                      NaN
# 2        Black Non-Hispanic   213.0        25.0                     33.0
# 3     Other Race/ Ethnicity     NaN         NaN                      NaN
# 4        Black Non-Hispanic  1852.0       176.5                    148.4
# ...                     ...     ...         ...                      ...
# 1089     White Non-Hispanic  2293.0       170.3                    143.3
# 1090     Not Stated/Unknown    94.0         NaN                      NaN
# 1091     Not Stated/Unknown     9.0         NaN                      NaN
# 1092               Hispanic   149.0        13.0                     23.9
# 1093     Black Non-Hispanic    93.0         8.9                      7.6
#
# [1094 rows x 10 columns]

# %%
#change data types of other values to categorical
df['leading_cause'] = pd.Categorical(df['leading_cause'])
df['sex'] = pd.Categorical(df['sex'])
df['race_ethnicity'] = pd.Categorical(df['race_ethnicity'])
df.dtypes
# Out:
# key                          object
# created_at                    int64
# updated_at                    int64
# year                          int64
# leading_cause              category
# sex                        category
# race_ethnicity             category
# deaths                      float64
# death_rate                  float64
# age_adjusted_death_rate     float64
# dtype: object

# %%
#switch timestamps and dates. Note we use s to specify seconds
df['created_at'] = pd.to_datetime(df['created_at'], unit='s')
df['updated_at'] = pd.to_datetime(df['updated_at'], unit='s')
df.dtypes
# Out:
# key                                object
# created_at                 datetime64[ns]
# updated_at                 datetime64[ns]
# year                                int64
# leading_cause                    category
# sex                              category
# race_ethnicity                   category
# deaths                            float64
# death_rate                        float64
# age_adjusted_death_rate           float64
# dtype: object

# %%
#sort the values by year
df.sort_values(by='year')
# Out:
#                                        key          created_at  \
# 0     00000000-0000-0000-85AB-5F87A996A300 2024-12-09 20:35:05
# 1079  00000000-0000-0000-FECF-7A58A8C85B15 2024-12-09 20:35:05
# 2     00000000-0000-0000-FDE0-47C6EDC2A52E 2024-12-09 20:35:05
# 1078  00000000-0000-0000-B534-60BBEF04A846 2024-12-09 20:35:05
# 38    00000000-0000-0000-71E5-2496086D8623 2024-12-09 20:35:05
# ...                                    ...                 ...
# 35    00000000-0000-0000-F7B9-F913C3F2A3B2 2024-12-09 20:35:05
# 420   00000000-0000-0000-318A-E62926DC3C28 2024-12-09 20:35:05
# 425   00000000-0000-0000-E419-3E5476DAA97E 2024-12-09 20:35:05
# 431   00000000-0000-0000-F7C3-E3CE3F66998F 2024-12-09 20:35:05
# 1081  00000000-0000-0000-D1BF-C31BE662B052 2024-12-09 20:35:05
#
#               updated_at  year  \
# 0    2024-12-09 20:35:05  2007
# 1079 2024-12-09 20:35:05  2007
# 2    2024-12-09 20:35:05  2007
# 1078 2024-12-09 20:35:05  2007
# 38   2024-12-09 20:35:05  2007
# ...                  ...   ...
# 35   2024-12-09 20:35:05  2014
# 420  2024-12-09 20:35:05  2014
# 425  2024-12-09 20:35:05  2014
# 431  2024-12-09 20:35:05  2014
# 1081 2024-12-09 20:35:05  2014
#
#                                           leading_cause sex  \
# 0                           Diabetes Mellitus (E10-E14)   M
# 1079            Influenza (Flu) and Pneumonia (J09-J18)   M
# 2             Cerebrovascular Disease (Stroke: I60-I69)   M
# 1078                 Assault (Homicide: Y87.1, X85-Y09)   M
# 38    Essential Hypertension and Renal Diseases (I10...   M
# ...                                                 ...  ..
# 35    Essential Hypertension and Renal Diseases (I10...   F
# 420      Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 425      Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 431                           Alzheimer's Disease (G30)   F
# 1081     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
#
#                   race_ethnicity  deaths  death_rate  age_adjusted_death_rate
# 0          Other Race/ Ethnicity    11.0         NaN                      NaN
# 1079          Black Non-Hispanic   229.0        26.9                     40.1
# 2             Black Non-Hispanic   213.0        25.0                     33.0
# 1078          Not Stated/Unknown     NaN         NaN                      NaN
# 38            Black Non-Hispanic   137.0        16.1                     22.0
# ...                          ...     ...         ...                      ...
# 35                      Hispanic   116.0         9.2                     10.1
# 420        Other Race/ Ethnicity    68.0         NaN                      NaN
# 425           White Non-Hispanic  4507.0       318.0                    161.0
# 431   Asian and Pacific Islander    26.0         4.2                      4.7
# 1081          Black Non-Hispanic  1958.0       226.8                    264.7
#
# [1094 rows x 10 columns]

# %% [markdown]
# #Perform Exploratory Data Analysis

# %%
# race values
df['race_ethnicity'].value_counts()
# Out:
# race_ethnicity
# Not Stated/Unknown            200
# Other Race/ Ethnicity         186
# Black Non-Hispanic            178
# Asian and Pacific Islander    177
# Hispanic                      177
# White Non-Hispanic            176
# Name: count, dtype: int64

# %%
#review sex breakdown
df['sex'].value_counts()
# Out:
# sex
# F    554
# M    540
# Name: count, dtype: int64

# %%
#leading cause breakdown
df['leading_cause'].value_counts()
# Out:
# leading_cause
# All Other Causes                                                                                                                     96
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                                                                                       96
# Influenza (Flu) and Pneumonia (J09-J18)                                                                                              96
# Malignant Neoplasms (Cancer: C00-C97)                                                                                                96
# Diabetes Mellitus (E10-E14)                                                                                                          92
# Cerebrovascular Disease (Stroke: I60-I69)                                                                                            90
# Chronic Lower Respiratory Diseases (J40-J47)                                                                                         88
# Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)                                                                     80
# Essential Hypertension and Renal Diseases (I10, I12)                                                                                 75
# Human Immunodeficiency Virus Disease (HIV: B20-B24)                                                                                  43
# Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)    39
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                                                                                      38
# Alzheimer's Disease (G30)                                                                                                            32
# Chronic Liver Disease and Cirrhosis (K70, K73)                                                                                       29
# Certain Conditions originating in the Perinatal Period (P00-P96)                                                                     26
# Assault (Homicide: Y87.1, X85-Y09)                                                                                                   20
# Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)                                                              17
# Septicemia (A40-A41)                                                                                                                 13
# Congenital Malformations, Deformations, and Chromosomal Abnormalities (Q00-Q99)                                                       8
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                                                                                      5
# Viral Hepatitis (B15-B19)                                                                                                             5
# Atherosclerosis (I70)                                                                                                                 3
# Aortic Aneurysm and Dissection (I71)                                                                                                  3
# Mental and Behavioral Disorders due to Use of Alcohol (F10)                                                                           2
# Parkinson's Disease (G20)                                                                                                             1
# Tuberculosis (A16-A19)                                                                                                                1
# Name: count, dtype: int64

# %%
#create pivot table to view the leading cause compared to race and sex
import numpy as np
pivot = pd.pivot_table(df,
                       values='deaths',
                       index='leading_cause',               #rows
                       columns=['sex','race_ethnicity'],    #columns
                       aggfunc=np.sum)                      #aggregate function
pivot
# Out:
# <ipython-input-25-0b21d305e33a>:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = pd.pivot_table(df,
# <ipython-input-25-0b21d305e33a>:3: FutureWarning: The provided callable <function sum at 0x7f7c113c82c0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot = pd.pivot_table(df,
# sex                                                                         F  \
# race_ethnicity                                     Asian and Pacific Islander
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...                      284.0
# All Other Causes                                                       2118.0
# Alzheimer's Disease (G30)                                                64.0
# Aortic Aneurysm and Dissection (I71)                                      0.0
# Assault (Homicide: Y87.1, X85-Y09)                                        0.0
# Atherosclerosis (I70)                                                     0.0
# Cerebrovascular Disease (Stroke: I60-I69)                               677.0
# Certain Conditions originating in the Perinatal...                       18.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                            0.0
# Chronic Lower Respiratory Diseases (J40-J47)                            249.0
# Congenital Malformations, Deformations, and Chr...                        0.0
# Diabetes Mellitus (E10-E14)                                             405.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                         3429.0
# Essential Hypertension and Renal Diseases (I10,...                      269.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                        0.0
# Influenza (Flu) and Pneumonia (J09-J18)                                 603.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                          0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                         164.0
# Malignant Neoplasms (Cancer: C00-C97)                                  3432.0
# Mental and Behavioral Disorders due to Accident...                        0.0
# Mental and Behavioral Disorders due to Use of A...                        0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                       48.0
# Parkinson's Disease (G20)                                                 0.0
# Septicemia (A40-A41)                                                     16.0
# Tuberculosis (A16-A19)                                                    0.0
# Viral Hepatitis (B15-B19)                                                15.0
#
# sex                                                                    \
# race_ethnicity                                     Black Non-Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...              157.0
# All Other Causes                                              11178.0
# Alzheimer's Disease (G30)                                       601.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                                0.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                      2147.0
# Certain Conditions originating in the Perinatal...                0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                    0.0
# Chronic Lower Respiratory Diseases (J40-J47)                   1651.0
# Congenital Malformations, Deformations, and Chr...                0.0
# Diabetes Mellitus (E10-E14)                                    3133.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                19335.0
# Essential Hypertension and Renal Diseases (I10,...             1723.0
# Human Immunodeficiency Virus Disease (HIV: B20-...             1324.0
# Influenza (Flu) and Pneumonia (J09-J18)                        2288.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                   0.0
# Malignant Neoplasms (Cancer: C00-C97)                         14525.0
# Mental and Behavioral Disorders due to Accident...               87.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...              574.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                             89.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         0.0
#
# sex                                                          \
# race_ethnicity                                     Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...    437.0
# All Other Causes                                     7838.0
# Alzheimer's Disease (G30)                             605.0
# Aortic Aneurysm and Dissection (I71)                    0.0
# Assault (Homicide: Y87.1, X85-Y09)                      0.0
# Atherosclerosis (I70)                                   0.0
# Cerebrovascular Disease (Stroke: I60-I69)            1428.0
# Certain Conditions originating in the Perinatal...      0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)        183.0
# Chronic Lower Respiratory Diseases (J40-J47)         1258.0
# Congenital Malformations, Deformations, and Chr...      0.0
# Diabetes Mellitus (E10-E14)                          1693.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)      10630.0
# Essential Hypertension and Renal Diseases (I10,...    764.0
# Human Immunodeficiency Virus Disease (HIV: B20-...    467.0
# Influenza (Flu) and Pneumonia (J09-J18)              1710.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)        0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)         0.0
# Malignant Neoplasms (Cancer: C00-C97)                8670.0
# Mental and Behavioral Disorders due to Accident...    176.0
# Mental and Behavioral Disorders due to Use of A...      0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...      0.0
# Parkinson's Disease (G20)                               0.0
# Septicemia (A40-A41)                                   49.0
# Tuberculosis (A16-A19)                                  0.0
# Viral Hepatitis (B15-B19)                               0.0
#
# sex                                                                    \
# race_ethnicity                                     Not Stated/Unknown
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...                0.0
# All Other Causes                                                307.0
# Alzheimer's Disease (G30)                                         8.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                                0.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                        51.0
# Certain Conditions originating in the Perinatal...               55.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                    0.0
# Chronic Lower Respiratory Diseases (J40-J47)                     53.0
# Congenital Malformations, Deformations, and Chr...                8.0
# Diabetes Mellitus (E10-E14)                                      62.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                  691.0
# Essential Hypertension and Renal Diseases (I10,...               22.0
# Human Immunodeficiency Virus Disease (HIV: B20-...               12.0
# Influenza (Flu) and Pneumonia (J09-J18)                          74.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  5.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                   0.0
# Malignant Neoplasms (Cancer: C00-C97)                           348.0
# Mental and Behavioral Disorders due to Accident...               12.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                0.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                              0.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         0.0
#
# sex                                                                       \
# race_ethnicity                                     Other Race/ Ethnicity
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...                   6.0
# All Other Causes                                                   230.0
# Alzheimer's Disease (G30)                                            0.0
# Aortic Aneurysm and Dissection (I71)                                 0.0
# Assault (Homicide: Y87.1, X85-Y09)                                   0.0
# Atherosclerosis (I70)                                                0.0
# Cerebrovascular Disease (Stroke: I60-I69)                           28.0
# Certain Conditions originating in the Perinatal...                   0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                       0.0
# Chronic Lower Respiratory Diseases (J40-J47)                         6.0
# Congenital Malformations, Deformations, and Chr...                   0.0
# Diabetes Mellitus (E10-E14)                                         45.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                     356.0
# Essential Hypertension and Renal Diseases (I10,...                   8.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                   0.0
# Influenza (Flu) and Pneumonia (J09-J18)                             32.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                     0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                     15.0
# Malignant Neoplasms (Cancer: C00-C97)                              267.0
# Mental and Behavioral Disorders due to Accident...                   0.0
# Mental and Behavioral Disorders due to Use of A...                   0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                   0.0
# Parkinson's Disease (G20)                                            0.0
# Septicemia (A40-A41)                                                 0.0
# Tuberculosis (A16-A19)                                               0.0
# Viral Hepatitis (B15-B19)                                            0.0
#
# sex                                                                    \
# race_ethnicity                                     White Non-Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...             1392.0
# All Other Causes                                              17272.0
# Alzheimer's Disease (G30)                                      1702.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                                0.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                      3250.0
# Certain Conditions originating in the Perinatal...                0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                    0.0
# Chronic Lower Respiratory Diseases (J40-J47)                   4002.0
# Congenital Malformations, Deformations, and Chr...                0.0
# Diabetes Mellitus (E10-E14)                                    1887.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                44311.0
# Essential Hypertension and Renal Diseases (I10,...             1524.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                0.0
# Influenza (Flu) and Pneumonia (J09-J18)                        5073.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                   0.0
# Malignant Neoplasms (Cancer: C00-C97)                         26635.0
# Mental and Behavioral Disorders due to Accident...              249.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...               89.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                            473.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         0.0
#
# sex                                                                         M  \
# race_ethnicity                                     Asian and Pacific Islander
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...                      463.0
# All Other Causes                                                       2479.0
# Alzheimer's Disease (G30)                                                 0.0
# Aortic Aneurysm and Dissection (I71)                                      0.0
# Assault (Homicide: Y87.1, X85-Y09)                                        0.0
# Atherosclerosis (I70)                                                     0.0
# Cerebrovascular Disease (Stroke: I60-I69)                               556.0
# Certain Conditions originating in the Perinatal...                       19.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                          133.0
# Chronic Lower Respiratory Diseases (J40-J47)                            496.0
# Congenital Malformations, Deformations, and Chr...                       14.0
# Diabetes Mellitus (E10-E14)                                             514.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                         4080.0
# Essential Hypertension and Renal Diseases (I10,...                      221.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                        0.0
# Influenza (Flu) and Pneumonia (J09-J18)                                 725.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                          0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                         327.0
# Malignant Neoplasms (Cancer: C00-C97)                                  4495.0
# Mental and Behavioral Disorders due to Accident...                        0.0
# Mental and Behavioral Disorders due to Use of A...                        0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                       42.0
# Parkinson's Disease (G20)                                                 0.0
# Septicemia (A40-A41)                                                      0.0
# Tuberculosis (A16-A19)                                                    0.0
# Viral Hepatitis (B15-B19)                                                 0.0
#
# sex                                                                    \
# race_ethnicity                                     Black Non-Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...             1044.0
# All Other Causes                                              10228.0
# Alzheimer's Disease (G30)                                         0.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                             1968.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                      1502.0
# Certain Conditions originating in the Perinatal...                0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                    0.0
# Chronic Lower Respiratory Diseases (J40-J47)                   1409.0
# Congenital Malformations, Deformations, and Chr...                0.0
# Diabetes Mellitus (E10-E14)                                    2308.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                15887.0
# Essential Hypertension and Renal Diseases (I10,...             1180.0
# Human Immunodeficiency Virus Disease (HIV: B20-...             2259.0
# Influenza (Flu) and Pneumonia (J09-J18)                        1860.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                   0.0
# Malignant Neoplasms (Cancer: C00-C97)                         12361.0
# Mental and Behavioral Disorders due to Accident...              298.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                0.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                              0.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         0.0
#
# sex                                                          \
# race_ethnicity                                     Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...   1378.0
# All Other Causes                                     9085.0
# Alzheimer's Disease (G30)                               0.0
# Aortic Aneurysm and Dissection (I71)                    0.0
# Assault (Homicide: Y87.1, X85-Y09)                    114.0
# Atherosclerosis (I70)                                   0.0
# Cerebrovascular Disease (Stroke: I60-I69)            1132.0
# Certain Conditions originating in the Perinatal...      0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)       1148.0
# Chronic Lower Respiratory Diseases (J40-J47)          934.0
# Congenital Malformations, Deformations, and Chr...      0.0
# Diabetes Mellitus (E10-E14)                          1499.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)      10433.0
# Essential Hypertension and Renal Diseases (I10,...      0.0
# Human Immunodeficiency Virus Disease (HIV: B20-...   1304.0
# Influenza (Flu) and Pneumonia (J09-J18)              1640.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)        0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)         0.0
# Malignant Neoplasms (Cancer: C00-C97)                8892.0
# Mental and Behavioral Disorders due to Accident...   1335.0
# Mental and Behavioral Disorders due to Use of A...      0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...      0.0
# Parkinson's Disease (G20)                               0.0
# Septicemia (A40-A41)                                    0.0
# Tuberculosis (A16-A19)                                  0.0
# Viral Hepatitis (B15-B19)                               0.0
#
# sex                                                                    \
# race_ethnicity                                     Not Stated/Unknown
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...               58.0
# All Other Causes                                                548.0
# Alzheimer's Disease (G30)                                         0.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                               15.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                        18.0
# Certain Conditions originating in the Perinatal...               97.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                   26.0
# Chronic Lower Respiratory Diseases (J40-J47)                     68.0
# Congenital Malformations, Deformations, and Chr...                0.0
# Diabetes Mellitus (E10-E14)                                      50.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                  769.0
# Essential Hypertension and Renal Diseases (I10,...               24.0
# Human Immunodeficiency Virus Disease (HIV: B20-...               60.0
# Influenza (Flu) and Pneumonia (J09-J18)                          95.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                  30.0
# Malignant Neoplasms (Cancer: C00-C97)                           450.0
# Mental and Behavioral Disorders due to Accident...               69.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                0.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                              8.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         6.0
#
# sex                                                                       \
# race_ethnicity                                     Other Race/ Ethnicity
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...                  42.0
# All Other Causes                                                   242.0
# Alzheimer's Disease (G30)                                            0.0
# Aortic Aneurysm and Dissection (I71)                                 0.0
# Assault (Homicide: Y87.1, X85-Y09)                                   5.0
# Atherosclerosis (I70)                                                0.0
# Cerebrovascular Disease (Stroke: I60-I69)                           36.0
# Certain Conditions originating in the Perinatal...                   8.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                      15.0
# Chronic Lower Respiratory Diseases (J40-J47)                         5.0
# Congenital Malformations, Deformations, and Chr...                   0.0
# Diabetes Mellitus (E10-E14)                                         73.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                     381.0
# Essential Hypertension and Renal Diseases (I10,...                   5.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                  10.0
# Influenza (Flu) and Pneumonia (J09-J18)                             44.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                     0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                     11.0
# Malignant Neoplasms (Cancer: C00-C97)                              251.0
# Mental and Behavioral Disorders due to Accident...                  12.0
# Mental and Behavioral Disorders due to Use of A...                   0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                   0.0
# Parkinson's Disease (G20)                                            0.0
# Septicemia (A40-A41)                                                 6.0
# Tuberculosis (A16-A19)                                               0.0
# Viral Hepatitis (B15-B19)                                            0.0
#
# sex
# race_ethnicity                                     White Non-Hispanic
# leading_cause
# Accidents Except Drug Posioning (V01-X39, X43, ...             2206.0
# All Other Causes                                              16474.0
# Alzheimer's Disease (G30)                                         0.0
# Aortic Aneurysm and Dissection (I71)                              0.0
# Assault (Homicide: Y87.1, X85-Y09)                                0.0
# Atherosclerosis (I70)                                             0.0
# Cerebrovascular Disease (Stroke: I60-I69)                      2116.0
# Certain Conditions originating in the Perinatal...                0.0
# Chronic Liver Disease and Cirrhosis (K70, K73)                    0.0
# Chronic Lower Respiratory Diseases (J40-J47)                   3083.0
# Congenital Malformations, Deformations, and Chr...                0.0
# Diabetes Mellitus (E10-E14)                                    2125.0
# Diseases of Heart (I00-I09, I11, I13, I20-I51)                37249.0
# Essential Hypertension and Renal Diseases (I10,...             1215.0
# Human Immunodeficiency Virus Disease (HIV: B20-...                0.0
# Influenza (Flu) and Pneumonia (J09-J18)                        4534.0
# Insitu or Benign / Uncertain Neoplasms (D00-D48)                  0.0
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)                1539.0
# Malignant Neoplasms (Cancer: C00-C97)                         26041.0
# Mental and Behavioral Disorders due to Accident...             2046.0
# Mental and Behavioral Disorders due to Use of A...                0.0
# Nephritis, Nephrotic Syndrome and Nephrisis (N0...                0.0
# Parkinson's Disease (G20)                                         0.0
# Septicemia (A40-A41)                                              0.0
# Tuberculosis (A16-A19)                                            0.0
# Viral Hepatitis (B15-B19)                                         0.0

# %%
# we can transpose the data with the transpose() fucntion or using the pivot.T
pivot.transpose()
# Out:
# leading_cause                   Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                              284.0
#     Black Non-Hispanic                                                      157.0
#     Hispanic                                                                437.0
#     Not Stated/Unknown                                                        0.0
#     Other Race/ Ethnicity                                                     6.0
#     White Non-Hispanic                                                     1392.0
# M   Asian and Pacific Islander                                              463.0
#     Black Non-Hispanic                                                     1044.0
#     Hispanic                                                               1378.0
#     Not Stated/Unknown                                                       58.0
#     Other Race/ Ethnicity                                                    42.0
#     White Non-Hispanic                                                     2206.0
#
# leading_cause                   All Other Causes  Alzheimer's Disease (G30)  \
# sex race_ethnicity
# F   Asian and Pacific Islander            2118.0                       64.0
#     Black Non-Hispanic                   11178.0                      601.0
#     Hispanic                              7838.0                      605.0
#     Not Stated/Unknown                     307.0                        8.0
#     Other Race/ Ethnicity                  230.0                        0.0
#     White Non-Hispanic                   17272.0                     1702.0
# M   Asian and Pacific Islander            2479.0                        0.0
#     Black Non-Hispanic                   10228.0                        0.0
#     Hispanic                              9085.0                        0.0
#     Not Stated/Unknown                     548.0                        0.0
#     Other Race/ Ethnicity                  242.0                        0.0
#     White Non-Hispanic                   16474.0                        0.0
#
# leading_cause                   Aortic Aneurysm and Dissection (I71)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                   0.0
#     Black Non-Hispanic                                           0.0
#     Hispanic                                                     0.0
#     Not Stated/Unknown                                           0.0
#     Other Race/ Ethnicity                                        0.0
#     White Non-Hispanic                                           0.0
# M   Asian and Pacific Islander                                   0.0
#     Black Non-Hispanic                                           0.0
#     Hispanic                                                     0.0
#     Not Stated/Unknown                                           0.0
#     Other Race/ Ethnicity                                        0.0
#     White Non-Hispanic                                           0.0
#
# leading_cause                   Assault (Homicide: Y87.1, X85-Y09)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                 0.0
#     Black Non-Hispanic                                         0.0
#     Hispanic                                                   0.0
#     Not Stated/Unknown                                         0.0
#     Other Race/ Ethnicity                                      0.0
#     White Non-Hispanic                                         0.0
# M   Asian and Pacific Islander                                 0.0
#     Black Non-Hispanic                                      1968.0
#     Hispanic                                                 114.0
#     Not Stated/Unknown                                        15.0
#     Other Race/ Ethnicity                                      5.0
#     White Non-Hispanic                                         0.0
#
# leading_cause                   Atherosclerosis (I70)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                    0.0
#     Black Non-Hispanic                            0.0
#     Hispanic                                      0.0
#     Not Stated/Unknown                            0.0
#     Other Race/ Ethnicity                         0.0
#     White Non-Hispanic                            0.0
# M   Asian and Pacific Islander                    0.0
#     Black Non-Hispanic                            0.0
#     Hispanic                                      0.0
#     Not Stated/Unknown                            0.0
#     Other Race/ Ethnicity                         0.0
#     White Non-Hispanic                            0.0
#
# leading_cause                   Cerebrovascular Disease (Stroke: I60-I69)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                      677.0
#     Black Non-Hispanic                                             2147.0
#     Hispanic                                                       1428.0
#     Not Stated/Unknown                                               51.0
#     Other Race/ Ethnicity                                            28.0
#     White Non-Hispanic                                             3250.0
# M   Asian and Pacific Islander                                      556.0
#     Black Non-Hispanic                                             1502.0
#     Hispanic                                                       1132.0
#     Not Stated/Unknown                                               18.0
#     Other Race/ Ethnicity                                            36.0
#     White Non-Hispanic                                             2116.0
#
# leading_cause                   Certain Conditions originating in the Perinatal Period (P00-P96)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                               18.0
#     Black Non-Hispanic                                                        0.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                       55.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                        0.0
# M   Asian and Pacific Islander                                               19.0
#     Black Non-Hispanic                                                        0.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                       97.0
#     Other Race/ Ethnicity                                                     8.0
#     White Non-Hispanic                                                        0.0
#
# leading_cause                   Chronic Liver Disease and Cirrhosis (K70, K73)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                             0.0
#     Black Non-Hispanic                                                     0.0
#     Hispanic                                                             183.0
#     Not Stated/Unknown                                                     0.0
#     Other Race/ Ethnicity                                                  0.0
#     White Non-Hispanic                                                     0.0
# M   Asian and Pacific Islander                                           133.0
#     Black Non-Hispanic                                                     0.0
#     Hispanic                                                            1148.0
#     Not Stated/Unknown                                                    26.0
#     Other Race/ Ethnicity                                                 15.0
#     White Non-Hispanic                                                     0.0
#
# leading_cause                   Chronic Lower Respiratory Diseases (J40-J47)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                         249.0
#     Black Non-Hispanic                                                1651.0
#     Hispanic                                                          1258.0
#     Not Stated/Unknown                                                  53.0
#     Other Race/ Ethnicity                                                6.0
#     White Non-Hispanic                                                4002.0
# M   Asian and Pacific Islander                                         496.0
#     Black Non-Hispanic                                                1409.0
#     Hispanic                                                           934.0
#     Not Stated/Unknown                                                  68.0
#     Other Race/ Ethnicity                                                5.0
#     White Non-Hispanic                                                3083.0
#
# leading_cause                   ...  \
# sex race_ethnicity              ...
# F   Asian and Pacific Islander  ...
#     Black Non-Hispanic          ...
#     Hispanic                    ...
#     Not Stated/Unknown          ...
#     Other Race/ Ethnicity       ...
#     White Non-Hispanic          ...
# M   Asian and Pacific Islander  ...
#     Black Non-Hispanic          ...
#     Hispanic                    ...
#     Not Stated/Unknown          ...
#     Other Race/ Ethnicity       ...
#     White Non-Hispanic          ...
#
# leading_cause                   Insitu or Benign / Uncertain Neoplasms (D00-D48)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                               0.0
#     Black Non-Hispanic                                                       0.0
#     Hispanic                                                                 0.0
#     Not Stated/Unknown                                                       5.0
#     Other Race/ Ethnicity                                                    0.0
#     White Non-Hispanic                                                       0.0
# M   Asian and Pacific Islander                                               0.0
#     Black Non-Hispanic                                                       0.0
#     Hispanic                                                                 0.0
#     Not Stated/Unknown                                                       0.0
#     Other Race/ Ethnicity                                                    0.0
#     White Non-Hispanic                                                       0.0
#
# leading_cause                   Intentional Self-Harm (Suicide: X60-X84, Y87.0)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                            164.0
#     Black Non-Hispanic                                                      0.0
#     Hispanic                                                                0.0
#     Not Stated/Unknown                                                      0.0
#     Other Race/ Ethnicity                                                  15.0
#     White Non-Hispanic                                                      0.0
# M   Asian and Pacific Islander                                            327.0
#     Black Non-Hispanic                                                      0.0
#     Hispanic                                                                0.0
#     Not Stated/Unknown                                                     30.0
#     Other Race/ Ethnicity                                                  11.0
#     White Non-Hispanic                                                   1539.0
#
# leading_cause                   Malignant Neoplasms (Cancer: C00-C97)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                 3432.0
#     Black Non-Hispanic                                        14525.0
#     Hispanic                                                   8670.0
#     Not Stated/Unknown                                          348.0
#     Other Race/ Ethnicity                                       267.0
#     White Non-Hispanic                                        26635.0
# M   Asian and Pacific Islander                                 4495.0
#     Black Non-Hispanic                                        12361.0
#     Hispanic                                                   8892.0
#     Not Stated/Unknown                                          450.0
#     Other Race/ Ethnicity                                       251.0
#     White Non-Hispanic                                        26041.0
#
# leading_cause                   Mental and Behavioral Disorders due to Accidental Poisoning and Other Psychoactive Substance Use (F11-F16, F18-F19, X40-X42, X44)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                                0.0
#     Black Non-Hispanic                                                       87.0
#     Hispanic                                                                176.0
#     Not Stated/Unknown                                                       12.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                      249.0
# M   Asian and Pacific Islander                                                0.0
#     Black Non-Hispanic                                                      298.0
#     Hispanic                                                               1335.0
#     Not Stated/Unknown                                                       69.0
#     Other Race/ Ethnicity                                                    12.0
#     White Non-Hispanic                                                     2046.0
#
# leading_cause                   Mental and Behavioral Disorders due to Use of Alcohol (F10)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                                0.0
#     Black Non-Hispanic                                                        0.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                        0.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                        0.0
# M   Asian and Pacific Islander                                                0.0
#     Black Non-Hispanic                                                        0.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                        0.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                        0.0
#
# leading_cause                   Nephritis, Nephrotic Syndrome and Nephrisis (N00-N07, N17-N19, N25-N27)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                                               48.0
#     Black Non-Hispanic                                                      574.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                        0.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                       89.0
# M   Asian and Pacific Islander                                               42.0
#     Black Non-Hispanic                                                        0.0
#     Hispanic                                                                  0.0
#     Not Stated/Unknown                                                        0.0
#     Other Race/ Ethnicity                                                     0.0
#     White Non-Hispanic                                                        0.0
#
# leading_cause                   Parkinson's Disease (G20)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                        0.0
#     Black Non-Hispanic                                0.0
#     Hispanic                                          0.0
#     Not Stated/Unknown                                0.0
#     Other Race/ Ethnicity                             0.0
#     White Non-Hispanic                                0.0
# M   Asian and Pacific Islander                        0.0
#     Black Non-Hispanic                                0.0
#     Hispanic                                          0.0
#     Not Stated/Unknown                                0.0
#     Other Race/ Ethnicity                             0.0
#     White Non-Hispanic                                0.0
#
# leading_cause                   Septicemia (A40-A41)  Tuberculosis (A16-A19)  \
# sex race_ethnicity
# F   Asian and Pacific Islander                  16.0                     0.0
#     Black Non-Hispanic                          89.0                     0.0
#     Hispanic                                    49.0                     0.0
#     Not Stated/Unknown                           0.0                     0.0
#     Other Race/ Ethnicity                        0.0                     0.0
#     White Non-Hispanic                         473.0                     0.0
# M   Asian and Pacific Islander                   0.0                     0.0
#     Black Non-Hispanic                           0.0                     0.0
#     Hispanic                                     0.0                     0.0
#     Not Stated/Unknown                           8.0                     0.0
#     Other Race/ Ethnicity                        6.0                     0.0
#     White Non-Hispanic                           0.0                     0.0
#
# leading_cause                   Viral Hepatitis (B15-B19)
# sex race_ethnicity
# F   Asian and Pacific Islander                       15.0
#     Black Non-Hispanic                                0.0
#     Hispanic                                          0.0
#     Not Stated/Unknown                                0.0
#     Other Race/ Ethnicity                             0.0
#     White Non-Hispanic                                0.0
# M   Asian and Pacific Islander                        0.0
#     Black Non-Hispanic                                0.0
#     Hispanic                                          0.0
#     Not Stated/Unknown                                6.0
#     Other Race/ Ethnicity                             0.0
#     White Non-Hispanic                                0.0
#
# [12 rows x 26 columns]

# %%
#plot the data
pivot.transpose()["Diseases of Heart (I00-I09, I11, I13, I20-I51)"].plot.bar()
# Out:
# <Axes: xlabel='sex,race_ethnicity'>

# %% [markdown]
# Write a function that will change the values for the "leading cause" column, and make them shorter. For example, we want to eliminate the codes within the parentheses; the value "Alzheimer's Disease (G30)" should become "Alzheimer's Disease". Use the apply function and/or the map function to create a new column with the shortened values. Then use the drop command to delete the old leading_cause column.
#
# Change the pivot_table to compute the average age_adjusted_death_rate instead of the sum of deaths. (Hint: you can use the numpy.mean function to compute averages.

# %%
# Example input:
# 'Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)
# Example output
# 'Accidents Except Drug Posioning'
import re

def shorten(cause):
    # Get everything before the parentheses
    regex_expression = r'(.*)\(.*\)' # notice that we escape the parentheses
    regex= re.compile(regex_expression)
    matches = regex.finditer(cause)
    for m in matches:
        return m.group(1).strip()[:35]
    return cause[:35]

shorten('Accidents Except Drug Posioning (V01-X39, X43, X45-X59, Y85-Y86)')
# Out:
# 'Accidents Except Drug Posioning'

# %%
[shorten(cause) for cause in set(df['leading_cause'].values)]
# Out:
# ["Alzheimer's Disease",
#  'Diabetes Mellitus',
#  'Insitu or Benign / Uncertain Neopla',
#  'Assault',
#  'Intentional Self-Harm',
#  'Cerebrovascular Disease',
#  'Nephritis, Nephrotic Syndrome and N',
#  'Aortic Aneurysm and Dissection',
#  'Mental and Behavioral Disorders due',
#  'Diseases of Heart',
#  'All Other Causes',
#  'Certain Conditions originating in t',
#  'Atherosclerosis',
#  'Congenital Malformations, Deformati',
#  'Human Immunodeficiency Virus Diseas',
#  'Mental and Behavioral Disorders due',
#  'Tuberculosis',
#  'Viral Hepatitis',
#  'Accidents Except Drug Posioning',
#  'Malignant Neoplasms',
#  'Essential Hypertension and Renal Di',
#  'Chronic Liver Disease and Cirrhosis',
#  "Parkinson's Disease",
#  'Influenza (Flu) and Pneumonia',
#  'Septicemia',
#  'Chronic Lower Respiratory Diseases']

# %%
df["cause"] = df["leading_cause"].apply(shorten)
df
# Out:
#                                        key          created_at  \
# 0     00000000-0000-0000-85AB-5F87A996A300 2024-12-09 20:35:05
# 1     00000000-0000-0000-5DC3-A9FF70A70774 2024-12-09 20:35:05
# 2     00000000-0000-0000-FDE0-47C6EDC2A52E 2024-12-09 20:35:05
# 3     00000000-0000-0000-3231-0B9575966E6B 2024-12-09 20:35:05
# 4     00000000-0000-0000-BBA7-44D13389B1EE 2024-12-09 20:35:05
# ...                                    ...                 ...
# 1089  00000000-0000-0000-2259-D3EC931A567A 2024-12-09 20:35:05
# 1090  00000000-0000-0000-D33D-9EA1CAB15A3A 2024-12-09 20:35:05
# 1091  00000000-0000-0000-8F6B-49D2BDC18CF3 2024-12-09 20:35:05
# 1092  00000000-0000-0000-E015-C94191CE3EEC 2024-12-09 20:35:05
# 1093  00000000-0000-0000-4FAB-41F56BB3458E 2024-12-09 20:35:05
#
#               updated_at  year  \
# 0    2024-12-09 20:35:05  2007
# 1    2024-12-09 20:35:05  2010
# 2    2024-12-09 20:35:05  2007
# 3    2024-12-09 20:35:05  2007
# 4    2024-12-09 20:35:05  2014
# ...                  ...   ...
# 1089 2024-12-09 20:35:05  2013
# 1090 2024-12-09 20:35:05  2009
# 1091 2024-12-09 20:35:05  2008
# 1092 2024-12-09 20:35:05  2010
# 1093 2024-12-09 20:35:05  2013
#
#                                           leading_cause sex  \
# 0                           Diabetes Mellitus (E10-E14)   M
# 1        Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 2             Cerebrovascular Disease (Stroke: I60-I69)   M
# 3                                 Atherosclerosis (I70)   F
# 4                 Malignant Neoplasms (Cancer: C00-C97)   F
# ...                                                 ...  ..
# 1089                                   All Other Causes   M
# 1090     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 1091  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 1092       Chronic Lower Respiratory Diseases (J40-J47)   M
# 1093  Nephritis, Nephrotic Syndrome and Nephrisis (N...   F
#
#              race_ethnicity  deaths  death_rate  age_adjusted_death_rate  \
# 0     Other Race/ Ethnicity    11.0         NaN                      NaN
# 1        Not Stated/Unknown    70.0         NaN                      NaN
# 2        Black Non-Hispanic   213.0        25.0                     33.0
# 3     Other Race/ Ethnicity     NaN         NaN                      NaN
# 4        Black Non-Hispanic  1852.0       176.5                    148.4
# ...                     ...     ...         ...                      ...
# 1089     White Non-Hispanic  2293.0       170.3                    143.3
# 1090     Not Stated/Unknown    94.0         NaN                      NaN
# 1091     Not Stated/Unknown     9.0         NaN                      NaN
# 1092               Hispanic   149.0        13.0                     23.9
# 1093     Black Non-Hispanic    93.0         8.9                      7.6
#
#                                     cause
# 0                       Diabetes Mellitus
# 1                       Diseases of Heart
# 2                 Cerebrovascular Disease
# 3                         Atherosclerosis
# 4                     Malignant Neoplasms
# ...                                   ...
# 1089                     All Other Causes
# 1090                    Diseases of Heart
# 1091  Human Immunodeficiency Virus Diseas
# 1092   Chronic Lower Respiratory Diseases
# 1093  Nephritis, Nephrotic Syndrome and N
#
# [1094 rows x 11 columns]

# %%
import numpy as np
pivot = pd.pivot_table(df,
                       values='deaths',
                       index=['cause'], # rows
                       columns=['sex', 'race_ethnicity'], # columns
                       aggfunc=np.mean) # aggregation function
pivot
# Out:
# <ipython-input-31-9cbce9810cd1>:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = pd.pivot_table(df,
# <ipython-input-31-9cbce9810cd1>:2: FutureWarning: The provided callable <function mean at 0x7f7c113c93a0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = pd.pivot_table(df,
# sex                                                          F  \
# race_ethnicity                      Asian and Pacific Islander
# cause
# Accidents Except Drug Posioning                      35.500000
# All Other Causes                                    264.750000
# Alzheimer's Disease                                  21.333333
# Assault                                                    NaN
# Cerebrovascular Disease                              84.625000
# Certain Conditions originating in t                  18.000000
# Chronic Liver Disease and Cirrhosis                        NaN
# Chronic Lower Respiratory Diseases                   31.125000
# Congenital Malformations, Deformati                        NaN
# Diabetes Mellitus                                    50.625000
# Diseases of Heart                                   428.625000
# Essential Hypertension and Renal Di                  33.625000
# Human Immunodeficiency Virus Diseas                        NaN
# Influenza (Flu) and Pneumonia                        75.375000
# Insitu or Benign / Uncertain Neopla                        NaN
# Intentional Self-Harm                                23.428571
# Malignant Neoplasms                                 429.000000
# Mental and Behavioral Disorders due                        NaN
# Nephritis, Nephrotic Syndrome and N                  16.000000
# Septicemia                                           16.000000
# Viral Hepatitis                                      15.000000
#
# sex                                                                  \
# race_ethnicity                      Black Non-Hispanic     Hispanic
# cause
# Accidents Except Drug Posioning              78.500000    62.428571
# All Other Causes                           1397.250000   979.750000
# Alzheimer's Disease                         100.166667   100.833333
# Assault                                            NaN          NaN
# Cerebrovascular Disease                     268.375000   178.500000
# Certain Conditions originating in t                NaN          NaN
# Chronic Liver Disease and Cirrhosis                NaN    61.000000
# Chronic Lower Respiratory Diseases          206.375000   157.250000
# Congenital Malformations, Deformati                NaN          NaN
# Diabetes Mellitus                           391.625000   211.625000
# Diseases of Heart                          2416.875000  1328.750000
# Essential Hypertension and Renal Di         215.375000    95.500000
# Human Immunodeficiency Virus Diseas         165.500000    93.400000
# Influenza (Flu) and Pneumonia               286.000000   213.750000
# Insitu or Benign / Uncertain Neopla                NaN          NaN
# Intentional Self-Harm                              NaN          NaN
# Malignant Neoplasms                        1815.625000  1083.750000
# Mental and Behavioral Disorders due          87.000000    58.666667
# Nephritis, Nephrotic Syndrome and N          82.000000          NaN
# Septicemia                                   89.000000    49.000000
# Viral Hepatitis                                    NaN          NaN
#
# sex                                                                           \
# race_ethnicity                      Not Stated/Unknown Other Race/ Ethnicity
# cause
# Accidents Except Drug Posioning                    NaN                 6.000
# All Other Causes                             38.375000                28.750
# Alzheimer's Disease                           8.000000                   NaN
# Assault                                            NaN                   NaN
# Cerebrovascular Disease                      10.200000                 7.000
# Certain Conditions originating in t           9.166667                   NaN
# Chronic Liver Disease and Cirrhosis                NaN                   NaN
# Chronic Lower Respiratory Diseases            7.571429                 6.000
# Congenital Malformations, Deformati           8.000000                   NaN
# Diabetes Mellitus                            10.333333                 9.000
# Diseases of Heart                            86.375000                44.500
# Essential Hypertension and Renal Di           5.500000                 8.000
# Human Immunodeficiency Virus Diseas           6.000000                   NaN
# Influenza (Flu) and Pneumonia                12.333333                 6.400
# Insitu or Benign / Uncertain Neopla           5.000000                   NaN
# Intentional Self-Harm                              NaN                 5.000
# Malignant Neoplasms                          43.500000                33.375
# Mental and Behavioral Disorders due           6.000000                   NaN
# Nephritis, Nephrotic Syndrome and N                NaN                   NaN
# Septicemia                                         NaN                   NaN
# Viral Hepatitis                                    NaN                   NaN
#
# sex                                                     \
# race_ethnicity                      White Non-Hispanic
# cause
# Accidents Except Drug Posioning                174.000
# All Other Causes                              2159.000
# Alzheimer's Disease                            212.750
# Assault                                            NaN
# Cerebrovascular Disease                        406.250
# Certain Conditions originating in t                NaN
# Chronic Liver Disease and Cirrhosis                NaN
# Chronic Lower Respiratory Diseases             500.250
# Congenital Malformations, Deformati                NaN
# Diabetes Mellitus                              235.875
# Diseases of Heart                             5538.875
# Essential Hypertension and Renal Di            190.500
# Human Immunodeficiency Virus Diseas                NaN
# Influenza (Flu) and Pneumonia                  634.125
# Insitu or Benign / Uncertain Neopla                NaN
# Intentional Self-Harm                              NaN
# Malignant Neoplasms                           3329.375
# Mental and Behavioral Disorders due             83.000
# Nephritis, Nephrotic Syndrome and N             89.000
# Septicemia                                     118.250
# Viral Hepatitis                                    NaN
#
# sex                                                          M  \
# race_ethnicity                      Asian and Pacific Islander
# cause
# Accidents Except Drug Posioning                      57.875000
# All Other Causes                                    309.875000
# Alzheimer's Disease                                        NaN
# Assault                                                    NaN
# Cerebrovascular Disease                              69.500000
# Certain Conditions originating in t                  19.000000
# Chronic Liver Disease and Cirrhosis                  22.166667
# Chronic Lower Respiratory Diseases                   62.000000
# Congenital Malformations, Deformati                  14.000000
# Diabetes Mellitus                                    64.250000
# Diseases of Heart                                   510.000000
# Essential Hypertension and Renal Di                  31.571429
# Human Immunodeficiency Virus Diseas                        NaN
# Influenza (Flu) and Pneumonia                        90.625000
# Insitu or Benign / Uncertain Neopla                        NaN
# Intentional Self-Harm                                40.875000
# Malignant Neoplasms                                 561.875000
# Mental and Behavioral Disorders due                        NaN
# Nephritis, Nephrotic Syndrome and N                  21.000000
# Septicemia                                                 NaN
# Viral Hepatitis                                            NaN
#
# sex                                                                  \
# race_ethnicity                      Black Non-Hispanic     Hispanic
# cause
# Accidents Except Drug Posioning             149.142857   172.250000
# All Other Causes                           1278.500000  1135.625000
# Alzheimer's Disease                                NaN          NaN
# Assault                                     246.000000   114.000000
# Cerebrovascular Disease                     187.750000   141.500000
# Certain Conditions originating in t                NaN          NaN
# Chronic Liver Disease and Cirrhosis                NaN   143.500000
# Chronic Lower Respiratory Diseases          176.125000   133.428571
# Congenital Malformations, Deformati                NaN          NaN
# Diabetes Mellitus                           288.500000   187.375000
# Diseases of Heart                          1985.875000  1304.125000
# Essential Hypertension and Renal Di         147.500000          NaN
# Human Immunodeficiency Virus Diseas         282.375000   163.000000
# Influenza (Flu) and Pneumonia               232.500000   205.000000
# Insitu or Benign / Uncertain Neopla                NaN          NaN
# Intentional Self-Harm                              NaN          NaN
# Malignant Neoplasms                        1545.125000  1111.500000
# Mental and Behavioral Disorders due         149.000000   166.875000
# Nephritis, Nephrotic Syndrome and N                NaN          NaN
# Septicemia                                         NaN          NaN
# Viral Hepatitis                                    NaN          NaN
#
# sex                                                                           \
# race_ethnicity                      Not Stated/Unknown Other Race/ Ethnicity
# cause
# Accidents Except Drug Posioning              11.600000              7.000000
# All Other Causes                             68.500000             30.250000
# Alzheimer's Disease                                NaN                   NaN
# Assault                                       7.500000              5.000000
# Cerebrovascular Disease                       9.000000              7.200000
# Certain Conditions originating in t          13.857143              8.000000
# Chronic Liver Disease and Cirrhosis          13.000000              7.500000
# Chronic Lower Respiratory Diseases           11.333333              5.000000
# Congenital Malformations, Deformati                NaN                   NaN
# Diabetes Mellitus                            10.000000             12.166667
# Diseases of Heart                            96.125000             47.625000
# Essential Hypertension and Renal Di          12.000000              5.000000
# Human Immunodeficiency Virus Diseas           8.571429             10.000000
# Influenza (Flu) and Pneumonia                13.571429              7.333333
# Insitu or Benign / Uncertain Neopla                NaN                   NaN
# Intentional Self-Harm                        10.000000              5.500000
# Malignant Neoplasms                          56.250000             31.375000
# Mental and Behavioral Disorders due           9.857143             12.000000
# Nephritis, Nephrotic Syndrome and N                NaN                   NaN
# Septicemia                                    8.000000              6.000000
# Viral Hepatitis                               6.000000                   NaN
#
# sex
# race_ethnicity                      White Non-Hispanic
# cause
# Accidents Except Drug Posioning                275.750
# All Other Causes                              2059.250
# Alzheimer's Disease                                NaN
# Assault                                            NaN
# Cerebrovascular Disease                        264.500
# Certain Conditions originating in t                NaN
# Chronic Liver Disease and Cirrhosis                NaN
# Chronic Lower Respiratory Diseases             385.375
# Congenital Malformations, Deformati                NaN
# Diabetes Mellitus                              265.625
# Diseases of Heart                             4656.125
# Essential Hypertension and Renal Di            151.875
# Human Immunodeficiency Virus Diseas                NaN
# Influenza (Flu) and Pneumonia                  566.750
# Insitu or Benign / Uncertain Neopla                NaN
# Intentional Self-Harm                          192.375
# Malignant Neoplasms                           3255.125
# Mental and Behavioral Disorders due            255.750
# Nephritis, Nephrotic Syndrome and N                NaN
# Septicemia                                         NaN
# Viral Hepatitis                                    NaN
